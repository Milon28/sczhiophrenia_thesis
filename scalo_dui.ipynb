# %%
import os
import numpy as np
import pandas as pd
import matplotlib
matplotlib.use('Agg')  # Set backend before importing pyplot
import matplotlib.pyplot as plt
from scipy import signal
from scipy.signal import butter, sosfiltfilt
import pywt
from concurrent.futures import ThreadPoolExecutor, as_completed
import multiprocessing as mp
from functools import partial
import warnings
import traceback
import gc
warnings.filterwarnings('ignore')

class OptimizedEEGScalogramGenerator:
    def __init__(self, sz_input_dir, hc_input_dir, output_dir, sampling_rate=250, n_jobs=None):
        """
        Initialize the Optimized EEG Scalogram Generator using Continuous Wavelet Transform (CWT)
        
        Parameters:
        sz_input_dir (str): Directory containing CSV files with Schizophrenia EEG data
        hc_input_dir (str): Directory containing CSV files with Healthy Control EEG data
        output_dir (str): Root directory to save scalogram images
        sampling_rate (int): EEG sampling rate in Hz (default: 250 Hz)
        n_jobs (int): Number of parallel threads (default: CPU count)
        """
        self.sz_input_dir = sz_input_dir
        self.hc_input_dir = hc_input_dir
        self.output_dir = output_dir
        self.sampling_rate = sampling_rate
        self.segment_duration = 3  # 3 seconds
        self.segment_samples = self.sampling_rate * self.segment_duration
        
        # Set number of parallel jobs (using threads instead of processes)
        if n_jobs is None:
            self.n_jobs = min(mp.cpu_count(), 8)  # Cap at 8 to avoid memory issues
        else:
            self.n_jobs = min(n_jobs, 8)
        
        # Wavelet parameters - optimized
        self.wavelet = 'cmor1.5-1.0'  # Complex Morlet wavelet
        self.freq_min = 0.5  # Minimum frequency (Hz)
        self.freq_max = 45   # Maximum frequency (Hz)
        self.num_scales = 100  # Number of scales/frequencies
        
        # Pre-compute frequency array and scales (Float32 for efficiency)
        self.frequencies = np.logspace(np.log10(self.freq_min), np.log10(self.freq_max), 
                                     self.num_scales, dtype=np.float32)
        self.scales = pywt.frequency2scale(self.wavelet, self.frequencies / self.sampling_rate) * self.sampling_rate
        self.scales = self.scales.astype(np.float32)
        
        # Pre-compute filter coefficients (SOS format for stability and speed)
        self.filter_sos = self._precompute_filter()
        
        # Create output directories
        self.sz_dir = os.path.join(output_dir, 'Schizophrenia')
        self.hc_dir = os.path.join(output_dir, 'HealthyControl')
        os.makedirs(self.sz_dir, exist_ok=True)
        os.makedirs(self.hc_dir, exist_ok=True)
        
        print(f"Initialized with {self.n_jobs} parallel threads")
        
    def _precompute_filter(self):
        """Pre-compute bandpass filter coefficients for reuse"""
        nyquist = 0.5 * self.sampling_rate
        low = self.freq_min / nyquist
        high = self.freq_max / nyquist
        sos = signal.butter(4, [low, high], btype='band', output='sos')
        return sos
    
    def bandpass_filter_optimized(self, data):
        """
        Apply pre-computed bandpass filter to EEG data (optimized version)
        """
        # Use SOS format for better numerical stability and speed
        filtered_data = sosfiltfilt(self.filter_sos, data, axis=0)
        return filtered_data.astype(np.float32)
    
    def segment_signal_vectorized(self, data):
        """
        Vectorized segmentation of EEG signal into 3-second windows
        """
        n_samples, n_channels = data.shape
        n_segments = n_samples // self.segment_samples
        
        if n_segments == 0:
            return []
        
        # Reshape for vectorized processing
        valid_samples = n_segments * self.segment_samples
        reshaped_data = data[:valid_samples, :].reshape(n_segments, self.segment_samples, n_channels)
        
        # Convert to list of segments
        segments = [segment.astype(np.float32) for segment in reshaped_data]
        return segments
    
    def compute_cwt_optimized(self, signal_data):
        """
        Optimized CWT computation for a single channel
        """
        signal_data = signal_data.astype(np.float32)
        
        try:
            coefficients, _ = pywt.cwt(signal_data, self.scales, self.wavelet, 
                                     sampling_period=1/self.sampling_rate)
            
            # Convert to power and dB scale with error handling
            power = np.abs(coefficients) ** 2
            # Avoid log(0) by adding small epsilon
            power_db = 10 * np.log10(np.maximum(power, 1e-12))
            
            return power_db.astype(np.float32)
        except Exception as e:
            print(f"CWT computation error: {e}")
            # Return zeros if computation fails
            return np.zeros((len(self.scales), len(signal_data)), dtype=np.float32)
    
    def create_combined_scalogram_safe(self, segment, patient_id, segment_idx, label):
        """
        Safe version of scalogram creation with proper error handling
        """
        try:
            # Compute CWT for all channels
            scalograms = []
            for ch in range(segment.shape[1]):
                cwt_result = self.compute_cwt_optimized(segment[:, ch])
                scalograms.append(cwt_result)
            
            # Average across all channels
            avg_scalogram = np.mean(scalograms, axis=0, dtype=np.float32)
            
            # Create time axis
            time_axis = np.linspace(0, self.segment_duration, segment.shape[0], dtype=np.float32)
            
            # Create figure with explicit cleanup
            plt.ioff()  # Turn off interactive mode
            fig, ax = plt.subplots(figsize=(10, 6), dpi=150)
            
            try:
                im = ax.imshow(
                    avg_scalogram, 
                    aspect='auto', 
                    origin='lower',
                    extent=[time_axis[0], time_axis[-1], self.frequencies[0], self.frequencies[-1]],
                    cmap='viridis',
                    interpolation='bilinear'
                )
                
                ax.set_title(f'Average EEG Scalogram (CWT) - {label} Patient {patient_id} - Segment {segment_idx}', 
                            fontsize=14, fontweight='bold')
                ax.set_xlabel('Time (s)', fontsize=12)
                ax.set_ylabel('Frequency (Hz)', fontsize=12)
                ax.set_yscale('log')
                ax.set_ylim(self.freq_min, self.freq_max)
                
                # Determine save directory and filename
                save_dir = self.sz_dir if label == 'SZ' else self.hc_dir
                filename = f'{label}_patient_{patient_id}_segment_{segment_idx:03d}_scalogram_combined.png'
                filepath = os.path.join(save_dir, filename)
                
                # Save with error handling (removed optimize parameter for compatibility)
                plt.savefig(filepath, dpi=150, bbox_inches='tight', facecolor='white', 
                           format='png')
                
                return filepath
                
            finally:
                plt.close(fig)  # Always close the figure
                plt.clf()       # Clear any remaining plots
                gc.collect()    # Force garbage collection
                
        except Exception as e:
            print(f"Error creating scalogram for {patient_id} segment {segment_idx}: {e}")
            return None
    
    def process_patient_file_safe(self, csv_file, patient_id, label):
        """
        Safe version of patient file processing with comprehensive error handling
        """
        print(f"Processing {label} Patient {patient_id}...")
        
        try:
            # Load EEG data with error handling
            try:
                data = pd.read_csv(csv_file, dtype=np.float32)
                eeg_data = data.values.astype(np.float32)
            except Exception as e:
                print(f"Error loading CSV file {csv_file}: {e}")
                return []
            
            # Handle channel count
            if eeg_data.shape[1] != 19:
                print(f"Warning: Expected 19 channels, got {eeg_data.shape[1]} for patient {patient_id}")
                if eeg_data.shape[1] > 19:
                    eeg_data = eeg_data[:, :19]
                else:
                    padding = np.zeros((eeg_data.shape[0], 19 - eeg_data.shape[1]), dtype=np.float32)
                    eeg_data = np.hstack([eeg_data, padding])
            
            print(f"  EEG data shape: {eeg_data.shape}")
            
            # Apply bandpass filter with error handling
            try:
                print(f"  Applying bandpass filter ({self.freq_min}-{self.freq_max} Hz)...")
                filtered_data = self.bandpass_filter_optimized(eeg_data)
            except Exception as e:
                print(f"Error in filtering for patient {patient_id}: {e}")
                return []
            
            # Segment the data
            print(f"  Segmenting data into {self.segment_duration}-second windows...")
            segments = self.segment_signal_vectorized(filtered_data)
            
            if not segments:
                print(f"  No segments generated for patient {patient_id}")
                return []
            
            print(f"  Generated {len(segments)} segments from patient {patient_id}")
            
            # Create scalogram images for each segment
            saved_files = []
            for idx, segment in enumerate(segments):
                print(f"  Processing segment {idx + 1}/{len(segments)}...")
                
                filepath = self.create_combined_scalogram_safe(segment, patient_id, idx, label)
                if filepath:
                    saved_files.append(filepath)
                    print(f"  Saved: {os.path.basename(filepath)}")
                else:
                    print(f"  Failed to save segment {idx}")
            
            return saved_files
            
        except Exception as e:
            print(f"Error processing patient {patient_id}: {str(e)}")
            traceback.print_exc()
            return []
    
    def get_patient_files(self, directory):
        """
        Get all CSV files from a directory
        """
        csv_files = []
        if os.path.exists(directory):
            for file in os.listdir(directory):
                if file.lower().endswith('.csv'):
                    csv_files.append(os.path.join(directory, file))
            csv_files.sort()
        else:
            print(f"Warning: Directory {directory} does not exist!")
        
        return csv_files
    
    def process_all_patients_threaded(self):
        """
        Process all patients using thread-based parallelism (safer than multiprocessing)
        """
        print("=== Optimized EEG Scalogram Generation (Thread-based Parallel Processing) ===")
        print("Generating scalograms with thread-based parallelism for stability\n")
        
        # Get patient files from both directories
        sz_patient_files = self.get_patient_files(self.sz_input_dir)
        hc_patient_files = self.get_patient_files(self.hc_input_dir)
        
        print(f"Found {len(sz_patient_files)} Schizophrenia patient files")
        print(f"Found {len(hc_patient_files)} Healthy Control patient files")
        print(f"Using {self.n_jobs} parallel threads")
        
        if len(sz_patient_files) == 0 and len(hc_patient_files) == 0:
            print("No CSV files found in the specified directories!")
            return
        
        # Prepare all patient processing tasks
        tasks = []
        
        # Add SZ patients
        for i, csv_file in enumerate(sz_patient_files, 1):
            patient_id = f"SZ_{i:02d}"
            tasks.append((csv_file, patient_id, 'SZ'))
        
        # Add HC patients
        for i, csv_file in enumerate(hc_patient_files, 1):
            patient_id = f"HC_{i:02d}"
            tasks.append((csv_file, patient_id, 'HC'))
        
        total_sz_images = 0
        total_hc_images = 0
        
        # Process patients using ThreadPoolExecutor
        with ThreadPoolExecutor(max_workers=self.n_jobs) as executor:
            # Submit all tasks
            future_to_task = {
                executor.submit(self.process_patient_file_safe, csv_file, patient_id, label): (patient_id, label)
                for csv_file, patient_id, label in tasks
            }
            
            # Process completed tasks
            for future in as_completed(future_to_task):
                patient_id, label = future_to_task[future]
                try:
                    saved_files = future.result(timeout=300)  # 5 minute timeout per patient
                    if label == 'SZ':
                        total_sz_images += len(saved_files)
                    else:
                        total_hc_images += len(saved_files)
                    print(f"  Completed {patient_id}: {len(saved_files)} scalograms generated\n")
                    
                except Exception as e:
                    print(f"Error processing {patient_id}: {e}")
                    traceback.print_exc()
        
        print("=== Summary ===")
        print(f"Total Schizophrenia scalogram images: {total_sz_images}")
        print(f"Total Healthy Control scalogram images: {total_hc_images}")
        print(f"Total scalogram images generated: {total_sz_images + total_hc_images}")
        print(f"Images saved in: {self.output_dir}")
        print(f"  - Schizophrenia scalograms: {self.sz_dir}")
        print(f"  - Healthy Control scalograms: {self.hc_dir}")
        print(f"Wavelet used: {self.wavelet}")
        print(f"Frequency range: {self.freq_min}-{self.freq_max} Hz")
        print(f"Processing completed successfully with {self.n_jobs} threads")

    def process_all_patients_sequential_optimized(self):
        """
        Optimized sequential processing as fallback option
        """
        print("=== Optimized EEG Scalogram Generation (Sequential Processing) ===")
        print("Using optimized sequential processing for maximum stability\n")
        
        # Get patient files from both directories
        sz_patient_files = self.get_patient_files(self.sz_input_dir)
        hc_patient_files = self.get_patient_files(self.hc_input_dir)
        
        print(f"Found {len(sz_patient_files)} Schizophrenia patient files")
        print(f"Found {len(hc_patient_files)} Healthy Control patient files")
        
        if len(sz_patient_files) == 0 and len(hc_patient_files) == 0:
            print("No CSV files found in the specified directories!")
            return
        
        total_sz_images = 0
        total_hc_images = 0
        
        print("\n=== Processing Schizophrenia Patients ===")
        for i, csv_file in enumerate(sz_patient_files, 1):
            patient_id = f"SZ_{i:02d}"
            saved_files = self.process_patient_file_safe(csv_file, patient_id, 'SZ')
            total_sz_images += len(saved_files)
            print(f"  Generated {len(saved_files)} scalograms for {patient_id}\n")
        
        print("=== Processing Healthy Control Patients ===")
        for i, csv_file in enumerate(hc_patient_files, 1):
            patient_id = f"HC_{i:02d}"
            saved_files = self.process_patient_file_safe(csv_file, patient_id, 'HC')
            total_hc_images += len(saved_files)
            print(f"  Generated {len(saved_files)} scalograms for {patient_id}\n")
        
        print("=== Summary ===")
        print(f"Total Schizophrenia scalogram images: {total_sz_images}")
        print(f"Total Healthy Control scalogram images: {total_hc_images}")
        print(f"Total scalogram images generated: {total_sz_images + total_hc_images}")
        print(f"Images saved in: {self.output_dir}")
        print(f"Sequential processing completed successfully")

# Example usage
if __name__ == "__main__":
    # Define paths
    sz_input_directory = "D:/Milon2/SD14/schizophrenia"
    hc_input_directory = "D:/Milon2/SD14/healthy" 
    output_directory = "D:/Milon2/scalogram/images"
    
    # Create optimized scalogram generator
    generator = OptimizedEEGScalogramGenerator(
        sz_input_dir=sz_input_directory,
        hc_input_dir=hc_input_directory,
        output_dir=output_directory,
        sampling_rate=256,
        n_jobs=4  # Use 4 threads for safer parallel processing
    )
    
    print("Choose processing method:")
    print("1. Thread-based parallel processing (recommended)")
    print("2. Sequential processing (most stable)")
    
    try:
        # Try thread-based parallel processing first
        print("\nStarting thread-based parallel processing...")
        generator.process_all_patients_threaded()
    except Exception as e:
        print(f"\nThread-based processing failed: {e}")
        print("Falling back to sequential processing...")
        generator.process_all_patients_sequential_optimized()
    
    print("\nOptimized scalogram generation completed!")
    print("Key improvements:")
    print("- Thread-based parallelism (safer than multiprocessing)")
    print("- Comprehensive error handling and recovery")
    print("- Memory management with garbage collection")
    print("- Vectorized operations where possible")
    print("- Pre-computed filter coefficients")
    print("- Optimized matplotlib settings")
# Out:
# Initialized with 4 parallel threads
# Choose processing method:
# 1. Thread-based parallel processing (recommended)
# 2. Sequential processing (most stable)
#
# Starting thread-based parallel processing...
# === Optimized EEG Scalogram Generation (Thread-based Parallel Processing) ===
# Generating scalograms with thread-based parallelism for stability
#
# Found 14 Schizophrenia patient files
# Found 14 Healthy Control patient files
# Using 4 parallel threads
# Processing SZ Patient SZ_01...
# Processing SZ Patient SZ_02...
# Processing SZ Patient SZ_03...
# Processing SZ Patient SZ_04...
#   EEG data shape: (211250, 19)
#   Applying bandpass filter (0.5-45 Hz)...
#   Segmenting data into 3-second windows...
#   Generated 275 segments from patient SZ_01
#   Processing segment 1/275...
#   EEG data shape: (241000, 19)
#   Applying bandpass filter (0.5-45 Hz)...
#   Segmenting data into 3-second windows...
#   Generated 313 segments from patient SZ_03
#   Processing segment 1/313...
#   EEG data shape: (286250, 19)
#   Applying bandpass filter (0.5-45 Hz)...
#   EEG data shape: (301250, 19)
#   Applying bandpass filter (0.5-45 Hz)...
#   Segmenting data into 3-second windows...
#   Generated 372 segments from patient SZ_02
#   Processing segment 1/372...
#   Segmenting data into 3-second windows...
#   Generated 392 segments from patient SZ_04
#   Processing segment 1/392...
#   Saved: SZ_patient_SZ_04_segment_000_scalogram_combined.png  Saved: SZ_patient_SZ_02_segment_000_scalogram_combined.png
#   Processing segment 2/372...
#
#   Processing segment 2/392...
#   Saved: SZ_patient_SZ_01_segment_000_scalogram_combined.png
#   Processing segment 2/275...
#   Saved: SZ_patient_SZ_03_segment_000_scalogram_combined.png
#   Processing segment 2/313...
#   Saved: SZ_patient_SZ_04_segment_001_scalogram_combined.png
#   Processing segment 3/392...
#   Saved: SZ_patient_SZ_02_segment_001_scalogram_combined.png
#   Processing segment 3/372...
#   Saved: SZ_patient_SZ_01_segment_001_scalogram_combined.png
#   Processing segment 3/275...
#   Saved: SZ_patient_SZ_03_segment_001_scalogram_combined.png
#   Processing segment 3/313...
#   Saved: SZ_patient_SZ_04_segment_002_scalogram_combined.png
#   Processing segment 4/392...
#   Saved: SZ_patient_SZ_02_segment_002_scalogram_combined.png
#   Processing segment 4/372...
#   Saved: SZ_patient_SZ_01_segment_002_scalogram_combined.png
#   Processing segment 4/275...
#   Saved: SZ_patient_SZ_03_segment_002_scalogram_combined.png
#   Processing segment 4/313...
#   Saved: SZ_patient_SZ_04_segment_003_scalogram_combined.png
#   Processing segment 5/392...
#   Saved: SZ_patient_SZ_02_segment_003_scalogram_combined.png
#   Processing segment 5/372...
#   Saved: SZ_patient_SZ_01_segment_003_scalogram_combined.png
#   Processing segment 5/275...
#   Saved: SZ_patient_SZ_03_segment_003_scalogram_combined.png
#   Processing segment 5/313...
#   Saved: SZ_patient_SZ_04_segment_004_scalogram_combined.png
#   Processing segment 6/392...
#   Saved: SZ_patient_SZ_02_segment_004_scalogram_combined.png
#   Processing segment 6/372...
#   Saved: SZ_patient_SZ_01_segment_004_scalogram_combined.png
#   Processing segment 6/275...
#   Saved: SZ_patient_SZ_03_segment_004_scalogram_combined.png
#   Processing segment 6/313...
#   Saved: SZ_patient_SZ_04_segment_005_scalogram_combined.png
#   Processing segment 7/392...
#   Saved: SZ_patient_SZ_02_segment_005_scalogram_combined.png
#   Processing segment 7/372...
#   Saved: SZ_patient_SZ_01_segment_005_scalogram_combined.png
#   Processing segment 7/275...
#   Saved: SZ_patient_SZ_03_segment_005_scalogram_combined.png
#   Processing segment 7/313...
#   Saved: SZ_patient_SZ_04_segment_006_scalogram_combined.png
#   Processing segment 8/392...
#   Saved: SZ_patient_SZ_02_segment_006_scalogram_combined.png
#   Processing segment 8/372...
#   Saved: SZ_patient_SZ_01_segment_006_scalogram_combined.png
#   Processing segment 8/275...
#   Saved: SZ_patient_SZ_03_segment_006_scalogram_combined.png
#   Processing segment 8/313...
#   Saved: SZ_patient_SZ_04_segment_007_scalogram_combined.png
#   Processing segment 9/392...
#   Saved: SZ_patient_SZ_02_segment_007_scalogram_combined.png
#   Processing segment 9/372...
#   Saved: SZ_patient_SZ_01_segment_007_scalogram_combined.png
#   Processing segment 9/275...
#   Saved: SZ_patient_SZ_03_segment_007_scalogram_combined.png
#   Processing segment 9/313...
#   Saved: SZ_patient_SZ_04_segment_008_scalogram_combined.png
#   Processing segment 10/392...
#   Saved: SZ_patient_SZ_02_segment_008_scalogram_combined.png
#   Processing segment 10/372...
#   Saved: SZ_patient_SZ_01_segment_008_scalogram_combined.png
#   Processing segment 10/275...
#   Saved: SZ_patient_SZ_03_segment_008_scalogram_combined.png
#   Processing segment 10/313...
#   Saved: SZ_patient_SZ_04_segment_009_scalogram_combined.png
#   Processing segment 11/392...
#   Saved: SZ_patient_SZ_02_segment_009_scalogram_combined.png
#   Processing segment 11/372...
#   Saved: SZ_patient_SZ_01_segment_009_scalogram_combined.png
#   Processing segment 11/275...
#   Saved: SZ_patient_SZ_03_segment_009_scalogram_combined.png
#   Processing segment 11/313...
#   Saved: SZ_patient_SZ_04_segment_010_scalogram_combined.png
#   Processing segment 12/392...
#   Saved: SZ_patient_SZ_02_segment_010_scalogram_combined.png
#   Processing segment 12/372...
#   Saved: SZ_patient_SZ_01_segment_010_scalogram_combined.png
#   Processing segment 12/275...
#   Saved: SZ_patient_SZ_03_segment_010_scalogram_combined.png
#   Processing segment 12/313...
#   Saved: SZ_patient_SZ_04_segment_011_scalogram_combined.png
#   Processing segment 13/392...
#   Saved: SZ_patient_SZ_02_segment_011_scalogram_combined.png
#   Processing segment 13/372...
#   Saved: SZ_patient_SZ_01_segment_011_scalogram_combined.png
#   Processing segment 13/275...
#   Saved: SZ_patient_SZ_03_segment_011_scalogram_combined.png
#   Processing segment 13/313...
#   Saved: SZ_patient_SZ_04_segment_012_scalogram_combined.png
#   Processing segment 14/392...
#   Saved: SZ_patient_SZ_02_segment_012_scalogram_combined.png
#   Processing segment 14/372...
#   Saved: SZ_patient_SZ_01_segment_012_scalogram_combined.png
#   Processing segment 14/275...
#   Saved: SZ_patient_SZ_03_segment_012_scalogram_combined.png
#   Processing segment 14/313...
#   Saved: SZ_patient_SZ_04_segment_013_scalogram_combined.png
#   Processing segment 15/392...
#   Saved: SZ_patient_SZ_02_segment_013_scalogram_combined.png
#   Processing segment 15/372...
#   Saved: SZ_patient_SZ_01_segment_013_scalogram_combined.png
#   Processing segment 15/275...
#   Saved: SZ_patient_SZ_03_segment_013_scalogram_combined.png
#   Processing segment 15/313...
#   Saved: SZ_patient_SZ_04_segment_014_scalogram_combined.png
#   Processing segment 16/392...
#   Saved: SZ_patient_SZ_02_segment_014_scalogram_combined.png
#   Processing segment 16/372...
#   Saved: SZ_patient_SZ_01_segment_014_scalogram_combined.png
#   Processing segment 16/275...
#   Saved: SZ_patient_SZ_03_segment_014_scalogram_combined.png
#   Processing segment 16/313...
#   Saved: SZ_patient_SZ_04_segment_015_scalogram_combined.png
#   Processing segment 17/392...
#   Saved: SZ_patient_SZ_02_segment_015_scalogram_combined.png
#   Processing segment 17/372...
#   Saved: SZ_patient_SZ_01_segment_015_scalogram_combined.png
#   Processing segment 17/275...
#   Saved: SZ_patient_SZ_03_segment_015_scalogram_combined.png
#   Processing segment 17/313...
#   Saved: SZ_patient_SZ_04_segment_016_scalogram_combined.png
#   Processing segment 18/392...
#   Saved: SZ_patient_SZ_02_segment_016_scalogram_combined.png
#   Processing segment 18/372...
#   Saved: SZ_patient_SZ_01_segment_016_scalogram_combined.png
#   Processing segment 18/275...
#   Saved: SZ_patient_SZ_03_segment_016_scalogram_combined.png
#   Processing segment 18/313...
#   Saved: SZ_patient_SZ_04_segment_017_scalogram_combined.png
#   Processing segment 19/392...
#   Saved: SZ_patient_SZ_02_segment_017_scalogram_combined.png
#   Processing segment 19/372...
#   Saved: SZ_patient_SZ_01_segment_017_scalogram_combined.png
#   Processing segment 19/275...
#   Saved: SZ_patient_SZ_03_segment_017_scalogram_combined.png
#   Processing segment 19/313...
#   Saved: SZ_patient_SZ_04_segment_018_scalogram_combined.png
#   Processing segment 20/392...
#   Saved: SZ_patient_SZ_02_segment_018_scalogram_combined.png
#   Processing segment 20/372...
#   Saved: SZ_patient_SZ_01_segment_018_scalogram_combined.png
#   Processing segment 20/275...
#   Saved: SZ_patient_SZ_03_segment_018_scalogram_combined.png
#   Processing segment 20/313...
#   Saved: SZ_patient_SZ_04_segment_019_scalogram_combined.png
#   Processing segment 21/392...
#   Saved: SZ_patient_SZ_02_segment_019_scalogram_combined.png
#   Processing segment 21/372...
#   Saved: SZ_patient_SZ_01_segment_019_scalogram_combined.png
#   Processing segment 21/275...
#   Saved: SZ_patient_SZ_03_segment_019_scalogram_combined.png
#   Processing segment 21/313...
#   Saved: SZ_patient_SZ_04_segment_020_scalogram_combined.png
#   Processing segment 22/392...
#   Saved: SZ_patient_SZ_02_segment_020_scalogram_combined.png
#   Processing segment 22/372...
#   Saved: SZ_patient_SZ_01_segment_020_scalogram_combined.png
#   Processing segment 22/275...
#   Saved: SZ_patient_SZ_03_segment_020_scalogram_combined.png
#   Processing segment 22/313...
#   Saved: SZ_patient_SZ_04_segment_021_scalogram_combined.png
#   Processing segment 23/392...
#   Saved: SZ_patient_SZ_02_segment_021_scalogram_combined.png
#   Processing segment 23/372...
#   Saved: SZ_patient_SZ_01_segment_021_scalogram_combined.png
#   Processing segment 23/275...
#   Saved: SZ_patient_SZ_03_segment_021_scalogram_combined.png
#   Processing segment 23/313...
#   Saved: SZ_patient_SZ_04_segment_022_scalogram_combined.png
#   Processing segment 24/392...
#   Saved: SZ_patient_SZ_02_segment_022_scalogram_combined.png
#   Processing segment 24/372...
#   Saved: SZ_patient_SZ_01_segment_022_scalogram_combined.png
#   Processing segment 24/275...
#   Saved: SZ_patient_SZ_03_segment_022_scalogram_combined.png
#   Processing segment 24/313...
#   Saved: SZ_patient_SZ_04_segment_023_scalogram_combined.png
#   Processing segment 25/392...
#   Saved: SZ_patient_SZ_02_segment_023_scalogram_combined.png
#   Processing segment 25/372...
#   Saved: SZ_patient_SZ_01_segment_023_scalogram_combined.png
#   Processing segment 25/275...
#   Saved: SZ_patient_SZ_03_segment_023_scalogram_combined.png
#   Processing segment 25/313...
#   Saved: SZ_patient_SZ_04_segment_024_scalogram_combined.png
#   Processing segment 26/392...
#   Saved: SZ_patient_SZ_02_segment_024_scalogram_combined.png
#   Processing segment 26/372...
#   Saved: SZ_patient_SZ_01_segment_024_scalogram_combined.png
#   Processing segment 26/275...
#   Saved: SZ_patient_SZ_03_segment_024_scalogram_combined.png
#   Processing segment 26/313...
#   Saved: SZ_patient_SZ_04_segment_025_scalogram_combined.png
#   Processing segment 27/392...
#   Saved: SZ_patient_SZ_02_segment_025_scalogram_combined.png
#   Processing segment 27/372...
#   Saved: SZ_patient_SZ_01_segment_025_scalogram_combined.png
#   Processing segment 27/275...
#   Saved: SZ_patient_SZ_03_segment_025_scalogram_combined.png
#   Processing segment 27/313...
#   Saved: SZ_patient_SZ_04_segment_026_scalogram_combined.png
#   Processing segment 28/392...
#   Saved: SZ_patient_SZ_02_segment_026_scalogram_combined.png
#   Processing segment 28/372...
#   Saved: SZ_patient_SZ_01_segment_026_scalogram_combined.png
#   Processing segment 28/275...
#   Saved: SZ_patient_SZ_03_segment_026_scalogram_combined.png
#   Processing segment 28/313...
#   Saved: SZ_patient_SZ_04_segment_027_scalogram_combined.png
#   Processing segment 29/392...
#   Saved: SZ_patient_SZ_02_segment_027_scalogram_combined.png
#   Processing segment 29/372...
#   Saved: SZ_patient_SZ_01_segment_027_scalogram_combined.png
#   Processing segment 29/275...
#   Saved: SZ_patient_SZ_03_segment_027_scalogram_combined.png
#   Processing segment 29/313...
#   Saved: SZ_patient_SZ_04_segment_028_scalogram_combined.png
#   Processing segment 30/392...
#   Saved: SZ_patient_SZ_02_segment_028_scalogram_combined.png
#   Processing segment 30/372...
#   Saved: SZ_patient_SZ_01_segment_028_scalogram_combined.png
#   Processing segment 30/275...
#   Saved: SZ_patient_SZ_03_segment_028_scalogram_combined.png
#   Processing segment 30/313...
#   Saved: SZ_patient_SZ_04_segment_029_scalogram_combined.png
#   Processing segment 31/392...
#   Saved: SZ_patient_SZ_02_segment_029_scalogram_combined.png
#   Processing segment 31/372...
#   Saved: SZ_patient_SZ_01_segment_029_scalogram_combined.png
#   Processing segment 31/275...
#   Saved: SZ_patient_SZ_03_segment_029_scalogram_combined.png
#   Processing segment 31/313...
#   Saved: SZ_patient_SZ_04_segment_030_scalogram_combined.png
#   Processing segment 32/392...
#   Saved: SZ_patient_SZ_02_segment_030_scalogram_combined.png
#   Processing segment 32/372...
#   Saved: SZ_patient_SZ_01_segment_030_scalogram_combined.png
#   Processing segment 32/275...
#   Saved: SZ_patient_SZ_03_segment_030_scalogram_combined.png
#   Processing segment 32/313...
#   Saved: SZ_patient_SZ_04_segment_031_scalogram_combined.png
#   Processing segment 33/392...
#   Saved: SZ_patient_SZ_02_segment_031_scalogram_combined.png
#   Processing segment 33/372...
#   Saved: SZ_patient_SZ_01_segment_031_scalogram_combined.png
#   Processing segment 33/275...
#   Saved: SZ_patient_SZ_03_segment_031_scalogram_combined.png
#   Processing segment 33/313...
#   Saved: SZ_patient_SZ_04_segment_032_scalogram_combined.png
#   Processing segment 34/392...
#   Saved: SZ_patient_SZ_02_segment_032_scalogram_combined.png
#   Processing segment 34/372...
#   Saved: SZ_patient_SZ_01_segment_032_scalogram_combined.png
#   Processing segment 34/275...
#   Saved: SZ_patient_SZ_03_segment_032_scalogram_combined.png
#   Processing segment 34/313...
#   Saved: SZ_patient_SZ_04_segment_033_scalogram_combined.png
#   Processing segment 35/392...
#   Saved: SZ_patient_SZ_02_segment_033_scalogram_combined.png
#   Processing segment 35/372...
#   Saved: SZ_patient_SZ_01_segment_033_scalogram_combined.png
#   Processing segment 35/275...
#   Saved: SZ_patient_SZ_03_segment_033_scalogram_combined.png
#   Processing segment 35/313...
#   Saved: SZ_patient_SZ_04_segment_034_scalogram_combined.png
#   Processing segment 36/392...
#   Saved: SZ_patient_SZ_02_segment_034_scalogram_combined.png
#   Processing segment 36/372...
#   Saved: SZ_patient_SZ_01_segment_034_scalogram_combined.png
#   Processing segment 36/275...
#   Saved: SZ_patient_SZ_03_segment_034_scalogram_combined.png
#   Processing segment 36/313...
#   Saved: SZ_patient_SZ_04_segment_035_scalogram_combined.png
#   Processing segment 37/392...
#   Saved: SZ_patient_SZ_02_segment_035_scalogram_combined.png
#   Processing segment 37/372...
#   Saved: SZ_patient_SZ_01_segment_035_scalogram_combined.png
#   Processing segment 37/275...
#   Saved: SZ_patient_SZ_03_segment_035_scalogram_combined.png
#   Processing segment 37/313...
#   Saved: SZ_patient_SZ_04_segment_036_scalogram_combined.png
#   Processing segment 38/392...
#   Saved: SZ_patient_SZ_02_segment_036_scalogram_combined.png
#   Processing segment 38/372...
#   Saved: SZ_patient_SZ_01_segment_036_scalogram_combined.png
#   Processing segment 38/275...
#   Saved: SZ_patient_SZ_04_segment_037_scalogram_combined.png  Saved: SZ_patient_SZ_03_segment_036_scalogram_combined.png
#   Processing segment 38/313...
#
#   Processing segment 39/392...
#   Saved: SZ_patient_SZ_02_segment_037_scalogram_combined.png
#   Processing segment 39/372...
#   Saved: SZ_patient_SZ_01_segment_037_scalogram_combined.png
#   Processing segment 39/275...
#   Saved: SZ_patient_SZ_04_segment_038_scalogram_combined.png
#   Processing segment 40/392...
#   Saved: SZ_patient_SZ_03_segment_037_scalogram_combined.png
#   Processing segment 39/313...
#   Saved: SZ_patient_SZ_02_segment_038_scalogram_combined.png
#   Processing segment 40/372...
#   Saved: SZ_patient_SZ_01_segment_038_scalogram_combined.png
#   Processing segment 40/275...
#   Saved: SZ_patient_SZ_04_segment_039_scalogram_combined.png
#   Processing segment 41/392...
#   Saved: SZ_patient_SZ_03_segment_038_scalogram_combined.png
#   Processing segment 40/313...
#   Saved: SZ_patient_SZ_02_segment_039_scalogram_combined.png
#   Processing segment 41/372...
#   Saved: SZ_patient_SZ_01_segment_039_scalogram_combined.png
#   Processing segment 41/275...
#   Saved: SZ_patient_SZ_04_segment_040_scalogram_combined.png
#   Processing segment 42/392...
#   Saved: SZ_patient_SZ_03_segment_039_scalogram_combined.png
#   Processing segment 41/313...
#   Saved: SZ_patient_SZ_02_segment_040_scalogram_combined.png
#   Processing segment 42/372...
#   Saved: SZ_patient_SZ_01_segment_040_scalogram_combined.png
#   Processing segment 42/275...
#   Saved: SZ_patient_SZ_04_segment_041_scalogram_combined.png
#   Processing segment 43/392...
#   Saved: SZ_patient_SZ_02_segment_041_scalogram_combined.png
#   Processing segment 43/372...
#   Saved: SZ_patient_SZ_03_segment_040_scalogram_combined.png
#   Processing segment 42/313...
#   Saved: SZ_patient_SZ_01_segment_041_scalogram_combined.png
#   Processing segment 43/275...
#   Saved: SZ_patient_SZ_04_segment_042_scalogram_combined.png
#   Processing segment 44/392...
#   Saved: SZ_patient_SZ_02_segment_042_scalogram_combined.png
#   Processing segment 44/372...
#   Saved: SZ_patient_SZ_03_segment_041_scalogram_combined.png
#   Processing segment 43/313...
#   Saved: SZ_patient_SZ_01_segment_042_scalogram_combined.png
#   Processing segment 44/275...
#   Saved: SZ_patient_SZ_04_segment_043_scalogram_combined.png
#   Processing segment 45/392...
#   Saved: SZ_patient_SZ_02_segment_043_scalogram_combined.png
#   Processing segment 45/372...
#   Saved: SZ_patient_SZ_03_segment_042_scalogram_combined.png
#   Processing segment 44/313...
#   Saved: SZ_patient_SZ_01_segment_043_scalogram_combined.png
#   Processing segment 45/275...
#   Saved: SZ_patient_SZ_04_segment_044_scalogram_combined.png
#   Processing segment 46/392...
#   Saved: SZ_patient_SZ_02_segment_044_scalogram_combined.png
#   Processing segment 46/372...
#   Saved: SZ_patient_SZ_03_segment_043_scalogram_combined.png
#   Processing segment 45/313...
#   Saved: SZ_patient_SZ_01_segment_044_scalogram_combined.png
#   Processing segment 46/275...
#   Saved: SZ_patient_SZ_04_segment_045_scalogram_combined.png
#   Processing segment 47/392...
#   Saved: SZ_patient_SZ_02_segment_045_scalogram_combined.png
#   Processing segment 47/372...
#   Saved: SZ_patient_SZ_03_segment_044_scalogram_combined.png
#   Processing segment 46/313...
#   Saved: SZ_patient_SZ_01_segment_045_scalogram_combined.png
#   Processing segment 47/275...
#   Saved: SZ_patient_SZ_04_segment_046_scalogram_combined.png
#   Processing segment 48/392...
#   Saved: SZ_patient_SZ_02_segment_046_scalogram_combined.png
#   Processing segment 48/372...
#   Saved: SZ_patient_SZ_03_segment_045_scalogram_combined.png
#   Processing segment 47/313...
#   Saved: SZ_patient_SZ_01_segment_046_scalogram_combined.png
#   Processing segment 48/275...
#   Saved: SZ_patient_SZ_04_segment_047_scalogram_combined.png
#   Processing segment 49/392...
#   Saved: SZ_patient_SZ_02_segment_047_scalogram_combined.png
#   Processing segment 49/372...
#   Saved: SZ_patient_SZ_03_segment_046_scalogram_combined.png
#   Processing segment 48/313...
#   Saved: SZ_patient_SZ_01_segment_047_scalogram_combined.png
#   Processing segment 49/275...
#   Saved: SZ_patient_SZ_04_segment_048_scalogram_combined.png
#   Processing segment 50/392...
#   Saved: SZ_patient_SZ_02_segment_048_scalogram_combined.png
#   Processing segment 50/372...
#   Saved: SZ_patient_SZ_03_segment_047_scalogram_combined.png
#   Processing segment 49/313...
#   Saved: SZ_patient_SZ_01_segment_048_scalogram_combined.png
#   Processing segment 50/275...
#   Saved: SZ_patient_SZ_04_segment_049_scalogram_combined.png
#   Processing segment 51/392...
#   Saved: SZ_patient_SZ_02_segment_049_scalogram_combined.png
#   Processing segment 51/372...
#   Saved: SZ_patient_SZ_03_segment_048_scalogram_combined.png
#   Processing segment 50/313...
#   Saved: SZ_patient_SZ_01_segment_049_scalogram_combined.png
#   Processing segment 51/275...
#   Saved: SZ_patient_SZ_04_segment_050_scalogram_combined.png
#   Processing segment 52/392...
#   Saved: SZ_patient_SZ_02_segment_050_scalogram_combined.png
#   Processing segment 52/372...
#   Saved: SZ_patient_SZ_03_segment_049_scalogram_combined.png
#   Processing segment 51/313...
#   Saved: SZ_patient_SZ_01_segment_050_scalogram_combined.png
#   Processing segment 52/275...
#   Saved: SZ_patient_SZ_04_segment_051_scalogram_combined.png
#   Processing segment 53/392...
#   Saved: SZ_patient_SZ_02_segment_051_scalogram_combined.png
#   Processing segment 53/372...
#   Saved: SZ_patient_SZ_03_segment_050_scalogram_combined.png
#   Processing segment 52/313...
#   Saved: SZ_patient_SZ_01_segment_051_scalogram_combined.png
#   Processing segment 53/275...
#   Saved: SZ_patient_SZ_04_segment_052_scalogram_combined.png
#   Processing segment 54/392...
#   Saved: SZ_patient_SZ_02_segment_052_scalogram_combined.png
#   Processing segment 54/372...
#   Saved: SZ_patient_SZ_03_segment_051_scalogram_combined.png
#   Processing segment 53/313...
#   Saved: SZ_patient_SZ_01_segment_052_scalogram_combined.png
#   Processing segment 54/275...
#   Saved: SZ_patient_SZ_04_segment_053_scalogram_combined.png
#   Processing segment 55/392...
#   Saved: SZ_patient_SZ_02_segment_053_scalogram_combined.png
#   Processing segment 55/372...
#   Saved: SZ_patient_SZ_03_segment_052_scalogram_combined.png
#   Processing segment 54/313...
#   Saved: SZ_patient_SZ_01_segment_053_scalogram_combined.png
#   Processing segment 55/275...
#   Saved: SZ_patient_SZ_04_segment_054_scalogram_combined.png
#   Processing segment 56/392...
#   Saved: SZ_patient_SZ_02_segment_054_scalogram_combined.png
#   Processing segment 56/372...
#   Saved: SZ_patient_SZ_03_segment_053_scalogram_combined.png
#   Processing segment 55/313...
#   Saved: SZ_patient_SZ_01_segment_054_scalogram_combined.png
#   Processing segment 56/275...
#   Saved: SZ_patient_SZ_04_segment_055_scalogram_combined.png
#   Processing segment 57/392...
#   Saved: SZ_patient_SZ_02_segment_055_scalogram_combined.png
#   Processing segment 57/372...
#   Saved: SZ_patient_SZ_03_segment_054_scalogram_combined.png
#   Processing segment 56/313...
#   Saved: SZ_patient_SZ_01_segment_055_scalogram_combined.png
#   Processing segment 57/275...
#   Saved: SZ_patient_SZ_04_segment_056_scalogram_combined.png
#   Processing segment 58/392...
#   Saved: SZ_patient_SZ_02_segment_056_scalogram_combined.png
#   Processing segment 58/372...
#   Saved: SZ_patient_SZ_03_segment_055_scalogram_combined.png
#   Processing segment 57/313...
#   Saved: SZ_patient_SZ_01_segment_056_scalogram_combined.png  Saved: SZ_patient_SZ_04_segment_057_scalogram_combined.png
#   Processing segment 59/392...
#
#   Processing segment 58/275...
#   Saved: SZ_patient_SZ_02_segment_057_scalogram_combined.png
#   Processing segment 59/372...
#   Saved: SZ_patient_SZ_03_segment_056_scalogram_combined.png
#   Processing segment 58/313...
#   Saved: SZ_patient_SZ_04_segment_058_scalogram_combined.png
#   Processing segment 60/392...
#   Saved: SZ_patient_SZ_01_segment_057_scalogram_combined.png
#   Processing segment 59/275...
#   Saved: SZ_patient_SZ_02_segment_058_scalogram_combined.png
#   Processing segment 60/372...
#   Saved: SZ_patient_SZ_03_segment_057_scalogram_combined.png
#   Processing segment 59/313...
#   Saved: SZ_patient_SZ_04_segment_059_scalogram_combined.png
#   Processing segment 61/392...
#   Saved: SZ_patient_SZ_01_segment_058_scalogram_combined.png
#   Processing segment 60/275...
#   Saved: SZ_patient_SZ_02_segment_059_scalogram_combined.png
#   Processing segment 61/372...
#   Saved: SZ_patient_SZ_03_segment_058_scalogram_combined.png
#   Processing segment 60/313...
#   Saved: SZ_patient_SZ_04_segment_060_scalogram_combined.png
#   Processing segment 62/392...
#   Saved: SZ_patient_SZ_01_segment_059_scalogram_combined.png
#   Processing segment 61/275...
#   Saved: SZ_patient_SZ_02_segment_060_scalogram_combined.png
#   Processing segment 62/372...
#   Saved: SZ_patient_SZ_03_segment_059_scalogram_combined.png
#   Processing segment 61/313...
#   Saved: SZ_patient_SZ_04_segment_061_scalogram_combined.png
#   Processing segment 63/392...
#   Saved: SZ_patient_SZ_01_segment_060_scalogram_combined.png
#   Processing segment 62/275...
#   Saved: SZ_patient_SZ_02_segment_061_scalogram_combined.png
#   Processing segment 63/372...
#   Saved: SZ_patient_SZ_03_segment_060_scalogram_combined.png
#   Processing segment 62/313...
#   Saved: SZ_patient_SZ_04_segment_062_scalogram_combined.png
#   Processing segment 64/392...
#   Saved: SZ_patient_SZ_01_segment_061_scalogram_combined.png
#   Processing segment 63/275...
#   Saved: SZ_patient_SZ_02_segment_062_scalogram_combined.png
#   Processing segment 64/372...
#   Saved: SZ_patient_SZ_03_segment_061_scalogram_combined.png
#   Processing segment 63/313...
#   Saved: SZ_patient_SZ_04_segment_063_scalogram_combined.png
#   Processing segment 65/392...
#   Saved: SZ_patient_SZ_01_segment_062_scalogram_combined.png
#   Processing segment 64/275...
#   Saved: SZ_patient_SZ_02_segment_063_scalogram_combined.png
#   Processing segment 65/372...
#   Saved: SZ_patient_SZ_03_segment_062_scalogram_combined.png
#   Processing segment 64/313...
#   Saved: SZ_patient_SZ_04_segment_064_scalogram_combined.png
#   Processing segment 66/392...
#   Saved: SZ_patient_SZ_02_segment_064_scalogram_combined.png
#   Processing segment 66/372...
#   Saved: SZ_patient_SZ_01_segment_063_scalogram_combined.png
#   Processing segment 65/275...
#   Saved: SZ_patient_SZ_03_segment_063_scalogram_combined.png
#   Processing segment 65/313...
#   Saved: SZ_patient_SZ_04_segment_065_scalogram_combined.png
#   Processing segment 67/392...
#   Saved: SZ_patient_SZ_02_segment_065_scalogram_combined.png
#   Processing segment 67/372...
#   Saved: SZ_patient_SZ_01_segment_064_scalogram_combined.png
#   Processing segment 66/275...
#   Saved: SZ_patient_SZ_03_segment_064_scalogram_combined.png
#   Processing segment 66/313...
#   Saved: SZ_patient_SZ_04_segment_066_scalogram_combined.png
#   Processing segment 68/392...
#   Saved: SZ_patient_SZ_02_segment_066_scalogram_combined.png
#   Processing segment 68/372...
#   Saved: SZ_patient_SZ_01_segment_065_scalogram_combined.png
#   Processing segment 67/275...
#   Saved: SZ_patient_SZ_03_segment_065_scalogram_combined.png
#   Processing segment 67/313...
#   Saved: SZ_patient_SZ_04_segment_067_scalogram_combined.png
#   Processing segment 69/392...
#   Saved: SZ_patient_SZ_02_segment_067_scalogram_combined.png
#   Processing segment 69/372...
#   Saved: SZ_patient_SZ_01_segment_066_scalogram_combined.png
#   Processing segment 68/275...
#   Saved: SZ_patient_SZ_03_segment_066_scalogram_combined.png
#   Processing segment 68/313...
#   Saved: SZ_patient_SZ_04_segment_068_scalogram_combined.png
#   Processing segment 70/392...
#   Saved: SZ_patient_SZ_02_segment_068_scalogram_combined.png
#   Processing segment 70/372...
#   Saved: SZ_patient_SZ_01_segment_067_scalogram_combined.png
#   Processing segment 69/275...
#   Saved: SZ_patient_SZ_03_segment_067_scalogram_combined.png
#   Processing segment 69/313...
#   Saved: SZ_patient_SZ_04_segment_069_scalogram_combined.png
#   Processing segment 71/392...
#   Saved: SZ_patient_SZ_02_segment_069_scalogram_combined.png
#   Processing segment 71/372...
#   Saved: SZ_patient_SZ_01_segment_068_scalogram_combined.png
#   Processing segment 70/275...
#   Saved: SZ_patient_SZ_03_segment_068_scalogram_combined.png
#   Processing segment 70/313...
#   Saved: SZ_patient_SZ_04_segment_070_scalogram_combined.png
#   Processing segment 72/392...
#   Saved: SZ_patient_SZ_02_segment_070_scalogram_combined.png
#   Processing segment 72/372...
#   Saved: SZ_patient_SZ_01_segment_069_scalogram_combined.png
#   Processing segment 71/275...
#   Saved: SZ_patient_SZ_03_segment_069_scalogram_combined.png
#   Processing segment 71/313...
#   Saved: SZ_patient_SZ_04_segment_071_scalogram_combined.png
#   Processing segment 73/392...
#   Saved: SZ_patient_SZ_02_segment_071_scalogram_combined.png
#   Processing segment 73/372...
#   Saved: SZ_patient_SZ_01_segment_070_scalogram_combined.png
#   Processing segment 72/275...
#   Saved: SZ_patient_SZ_03_segment_070_scalogram_combined.png
#   Processing segment 72/313...
#   Saved: SZ_patient_SZ_04_segment_072_scalogram_combined.png
#   Processing segment 74/392...
#   Saved: SZ_patient_SZ_02_segment_072_scalogram_combined.png
#   Processing segment 74/372...
#   Saved: SZ_patient_SZ_01_segment_071_scalogram_combined.png
#   Processing segment 73/275...
#   Saved: SZ_patient_SZ_04_segment_073_scalogram_combined.png
#   Processing segment 75/392...
#   Saved: SZ_patient_SZ_03_segment_071_scalogram_combined.png
#   Processing segment 73/313...
#   Saved: SZ_patient_SZ_02_segment_073_scalogram_combined.png
#   Processing segment 75/372...
#   Saved: SZ_patient_SZ_01_segment_072_scalogram_combined.png
#   Processing segment 74/275...
#   Saved: SZ_patient_SZ_04_segment_074_scalogram_combined.png
#   Processing segment 76/392...
#   Saved: SZ_patient_SZ_03_segment_072_scalogram_combined.png
#   Processing segment 74/313...
#   Saved: SZ_patient_SZ_02_segment_074_scalogram_combined.png
#   Processing segment 76/372...
#   Saved: SZ_patient_SZ_01_segment_073_scalogram_combined.png
#   Processing segment 75/275...
#   Saved: SZ_patient_SZ_04_segment_075_scalogram_combined.png
#   Processing segment 77/392...
#   Saved: SZ_patient_SZ_03_segment_073_scalogram_combined.png
#   Processing segment 75/313...
#   Saved: SZ_patient_SZ_02_segment_075_scalogram_combined.png
#   Processing segment 77/372...
#   Saved: SZ_patient_SZ_01_segment_074_scalogram_combined.png
#   Processing segment 76/275...
#   Saved: SZ_patient_SZ_04_segment_076_scalogram_combined.png
#   Processing segment 78/392...
#   Saved: SZ_patient_SZ_03_segment_074_scalogram_combined.png
#   Processing segment 76/313...
#   Saved: SZ_patient_SZ_02_segment_076_scalogram_combined.png
#   Processing segment 78/372...
#   Saved: SZ_patient_SZ_01_segment_075_scalogram_combined.png
#   Processing segment 77/275...
#   Saved: SZ_patient_SZ_04_segment_077_scalogram_combined.png
#   Processing segment 79/392...
#   Saved: SZ_patient_SZ_03_segment_075_scalogram_combined.png
#   Processing segment 77/313...
#   Saved: SZ_patient_SZ_02_segment_077_scalogram_combined.png
#   Processing segment 79/372...
#   Saved: SZ_patient_SZ_01_segment_076_scalogram_combined.png
#   Processing segment 78/275...
#   Saved: SZ_patient_SZ_04_segment_078_scalogram_combined.png
#   Processing segment 80/392...
#   Saved: SZ_patient_SZ_02_segment_078_scalogram_combined.png
#   Processing segment 80/372...
#   Saved: SZ_patient_SZ_03_segment_076_scalogram_combined.png
#   Processing segment 78/313...
#   Saved: SZ_patient_SZ_01_segment_077_scalogram_combined.png
#   Processing segment 79/275...
#   Saved: SZ_patient_SZ_04_segment_079_scalogram_combined.png
#   Processing segment 81/392...
#   Saved: SZ_patient_SZ_02_segment_079_scalogram_combined.png
#   Processing segment 81/372...
#   Saved: SZ_patient_SZ_03_segment_077_scalogram_combined.png
#   Processing segment 79/313...
#   Saved: SZ_patient_SZ_01_segment_078_scalogram_combined.png
#   Processing segment 80/275...
#   Saved: SZ_patient_SZ_04_segment_080_scalogram_combined.png
#   Processing segment 82/392...
#   Saved: SZ_patient_SZ_02_segment_080_scalogram_combined.png
#   Processing segment 82/372...
#   Saved: SZ_patient_SZ_03_segment_078_scalogram_combined.png
#   Processing segment 80/313...
#   Saved: SZ_patient_SZ_01_segment_079_scalogram_combined.png
#   Processing segment 81/275...
#   Saved: SZ_patient_SZ_04_segment_081_scalogram_combined.png
#   Processing segment 83/392...
#   Saved: SZ_patient_SZ_02_segment_081_scalogram_combined.png
#   Processing segment 83/372...
#   Saved: SZ_patient_SZ_03_segment_079_scalogram_combined.png
#   Processing segment 81/313...
#   Saved: SZ_patient_SZ_01_segment_080_scalogram_combined.png
#   Processing segment 82/275...
#   Saved: SZ_patient_SZ_04_segment_082_scalogram_combined.png
#   Processing segment 84/392...
#   Saved: SZ_patient_SZ_02_segment_082_scalogram_combined.png
#   Processing segment 84/372...
#   Saved: SZ_patient_SZ_03_segment_080_scalogram_combined.png
#   Processing segment 82/313...
#   Saved: SZ_patient_SZ_01_segment_081_scalogram_combined.png
#   Processing segment 83/275...
#   Saved: SZ_patient_SZ_04_segment_083_scalogram_combined.png
#   Processing segment 85/392...
#   Saved: SZ_patient_SZ_02_segment_083_scalogram_combined.png
#   Processing segment 85/372...
#   Saved: SZ_patient_SZ_03_segment_081_scalogram_combined.png
#   Processing segment 83/313...
#   Saved: SZ_patient_SZ_01_segment_082_scalogram_combined.png
#   Processing segment 84/275...
#   Saved: SZ_patient_SZ_04_segment_084_scalogram_combined.png
#   Processing segment 86/392...
#   Saved: SZ_patient_SZ_02_segment_084_scalogram_combined.png
#   Processing segment 86/372...
#   Saved: SZ_patient_SZ_03_segment_082_scalogram_combined.png
#   Processing segment 84/313...
#   Saved: SZ_patient_SZ_01_segment_083_scalogram_combined.png
#   Processing segment 85/275...
#   Saved: SZ_patient_SZ_04_segment_085_scalogram_combined.png
#   Processing segment 87/392...
#   Saved: SZ_patient_SZ_02_segment_085_scalogram_combined.png
#   Processing segment 87/372...
#   Saved: SZ_patient_SZ_03_segment_083_scalogram_combined.png
#   Processing segment 85/313...
#   Saved: SZ_patient_SZ_01_segment_084_scalogram_combined.png
#   Processing segment 86/275...
#   Saved: SZ_patient_SZ_04_segment_086_scalogram_combined.png
#   Processing segment 88/392...
#   Saved: SZ_patient_SZ_02_segment_086_scalogram_combined.png
#   Processing segment 88/372...
#   Saved: SZ_patient_SZ_03_segment_084_scalogram_combined.png
#   Processing segment 86/313...
#   Saved: SZ_patient_SZ_01_segment_085_scalogram_combined.png
#   Processing segment 87/275...
#   Saved: SZ_patient_SZ_04_segment_087_scalogram_combined.png
#   Processing segment 89/392...
#   Saved: SZ_patient_SZ_02_segment_087_scalogram_combined.png
#   Processing segment 89/372...
#   Saved: SZ_patient_SZ_03_segment_085_scalogram_combined.png
#   Processing segment 87/313...
#   Saved: SZ_patient_SZ_01_segment_086_scalogram_combined.png
#   Processing segment 88/275...
#   Saved: SZ_patient_SZ_04_segment_088_scalogram_combined.png
#   Processing segment 90/392...
#   Saved: SZ_patient_SZ_02_segment_088_scalogram_combined.png
#   Processing segment 90/372...
#   Saved: SZ_patient_SZ_03_segment_086_scalogram_combined.png
#   Processing segment 88/313...
#   Saved: SZ_patient_SZ_01_segment_087_scalogram_combined.png
#   Processing segment 89/275...
#   Saved: SZ_patient_SZ_04_segment_089_scalogram_combined.png
#   Processing segment 91/392...
#   Saved: SZ_patient_SZ_02_segment_089_scalogram_combined.png
#   Processing segment 91/372...
#   Saved: SZ_patient_SZ_03_segment_087_scalogram_combined.png
#   Processing segment 89/313...
#   Saved: SZ_patient_SZ_01_segment_088_scalogram_combined.png
#   Processing segment 90/275...
#   Saved: SZ_patient_SZ_04_segment_090_scalogram_combined.png
#   Processing segment 92/392...
#   Saved: SZ_patient_SZ_02_segment_090_scalogram_combined.png
#   Processing segment 92/372...
#   Saved: SZ_patient_SZ_03_segment_088_scalogram_combined.png
#   Processing segment 90/313...
#   Saved: SZ_patient_SZ_01_segment_089_scalogram_combined.png
#   Processing segment 91/275...
#   Saved: SZ_patient_SZ_04_segment_091_scalogram_combined.png
#   Processing segment 93/392...
#   Saved: SZ_patient_SZ_02_segment_091_scalogram_combined.png
#   Processing segment 93/372...
#   Saved: SZ_patient_SZ_03_segment_089_scalogram_combined.png
#   Processing segment 91/313...
#   Saved: SZ_patient_SZ_01_segment_090_scalogram_combined.png
#   Processing segment 92/275...
#   Saved: SZ_patient_SZ_04_segment_092_scalogram_combined.png
#   Processing segment 94/392...
#   Saved: SZ_patient_SZ_02_segment_092_scalogram_combined.png
#   Processing segment 94/372...
#   Saved: SZ_patient_SZ_03_segment_090_scalogram_combined.png
#   Processing segment 92/313...
#   Saved: SZ_patient_SZ_01_segment_091_scalogram_combined.png
#   Processing segment 93/275...
#   Saved: SZ_patient_SZ_04_segment_093_scalogram_combined.png
#   Processing segment 95/392...
#   Saved: SZ_patient_SZ_02_segment_093_scalogram_combined.png
#   Processing segment 95/372...
#   Saved: SZ_patient_SZ_03_segment_091_scalogram_combined.png
#   Processing segment 93/313...
#   Saved: SZ_patient_SZ_01_segment_092_scalogram_combined.png
#   Processing segment 94/275...
#   Saved: SZ_patient_SZ_04_segment_094_scalogram_combined.png
#   Processing segment 96/392...
#   Saved: SZ_patient_SZ_02_segment_094_scalogram_combined.png
#   Processing segment 96/372...
#   Saved: SZ_patient_SZ_03_segment_092_scalogram_combined.png
#   Processing segment 94/313...
#   Saved: SZ_patient_SZ_01_segment_093_scalogram_combined.png
#   Processing segment 95/275...
#   Saved: SZ_patient_SZ_04_segment_095_scalogram_combined.png
#   Processing segment 97/392...
#   Saved: SZ_patient_SZ_02_segment_095_scalogram_combined.png
#   Processing segment 97/372...
#   Saved: SZ_patient_SZ_03_segment_093_scalogram_combined.png
#   Processing segment 95/313...
#   Saved: SZ_patient_SZ_01_segment_094_scalogram_combined.png
#   Processing segment 96/275...
#   Saved: SZ_patient_SZ_04_segment_096_scalogram_combined.png
#   Processing segment 98/392...
#   Saved: SZ_patient_SZ_02_segment_096_scalogram_combined.png
#   Processing segment 98/372...
#   Saved: SZ_patient_SZ_03_segment_094_scalogram_combined.png
#   Processing segment 96/313...
#   Saved: SZ_patient_SZ_01_segment_095_scalogram_combined.png
#   Processing segment 97/275...
#   Saved: SZ_patient_SZ_04_segment_097_scalogram_combined.png
#   Processing segment 99/392...
#   Saved: SZ_patient_SZ_02_segment_097_scalogram_combined.png
#   Processing segment 99/372...
#   Saved: SZ_patient_SZ_03_segment_095_scalogram_combined.png
#   Processing segment 97/313...
#   Saved: SZ_patient_SZ_01_segment_096_scalogram_combined.png
#   Processing segment 98/275...
#   Saved: SZ_patient_SZ_04_segment_098_scalogram_combined.png
#   Processing segment 100/392...
#   Saved: SZ_patient_SZ_02_segment_098_scalogram_combined.png
#   Processing segment 100/372...
#   Saved: SZ_patient_SZ_03_segment_096_scalogram_combined.png
#   Processing segment 98/313...
#   Saved: SZ_patient_SZ_01_segment_097_scalogram_combined.png
#   Processing segment 99/275...
#   Saved: SZ_patient_SZ_04_segment_099_scalogram_combined.png
#   Processing segment 101/392...
#   Saved: SZ_patient_SZ_02_segment_099_scalogram_combined.png
#   Processing segment 101/372...
#   Saved: SZ_patient_SZ_01_segment_098_scalogram_combined.png
#   Processing segment 100/275...
#   Saved: SZ_patient_SZ_03_segment_097_scalogram_combined.png
#   Processing segment 99/313...
#   Saved: SZ_patient_SZ_04_segment_100_scalogram_combined.png
#   Processing segment 102/392...
#   Saved: SZ_patient_SZ_02_segment_100_scalogram_combined.png
#   Processing segment 102/372...
#   Saved: SZ_patient_SZ_01_segment_099_scalogram_combined.png
#   Processing segment 101/275...
#   Saved: SZ_patient_SZ_03_segment_098_scalogram_combined.png
#   Processing segment 100/313...
#   Saved: SZ_patient_SZ_04_segment_101_scalogram_combined.png
#   Processing segment 103/392...
#   Saved: SZ_patient_SZ_02_segment_101_scalogram_combined.png
#   Processing segment 103/372...
#   Saved: SZ_patient_SZ_01_segment_100_scalogram_combined.png
#   Processing segment 102/275...
#   Saved: SZ_patient_SZ_03_segment_099_scalogram_combined.png
#   Processing segment 101/313...
#   Saved: SZ_patient_SZ_04_segment_102_scalogram_combined.png
#   Processing segment 104/392...
#   Saved: SZ_patient_SZ_02_segment_102_scalogram_combined.png
#   Processing segment 104/372...
#   Saved: SZ_patient_SZ_01_segment_101_scalogram_combined.png
#   Processing segment 103/275...
#   Saved: SZ_patient_SZ_03_segment_100_scalogram_combined.png
#   Processing segment 102/313...
#   Saved: SZ_patient_SZ_04_segment_103_scalogram_combined.png
#   Processing segment 105/392...
#   Saved: SZ_patient_SZ_02_segment_103_scalogram_combined.png
#   Processing segment 105/372...
#   Saved: SZ_patient_SZ_01_segment_102_scalogram_combined.png
#   Processing segment 104/275...
#   Saved: SZ_patient_SZ_03_segment_101_scalogram_combined.png
#   Processing segment 103/313...
#   Saved: SZ_patient_SZ_04_segment_104_scalogram_combined.png
#   Processing segment 106/392...
#   Saved: SZ_patient_SZ_02_segment_104_scalogram_combined.png
#   Processing segment 106/372...
#   Saved: SZ_patient_SZ_01_segment_103_scalogram_combined.png
#   Processing segment 105/275...
#   Saved: SZ_patient_SZ_03_segment_102_scalogram_combined.png
#   Processing segment 104/313...
#   Saved: SZ_patient_SZ_04_segment_105_scalogram_combined.png
#   Processing segment 107/392...
#   Saved: SZ_patient_SZ_02_segment_105_scalogram_combined.png
#   Processing segment 107/372...
#   Saved: SZ_patient_SZ_01_segment_104_scalogram_combined.png
#   Processing segment 106/275...
#   Saved: SZ_patient_SZ_03_segment_103_scalogram_combined.png
#   Processing segment 105/313...
#   Saved: SZ_patient_SZ_04_segment_106_scalogram_combined.png
#   Processing segment 108/392...
#   Saved: SZ_patient_SZ_02_segment_106_scalogram_combined.png
#   Processing segment 108/372...
#   Saved: SZ_patient_SZ_01_segment_105_scalogram_combined.png
#   Processing segment 107/275...
#   Saved: SZ_patient_SZ_03_segment_104_scalogram_combined.png
#   Processing segment 106/313...
#   Saved: SZ_patient_SZ_04_segment_107_scalogram_combined.png
#   Processing segment 109/392...
#   Saved: SZ_patient_SZ_02_segment_107_scalogram_combined.png
#   Processing segment 109/372...
#   Saved: SZ_patient_SZ_01_segment_106_scalogram_combined.png
#   Processing segment 108/275...
#   Saved: SZ_patient_SZ_03_segment_105_scalogram_combined.png
#   Processing segment 107/313...
#   Saved: SZ_patient_SZ_04_segment_108_scalogram_combined.png
#   Processing segment 110/392...
#   Saved: SZ_patient_SZ_02_segment_108_scalogram_combined.png
#   Processing segment 110/372...
#   Saved: SZ_patient_SZ_01_segment_107_scalogram_combined.png
#   Processing segment 109/275...
#   Saved: SZ_patient_SZ_04_segment_109_scalogram_combined.png
#   Processing segment 111/392...
#   Saved: SZ_patient_SZ_03_segment_106_scalogram_combined.png
#   Processing segment 108/313...
#   Saved: SZ_patient_SZ_02_segment_109_scalogram_combined.png
#   Processing segment 111/372...
#   Saved: SZ_patient_SZ_01_segment_108_scalogram_combined.png
#   Processing segment 110/275...
#   Saved: SZ_patient_SZ_04_segment_110_scalogram_combined.png
#   Processing segment 112/392...
#   Saved: SZ_patient_SZ_03_segment_107_scalogram_combined.png
#   Processing segment 109/313...
#   Saved: SZ_patient_SZ_02_segment_110_scalogram_combined.png
#   Processing segment 112/372...
#   Saved: SZ_patient_SZ_01_segment_109_scalogram_combined.png
#   Processing segment 111/275...
#   Saved: SZ_patient_SZ_04_segment_111_scalogram_combined.png
#   Processing segment 113/392...
#   Saved: SZ_patient_SZ_03_segment_108_scalogram_combined.png
#   Processing segment 110/313...
#   Saved: SZ_patient_SZ_02_segment_111_scalogram_combined.png
#   Processing segment 113/372...
#   Saved: SZ_patient_SZ_01_segment_110_scalogram_combined.png
#   Processing segment 112/275...
#   Saved: SZ_patient_SZ_04_segment_112_scalogram_combined.png
#   Processing segment 114/392...
#   Saved: SZ_patient_SZ_03_segment_109_scalogram_combined.png
#   Processing segment 111/313...
#   Saved: SZ_patient_SZ_02_segment_112_scalogram_combined.png
#   Processing segment 114/372...
#   Saved: SZ_patient_SZ_01_segment_111_scalogram_combined.png
#   Processing segment 113/275...
#   Saved: SZ_patient_SZ_04_segment_113_scalogram_combined.png
#   Processing segment 115/392...
#   Saved: SZ_patient_SZ_03_segment_110_scalogram_combined.png
#   Processing segment 112/313...
#   Saved: SZ_patient_SZ_02_segment_113_scalogram_combined.png
#   Processing segment 115/372...
#   Saved: SZ_patient_SZ_01_segment_112_scalogram_combined.png
#   Processing segment 114/275...
#   Saved: SZ_patient_SZ_04_segment_114_scalogram_combined.png
#   Processing segment 116/392...
#   Saved: SZ_patient_SZ_03_segment_111_scalogram_combined.png
#   Processing segment 113/313...
#   Saved: SZ_patient_SZ_02_segment_114_scalogram_combined.png
#   Processing segment 116/372...
#   Saved: SZ_patient_SZ_04_segment_115_scalogram_combined.png
#   Processing segment 117/392...
#   Saved: SZ_patient_SZ_01_segment_113_scalogram_combined.png
#   Processing segment 115/275...
#   Saved: SZ_patient_SZ_03_segment_112_scalogram_combined.png
#   Processing segment 114/313...
#   Saved: SZ_patient_SZ_02_segment_115_scalogram_combined.png
#   Processing segment 117/372...
#   Saved: SZ_patient_SZ_04_segment_116_scalogram_combined.png
#   Processing segment 118/392...
#   Saved: SZ_patient_SZ_01_segment_114_scalogram_combined.png
#   Processing segment 116/275...
#   Saved: SZ_patient_SZ_03_segment_113_scalogram_combined.png
#   Processing segment 115/313...
#   Saved: SZ_patient_SZ_02_segment_116_scalogram_combined.png
#   Processing segment 118/372...
#   Saved: SZ_patient_SZ_04_segment_117_scalogram_combined.png
#   Processing segment 119/392...
#   Saved: SZ_patient_SZ_01_segment_115_scalogram_combined.png
#   Processing segment 117/275...
#   Saved: SZ_patient_SZ_03_segment_114_scalogram_combined.png
#   Processing segment 116/313...
#   Saved: SZ_patient_SZ_02_segment_117_scalogram_combined.png
#   Processing segment 119/372...
#   Saved: SZ_patient_SZ_04_segment_118_scalogram_combined.png
#   Processing segment 120/392...
#   Saved: SZ_patient_SZ_01_segment_116_scalogram_combined.png
#   Processing segment 118/275...
#   Saved: SZ_patient_SZ_02_segment_118_scalogram_combined.png
#   Processing segment 120/372...
#   Saved: SZ_patient_SZ_03_segment_115_scalogram_combined.png
#   Processing segment 117/313...
#   Saved: SZ_patient_SZ_04_segment_119_scalogram_combined.png
#   Processing segment 121/392...
#   Saved: SZ_patient_SZ_01_segment_117_scalogram_combined.png
#   Processing segment 119/275...
#   Saved: SZ_patient_SZ_02_segment_119_scalogram_combined.png
#   Processing segment 121/372...
#   Saved: SZ_patient_SZ_03_segment_116_scalogram_combined.png
#   Processing segment 118/313...
#   Saved: SZ_patient_SZ_04_segment_120_scalogram_combined.png
#   Processing segment 122/392...
#   Saved: SZ_patient_SZ_01_segment_118_scalogram_combined.png
#   Processing segment 120/275...
#   Saved: SZ_patient_SZ_02_segment_120_scalogram_combined.png
#   Processing segment 122/372...
#   Saved: SZ_patient_SZ_03_segment_117_scalogram_combined.png
#   Processing segment 119/313...
#   Saved: SZ_patient_SZ_04_segment_121_scalogram_combined.png
#   Processing segment 123/392...
#   Saved: SZ_patient_SZ_01_segment_119_scalogram_combined.png
#   Processing segment 121/275...
#   Saved: SZ_patient_SZ_02_segment_121_scalogram_combined.png
#   Processing segment 123/372...
#   Saved: SZ_patient_SZ_03_segment_118_scalogram_combined.png
#   Processing segment 120/313...
#   Saved: SZ_patient_SZ_04_segment_122_scalogram_combined.png
#   Processing segment 124/392...
#   Saved: SZ_patient_SZ_01_segment_120_scalogram_combined.png
#   Processing segment 122/275...
#   Saved: SZ_patient_SZ_02_segment_122_scalogram_combined.png
#   Processing segment 124/372...
#   Saved: SZ_patient_SZ_03_segment_119_scalogram_combined.png
#   Processing segment 121/313...
#   Saved: SZ_patient_SZ_04_segment_123_scalogram_combined.png
#   Processing segment 125/392...
#   Saved: SZ_patient_SZ_01_segment_121_scalogram_combined.png
#   Processing segment 123/275...
#   Saved: SZ_patient_SZ_02_segment_123_scalogram_combined.png
#   Processing segment 125/372...
#   Saved: SZ_patient_SZ_03_segment_120_scalogram_combined.png
#   Processing segment 122/313...
#   Saved: SZ_patient_SZ_04_segment_124_scalogram_combined.png
#   Processing segment 126/392...
#   Saved: SZ_patient_SZ_01_segment_122_scalogram_combined.png
#   Processing segment 124/275...
#   Saved: SZ_patient_SZ_02_segment_124_scalogram_combined.png
#   Processing segment 126/372...
#   Saved: SZ_patient_SZ_03_segment_121_scalogram_combined.png
#   Processing segment 123/313...
#   Saved: SZ_patient_SZ_04_segment_125_scalogram_combined.png
#   Processing segment 127/392...
#   Saved: SZ_patient_SZ_01_segment_123_scalogram_combined.png
#   Processing segment 125/275...
#   Saved: SZ_patient_SZ_02_segment_125_scalogram_combined.png
#   Processing segment 127/372...
#   Saved: SZ_patient_SZ_03_segment_122_scalogram_combined.png
#   Processing segment 124/313...
#   Saved: SZ_patient_SZ_04_segment_126_scalogram_combined.png
#   Processing segment 128/392...
#   Saved: SZ_patient_SZ_01_segment_124_scalogram_combined.png
#   Processing segment 126/275...
#   Saved: SZ_patient_SZ_02_segment_126_scalogram_combined.png
#   Processing segment 128/372...
#   Saved: SZ_patient_SZ_03_segment_123_scalogram_combined.png
#   Processing segment 125/313...
#   Saved: SZ_patient_SZ_04_segment_127_scalogram_combined.png
#   Processing segment 129/392...
#   Saved: SZ_patient_SZ_01_segment_125_scalogram_combined.png
#   Processing segment 127/275...
#   Saved: SZ_patient_SZ_02_segment_127_scalogram_combined.png
#   Processing segment 129/372...
# ...
#   Processing segment 354/385...
#   Saved: SZ_patient_SZ_12_segment_119_scalogram_combined.png
#   Processing segment 121/353...
#   Saved: SZ_patient_SZ_11_segment_242_scalogram_combined.png
#   Processing segment 244/442...
#   Saved: SZ_patient_SZ_13_segment_076_scalogram_combined.png
#   Processing segment 78/369...
#   Saved: SZ_patient_SZ_09_segment_353_scalogram_combined.png
#   Processing segment 355/385...
#   Saved: SZ_patient_SZ_12_segment_120_scalogram_combined.png
#   Processing segment 122/353...
#   Saved: SZ_patient_SZ_11_segment_243_scalogram_combined.png
#   Processing segment 245/442...
#   Saved: SZ_patient_SZ_13_segment_077_scalogram_combined.png
#   Processing segment 79/369...
#   Saved: SZ_patient_SZ_09_segment_354_scalogram_combined.png
#   Processing segment 356/385...
#   Saved: SZ_patient_SZ_12_segment_121_scalogram_combined.png
#   Processing segment 123/353...
#   Saved: SZ_patient_SZ_11_segment_244_scalogram_combined.png
#   Processing segment 246/442...
#   Saved: SZ_patient_SZ_13_segment_078_scalogram_combined.png
#   Processing segment 80/369...
#   Saved: SZ_patient_SZ_09_segment_355_scalogram_combined.png
#   Processing segment 357/385...
#   Saved: SZ_patient_SZ_12_segment_122_scalogram_combined.png
#   Processing segment 124/353...
#   Saved: SZ_patient_SZ_11_segment_245_scalogram_combined.png
#   Processing segment 247/442...
#   Saved: SZ_patient_SZ_13_segment_079_scalogram_combined.png
#   Processing segment 81/369...
#   Saved: SZ_patient_SZ_09_segment_356_scalogram_combined.png
#   Processing segment 358/385...
#   Saved: SZ_patient_SZ_12_segment_123_scalogram_combined.png
#   Processing segment 125/353...
#   Saved: SZ_patient_SZ_11_segment_246_scalogram_combined.png
#   Processing segment 248/442...
#   Saved: SZ_patient_SZ_13_segment_080_scalogram_combined.png
#   Processing segment 82/369...
#   Saved: SZ_patient_SZ_09_segment_357_scalogram_combined.png
#   Processing segment 359/385...
#   Saved: SZ_patient_SZ_12_segment_124_scalogram_combined.png
#   Processing segment 126/353...
#   Saved: SZ_patient_SZ_11_segment_247_scalogram_combined.png
#   Processing segment 249/442...
#   Saved: SZ_patient_SZ_13_segment_081_scalogram_combined.png
#   Processing segment 83/369...
#   Saved: SZ_patient_SZ_09_segment_358_scalogram_combined.png
#   Processing segment 360/385...
#   Saved: SZ_patient_SZ_12_segment_125_scalogram_combined.png
#   Processing segment 127/353...
#   Saved: SZ_patient_SZ_11_segment_248_scalogram_combined.png
#   Processing segment 250/442...
#   Saved: SZ_patient_SZ_13_segment_082_scalogram_combined.png
#   Processing segment 84/369...
#   Saved: SZ_patient_SZ_09_segment_359_scalogram_combined.png
#   Processing segment 361/385...
#   Saved: SZ_patient_SZ_12_segment_126_scalogram_combined.png
#   Processing segment 128/353...
#   Saved: SZ_patient_SZ_11_segment_249_scalogram_combined.png
#   Processing segment 251/442...
#   Saved: SZ_patient_SZ_13_segment_083_scalogram_combined.png
#   Processing segment 85/369...
#   Saved: SZ_patient_SZ_09_segment_360_scalogram_combined.png
#   Processing segment 362/385...
#   Saved: SZ_patient_SZ_12_segment_127_scalogram_combined.png
#   Processing segment 129/353...
#   Saved: SZ_patient_SZ_11_segment_250_scalogram_combined.png
#   Processing segment 252/442...
#   Saved: SZ_patient_SZ_13_segment_084_scalogram_combined.png
#   Processing segment 86/369...
#   Saved: SZ_patient_SZ_09_segment_361_scalogram_combined.png
#   Processing segment 363/385...
#   Saved: SZ_patient_SZ_12_segment_128_scalogram_combined.png
#   Processing segment 130/353...
#   Saved: SZ_patient_SZ_11_segment_251_scalogram_combined.png
#   Processing segment 253/442...
#   Saved: SZ_patient_SZ_13_segment_085_scalogram_combined.png
#   Processing segment 87/369...
#   Saved: SZ_patient_SZ_09_segment_362_scalogram_combined.png
#   Processing segment 364/385...
#   Saved: SZ_patient_SZ_12_segment_129_scalogram_combined.png
#   Processing segment 131/353...
#   Saved: SZ_patient_SZ_11_segment_252_scalogram_combined.png
#   Processing segment 254/442...
#   Saved: SZ_patient_SZ_13_segment_086_scalogram_combined.png
#   Processing segment 88/369...
#   Saved: SZ_patient_SZ_09_segment_363_scalogram_combined.png
#   Processing segment 365/385...
#   Saved: SZ_patient_SZ_12_segment_130_scalogram_combined.png
#   Processing segment 132/353...
#   Saved: SZ_patient_SZ_11_segment_253_scalogram_combined.png
#   Processing segment 255/442...
#   Saved: SZ_patient_SZ_13_segment_087_scalogram_combined.png
#   Processing segment 89/369...
#   Saved: SZ_patient_SZ_12_segment_131_scalogram_combined.png
#   Processing segment 133/353...
#   Saved: SZ_patient_SZ_09_segment_364_scalogram_combined.png
#   Processing segment 366/385...
#   Saved: SZ_patient_SZ_11_segment_254_scalogram_combined.png
#   Processing segment 256/442...
#   Saved: SZ_patient_SZ_13_segment_088_scalogram_combined.png
#   Processing segment 90/369...
#   Saved: SZ_patient_SZ_12_segment_132_scalogram_combined.png
#   Processing segment 134/353...
#   Saved: SZ_patient_SZ_09_segment_365_scalogram_combined.png
#   Processing segment 367/385...
#   Saved: SZ_patient_SZ_11_segment_255_scalogram_combined.png
#   Processing segment 257/442...
#   Saved: SZ_patient_SZ_13_segment_089_scalogram_combined.png
#   Processing segment 91/369...
#   Saved: SZ_patient_SZ_12_segment_133_scalogram_combined.png
#   Processing segment 135/353...
#   Saved: SZ_patient_SZ_09_segment_366_scalogram_combined.png
#   Processing segment 368/385...
#   Saved: SZ_patient_SZ_11_segment_256_scalogram_combined.png
#   Processing segment 258/442...
#   Saved: SZ_patient_SZ_13_segment_090_scalogram_combined.png
#   Processing segment 92/369...
#   Saved: SZ_patient_SZ_12_segment_134_scalogram_combined.png
#   Processing segment 136/353...
#   Saved: SZ_patient_SZ_09_segment_367_scalogram_combined.png
#   Processing segment 369/385...
#   Saved: SZ_patient_SZ_11_segment_257_scalogram_combined.png
#   Processing segment 259/442...
#   Saved: SZ_patient_SZ_13_segment_091_scalogram_combined.png
#   Processing segment 93/369...
#   Saved: SZ_patient_SZ_12_segment_135_scalogram_combined.png
#   Processing segment 137/353...
#   Saved: SZ_patient_SZ_09_segment_368_scalogram_combined.png
#   Processing segment 370/385...
#   Saved: SZ_patient_SZ_11_segment_258_scalogram_combined.png
#   Processing segment 260/442...
#   Saved: SZ_patient_SZ_13_segment_092_scalogram_combined.png
#   Processing segment 94/369...
#   Saved: SZ_patient_SZ_12_segment_136_scalogram_combined.png
#   Processing segment 138/353...
#   Saved: SZ_patient_SZ_09_segment_369_scalogram_combined.png
#   Processing segment 371/385...
#   Saved: SZ_patient_SZ_11_segment_259_scalogram_combined.png
#   Processing segment 261/442...
#   Saved: SZ_patient_SZ_13_segment_093_scalogram_combined.png
#   Processing segment 95/369...
#   Saved: SZ_patient_SZ_12_segment_137_scalogram_combined.png
#   Processing segment 139/353...
#   Saved: SZ_patient_SZ_09_segment_370_scalogram_combined.png
#   Processing segment 372/385...
#   Saved: SZ_patient_SZ_11_segment_260_scalogram_combined.png
#   Processing segment 262/442...
#   Saved: SZ_patient_SZ_13_segment_094_scalogram_combined.png
#   Processing segment 96/369...
#   Saved: SZ_patient_SZ_12_segment_138_scalogram_combined.png
#   Processing segment 140/353...
#   Saved: SZ_patient_SZ_09_segment_371_scalogram_combined.png
#   Processing segment 373/385...
#   Saved: SZ_patient_SZ_11_segment_261_scalogram_combined.png
#   Processing segment 263/442...
#   Saved: SZ_patient_SZ_13_segment_095_scalogram_combined.png
#   Processing segment 97/369...
#   Saved: SZ_patient_SZ_12_segment_139_scalogram_combined.png
#   Processing segment 141/353...
#   Saved: SZ_patient_SZ_09_segment_372_scalogram_combined.png
#   Processing segment 374/385...
#   Saved: SZ_patient_SZ_11_segment_262_scalogram_combined.png
#   Processing segment 264/442...
#   Saved: SZ_patient_SZ_12_segment_140_scalogram_combined.png
#   Processing segment 142/353...
#   Saved: SZ_patient_SZ_13_segment_096_scalogram_combined.png
#   Processing segment 98/369...
#   Saved: SZ_patient_SZ_11_segment_263_scalogram_combined.png
#   Processing segment 265/442...
#   Saved: SZ_patient_SZ_09_segment_373_scalogram_combined.png
#   Processing segment 375/385...
#   Saved: SZ_patient_SZ_12_segment_141_scalogram_combined.png
#   Processing segment 143/353...
#   Saved: SZ_patient_SZ_13_segment_097_scalogram_combined.png
#   Processing segment 99/369...
#   Saved: SZ_patient_SZ_11_segment_264_scalogram_combined.png
#   Processing segment 266/442...
#   Saved: SZ_patient_SZ_09_segment_374_scalogram_combined.png
#   Processing segment 376/385...
#   Saved: SZ_patient_SZ_12_segment_142_scalogram_combined.png
#   Processing segment 144/353...
#   Saved: SZ_patient_SZ_13_segment_098_scalogram_combined.png
#   Processing segment 100/369...
#   Saved: SZ_patient_SZ_11_segment_265_scalogram_combined.png
#   Processing segment 267/442...
#   Saved: SZ_patient_SZ_09_segment_375_scalogram_combined.png
#   Processing segment 377/385...
#   Saved: SZ_patient_SZ_12_segment_143_scalogram_combined.png
#   Processing segment 145/353...
#   Saved: SZ_patient_SZ_13_segment_099_scalogram_combined.png
#   Processing segment 101/369...
#   Saved: SZ_patient_SZ_11_segment_266_scalogram_combined.png
#   Processing segment 268/442...
#   Saved: SZ_patient_SZ_09_segment_376_scalogram_combined.png
#   Processing segment 378/385...
#   Saved: SZ_patient_SZ_12_segment_144_scalogram_combined.png
#   Processing segment 146/353...
#   Saved: SZ_patient_SZ_13_segment_100_scalogram_combined.png
#   Processing segment 102/369...
#   Saved: SZ_patient_SZ_11_segment_267_scalogram_combined.png
#   Processing segment 269/442...
#   Saved: SZ_patient_SZ_09_segment_377_scalogram_combined.png
#   Processing segment 379/385...
#   Saved: SZ_patient_SZ_12_segment_145_scalogram_combined.png
#   Processing segment 147/353...
#   Saved: SZ_patient_SZ_13_segment_101_scalogram_combined.png
#   Processing segment 103/369...
#   Saved: SZ_patient_SZ_11_segment_268_scalogram_combined.png
#   Processing segment 270/442...
#   Saved: SZ_patient_SZ_09_segment_378_scalogram_combined.png
#   Processing segment 380/385...
#   Saved: SZ_patient_SZ_12_segment_146_scalogram_combined.png
#   Processing segment 148/353...
#   Saved: SZ_patient_SZ_13_segment_102_scalogram_combined.png
#   Processing segment 104/369...
#   Saved: SZ_patient_SZ_11_segment_269_scalogram_combined.png
#   Processing segment 271/442...
#   Saved: SZ_patient_SZ_09_segment_379_scalogram_combined.png
#   Processing segment 381/385...
#   Saved: SZ_patient_SZ_12_segment_147_scalogram_combined.png
#   Processing segment 149/353...
#   Saved: SZ_patient_SZ_13_segment_103_scalogram_combined.png
#   Processing segment 105/369...
#   Saved: SZ_patient_SZ_11_segment_270_scalogram_combined.png
#   Processing segment 272/442...
#   Saved: SZ_patient_SZ_09_segment_380_scalogram_combined.png
#   Processing segment 382/385...
#   Saved: SZ_patient_SZ_12_segment_148_scalogram_combined.png
#   Processing segment 150/353...
#   Saved: SZ_patient_SZ_13_segment_104_scalogram_combined.png
#   Processing segment 106/369...
#   Saved: SZ_patient_SZ_11_segment_271_scalogram_combined.png
#   Processing segment 273/442...
#   Saved: SZ_patient_SZ_09_segment_381_scalogram_combined.png
#   Processing segment 383/385...
#   Saved: SZ_patient_SZ_12_segment_149_scalogram_combined.png
#   Processing segment 151/353...
#   Saved: SZ_patient_SZ_13_segment_105_scalogram_combined.png
#   Processing segment 107/369...
#   Saved: SZ_patient_SZ_11_segment_272_scalogram_combined.png
#   Processing segment 274/442...
#   Saved: SZ_patient_SZ_09_segment_382_scalogram_combined.png
#   Processing segment 384/385...
#   Saved: SZ_patient_SZ_12_segment_150_scalogram_combined.png
#   Processing segment 152/353...
#   Saved: SZ_patient_SZ_13_segment_106_scalogram_combined.png
#   Processing segment 108/369...
#   Saved: SZ_patient_SZ_11_segment_273_scalogram_combined.png
#   Processing segment 275/442...
#   Saved: SZ_patient_SZ_09_segment_383_scalogram_combined.png
#   Processing segment 385/385...
#   Saved: SZ_patient_SZ_12_segment_151_scalogram_combined.png
#   Processing segment 153/353...
#   Saved: SZ_patient_SZ_13_segment_107_scalogram_combined.png
#   Processing segment 109/369...
#   Saved: SZ_patient_SZ_11_segment_274_scalogram_combined.png
#   Processing segment 276/442...
#   Saved: SZ_patient_SZ_09_segment_384_scalogram_combined.png
# Processing SZ Patient SZ_14...
#   Completed SZ_09: 385 scalograms generated
#
#   EEG data shape: (542500, 19)
#   Applying bandpass filter (0.5-45 Hz)...
#   Segmenting data into 3-second windows...
#   Generated 706 segments from patient SZ_14
#   Processing segment 1/706...
#   Saved: SZ_patient_SZ_12_segment_152_scalogram_combined.png
#   Processing segment 154/353...
#   Saved: SZ_patient_SZ_13_segment_108_scalogram_combined.png
#   Processing segment 110/369...
#   Saved: SZ_patient_SZ_11_segment_275_scalogram_combined.png
#   Processing segment 277/442...
#   Saved: SZ_patient_SZ_14_segment_000_scalogram_combined.png
#   Processing segment 2/706...
#   Saved: SZ_patient_SZ_12_segment_153_scalogram_combined.png
#   Processing segment 155/353...
#   Saved: SZ_patient_SZ_13_segment_109_scalogram_combined.png
#   Processing segment 111/369...
#   Saved: SZ_patient_SZ_11_segment_276_scalogram_combined.png
#   Processing segment 278/442...
#   Saved: SZ_patient_SZ_14_segment_001_scalogram_combined.png
#   Processing segment 3/706...
#   Saved: SZ_patient_SZ_12_segment_154_scalogram_combined.png
#   Processing segment 156/353...
#   Saved: SZ_patient_SZ_13_segment_110_scalogram_combined.png
#   Processing segment 112/369...
#   Saved: SZ_patient_SZ_11_segment_277_scalogram_combined.png
#   Processing segment 279/442...
#   Saved: SZ_patient_SZ_14_segment_002_scalogram_combined.png
#   Processing segment 4/706...
#   Saved: SZ_patient_SZ_12_segment_155_scalogram_combined.png
#   Processing segment 157/353...
#   Saved: SZ_patient_SZ_13_segment_111_scalogram_combined.png
#   Processing segment 113/369...
#   Saved: SZ_patient_SZ_11_segment_278_scalogram_combined.png
#   Processing segment 280/442...
#   Saved: SZ_patient_SZ_14_segment_003_scalogram_combined.png
#   Processing segment 5/706...
#   Saved: SZ_patient_SZ_12_segment_156_scalogram_combined.png
#   Processing segment 158/353...
#   Saved: SZ_patient_SZ_13_segment_112_scalogram_combined.png
#   Processing segment 114/369...
#   Saved: SZ_patient_SZ_11_segment_279_scalogram_combined.png
#   Processing segment 281/442...
#   Saved: SZ_patient_SZ_14_segment_004_scalogram_combined.png
#   Processing segment 6/706...
#   Saved: SZ_patient_SZ_12_segment_157_scalogram_combined.png
#   Processing segment 159/353...
#   Saved: SZ_patient_SZ_11_segment_280_scalogram_combined.png
#   Processing segment 282/442...
#   Saved: SZ_patient_SZ_13_segment_113_scalogram_combined.png
#   Processing segment 115/369...
#   Saved: SZ_patient_SZ_14_segment_005_scalogram_combined.png
#   Processing segment 7/706...
#   Saved: SZ_patient_SZ_12_segment_158_scalogram_combined.png
#   Processing segment 160/353...
#   Saved: SZ_patient_SZ_11_segment_281_scalogram_combined.png
#   Processing segment 283/442...
#   Saved: SZ_patient_SZ_13_segment_114_scalogram_combined.png
#   Processing segment 116/369...
#   Saved: SZ_patient_SZ_14_segment_006_scalogram_combined.png
#   Processing segment 8/706...
#   Saved: SZ_patient_SZ_12_segment_159_scalogram_combined.png
#   Processing segment 161/353...
#   Saved: SZ_patient_SZ_11_segment_282_scalogram_combined.png
#   Processing segment 284/442...
#   Saved: SZ_patient_SZ_13_segment_115_scalogram_combined.png
#   Processing segment 117/369...
#   Saved: SZ_patient_SZ_14_segment_007_scalogram_combined.png
#   Processing segment 9/706...
#   Saved: SZ_patient_SZ_12_segment_160_scalogram_combined.png
#   Processing segment 162/353...
#   Saved: SZ_patient_SZ_11_segment_283_scalogram_combined.png
#   Processing segment 285/442...
#   Saved: SZ_patient_SZ_13_segment_116_scalogram_combined.png
#   Processing segment 118/369...
#   Saved: SZ_patient_SZ_14_segment_008_scalogram_combined.png
#   Processing segment 10/706...
#   Saved: SZ_patient_SZ_12_segment_161_scalogram_combined.png
#   Processing segment 163/353...
#   Saved: SZ_patient_SZ_11_segment_284_scalogram_combined.png
#   Processing segment 286/442...
#   Saved: SZ_patient_SZ_13_segment_117_scalogram_combined.png
#   Processing segment 119/369...
