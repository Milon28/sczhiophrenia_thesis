# %%
import os
import numpy as np
import pandas as pd
import matplotlib
matplotlib.use('Agg')  # Set backend before importing pyplot
import matplotlib.pyplot as plt
from scipy import signal
from scipy.signal import butter, sosfiltfilt
import pywt
from concurrent.futures import ThreadPoolExecutor, as_completed
import multiprocessing as mp
from functools import partial
import warnings
import traceback
import gc
warnings.filterwarnings('ignore')

class OptimizedEEGScalogramGenerator:
    def __init__(self, sz_input_dir, hc_input_dir, output_dir, sampling_rate=250, n_jobs=None):
        """
        Initialize the Optimized EEG Scalogram Generator using Continuous Wavelet Transform (CWT)
        
        Parameters:
        sz_input_dir (str): Directory containing CSV files with Schizophrenia EEG data
        hc_input_dir (str): Directory containing CSV files with Healthy Control EEG data
        output_dir (str): Root directory to save scalogram images
        sampling_rate (int): EEG sampling rate in Hz (default: 250 Hz)
        n_jobs (int): Number of parallel threads (default: CPU count)
        """
        self.sz_input_dir = sz_input_dir
        self.hc_input_dir = hc_input_dir
        self.output_dir = output_dir
        self.sampling_rate = sampling_rate
        self.segment_duration = 3  # 3 seconds
        self.segment_samples = self.sampling_rate * self.segment_duration
        
        # Set number of parallel jobs (using threads instead of processes)
        if n_jobs is None:
            self.n_jobs = min(mp.cpu_count(), 8)  # Cap at 8 to avoid memory issues
        else:
            self.n_jobs = min(n_jobs, 8)
        
        # Wavelet parameters - optimized
        self.wavelet = 'cmor1.5-1.0'  # Complex Morlet wavelet
        self.freq_min = 0.5  # Minimum frequency (Hz)
        self.freq_max = 45   # Maximum frequency (Hz)
        self.num_scales = 100  # Number of scales/frequencies
        
        # Pre-compute frequency array and scales (Float32 for efficiency)
        self.frequencies = np.logspace(np.log10(self.freq_min), np.log10(self.freq_max), 
                                     self.num_scales, dtype=np.float32)
        self.scales = pywt.frequency2scale(self.wavelet, self.frequencies / self.sampling_rate) * self.sampling_rate
        self.scales = self.scales.astype(np.float32)
        
        # Pre-compute filter coefficients (SOS format for stability and speed)
        self.filter_sos = self._precompute_filter()
        
        # Create output directories
        self.sz_dir = os.path.join(output_dir, 'Schizophrenia')
        self.hc_dir = os.path.join(output_dir, 'HealthyControl')
        os.makedirs(self.sz_dir, exist_ok=True)
        os.makedirs(self.hc_dir, exist_ok=True)
        
        print(f"Initialized with {self.n_jobs} parallel threads")
        
    def _precompute_filter(self):
        """Pre-compute bandpass filter coefficients for reuse"""
        nyquist = 0.5 * self.sampling_rate
        low = self.freq_min / nyquist
        high = self.freq_max / nyquist
        sos = signal.butter(4, [low, high], btype='band', output='sos')
        return sos
    
    def bandpass_filter_optimized(self, data):
        """
        Apply pre-computed bandpass filter to EEG data (optimized version)
        """
        # Use SOS format for better numerical stability and speed
        filtered_data = sosfiltfilt(self.filter_sos, data, axis=0)
        return filtered_data.astype(np.float32)
    
    def segment_signal_vectorized(self, data):
        """
        Vectorized segmentation of EEG signal into 3-second windows
        """
        n_samples, n_channels = data.shape
        n_segments = n_samples // self.segment_samples
        
        if n_segments == 0:
            return []
        
        # Reshape for vectorized processing
        valid_samples = n_segments * self.segment_samples
        reshaped_data = data[:valid_samples, :].reshape(n_segments, self.segment_samples, n_channels)
        
        # Convert to list of segments
        segments = [segment.astype(np.float32) for segment in reshaped_data]
        return segments
    
    def compute_cwt_optimized(self, signal_data):
        """
        Optimized CWT computation for a single channel
        """
        signal_data = signal_data.astype(np.float32)
        
        try:
            coefficients, _ = pywt.cwt(signal_data, self.scales, self.wavelet, 
                                     sampling_period=1/self.sampling_rate)
            
            # Convert to power and dB scale with error handling
            power = np.abs(coefficients) ** 2
            # Avoid log(0) by adding small epsilon
            power_db = 10 * np.log10(np.maximum(power, 1e-12))
            
            return power_db.astype(np.float32)
        except Exception as e:
            print(f"CWT computation error: {e}")
            # Return zeros if computation fails
            return np.zeros((len(self.scales), len(signal_data)), dtype=np.float32)
    
    def create_combined_scalogram_safe(self, segment, patient_id, segment_idx, label):
        """
        Safe version of scalogram creation with proper error handling
        """
        try:
            # Compute CWT for all channels
            scalograms = []
            for ch in range(segment.shape[1]):
                cwt_result = self.compute_cwt_optimized(segment[:, ch])
                scalograms.append(cwt_result)
            
            # Average across all channels
            avg_scalogram = np.mean(scalograms, axis=0, dtype=np.float32)
            
            # Create time axis
            time_axis = np.linspace(0, self.segment_duration, segment.shape[0], dtype=np.float32)
            
            # Create figure with explicit cleanup
            plt.ioff()  # Turn off interactive mode
            fig, ax = plt.subplots(figsize=(10, 6), dpi=150)
            
            try:
                im = ax.imshow(
                    avg_scalogram, 
                    aspect='auto', 
                    origin='lower',
                    extent=[time_axis[0], time_axis[-1], self.frequencies[0], self.frequencies[-1]],
                    cmap='viridis',
                    interpolation='bilinear'
                )
                
                ax.set_title(f'Average EEG Scalogram (CWT) - {label} Patient {patient_id} - Segment {segment_idx}', 
                            fontsize=14, fontweight='bold')
                ax.set_xlabel('Time (s)', fontsize=12)
                ax.set_ylabel('Frequency (Hz)', fontsize=12)
                ax.set_yscale('log')
                ax.set_ylim(self.freq_min, self.freq_max)
                
                # Determine save directory and filename
                save_dir = self.sz_dir if label == 'SZ' else self.hc_dir
                filename = f'{label}_patient_{patient_id}_segment_{segment_idx:03d}_scalogram_combined.png'
                filepath = os.path.join(save_dir, filename)
                
                # Save with error handling (removed optimize parameter for compatibility)
                plt.savefig(filepath, dpi=150, bbox_inches='tight', facecolor='white', 
                           format='png')
                
                return filepath
                
            finally:
                plt.close(fig)  # Always close the figure
                plt.clf()       # Clear any remaining plots
                gc.collect()    # Force garbage collection
                
        except Exception as e:
            print(f"Error creating scalogram for {patient_id} segment {segment_idx}: {e}")
            return None
    
    def process_patient_file_safe(self, csv_file, patient_id, label):
        """
        Safe version of patient file processing with comprehensive error handling
        """
        print(f"Processing {label} Patient {patient_id}...")
        
        try:
            # Load EEG data with error handling
            try:
                data = pd.read_csv(csv_file, dtype=np.float32)
                eeg_data = data.values.astype(np.float32)
            except Exception as e:
                print(f"Error loading CSV file {csv_file}: {e}")
                return []
            
            # Handle channel count
            if eeg_data.shape[1] != 19:
                print(f"Warning: Expected 19 channels, got {eeg_data.shape[1]} for patient {patient_id}")
                if eeg_data.shape[1] > 19:
                    eeg_data = eeg_data[:, :19]
                else:
                    padding = np.zeros((eeg_data.shape[0], 19 - eeg_data.shape[1]), dtype=np.float32)
                    eeg_data = np.hstack([eeg_data, padding])
            
            print(f"  EEG data shape: {eeg_data.shape}")
            
            # Apply bandpass filter with error handling
            try:
                print(f"  Applying bandpass filter ({self.freq_min}-{self.freq_max} Hz)...")
                filtered_data = self.bandpass_filter_optimized(eeg_data)
            except Exception as e:
                print(f"Error in filtering for patient {patient_id}: {e}")
                return []
            
            # Segment the data
            print(f"  Segmenting data into {self.segment_duration}-second windows...")
            segments = self.segment_signal_vectorized(filtered_data)
            
            if not segments:
                print(f"  No segments generated for patient {patient_id}")
                return []
            
            print(f"  Generated {len(segments)} segments from patient {patient_id}")
            
            # Create scalogram images for each segment
            saved_files = []
            for idx, segment in enumerate(segments):
                print(f"  Processing segment {idx + 1}/{len(segments)}...")
                
                filepath = self.create_combined_scalogram_safe(segment, patient_id, idx, label)
                if filepath:
                    saved_files.append(filepath)
                    print(f"  Saved: {os.path.basename(filepath)}")
                else:
                    print(f"  Failed to save segment {idx}")
            
            return saved_files
            
        except Exception as e:
            print(f"Error processing patient {patient_id}: {str(e)}")
            traceback.print_exc()
            return []
    
    def get_patient_files(self, directory):
        """
        Get all CSV files from a directory
        """
        csv_files = []
        if os.path.exists(directory):
            for file in os.listdir(directory):
                if file.lower().endswith('.csv'):
                    csv_files.append(os.path.join(directory, file))
            csv_files.sort()
        else:
            print(f"Warning: Directory {directory} does not exist!")
        
        return csv_files
    
    def process_all_patients_threaded(self):
        """
        Process all patients using thread-based parallelism (safer than multiprocessing)
        """
        print("=== Optimized EEG Scalogram Generation (Thread-based Parallel Processing) ===")
        print("Generating scalograms with thread-based parallelism for stability\n")
        
        # Get patient files from both directories
        sz_patient_files = self.get_patient_files(self.sz_input_dir)
        hc_patient_files = self.get_patient_files(self.hc_input_dir)
        
        print(f"Found {len(sz_patient_files)} Schizophrenia patient files")
        print(f"Found {len(hc_patient_files)} Healthy Control patient files")
        print(f"Using {self.n_jobs} parallel threads")
        
        if len(sz_patient_files) == 0 and len(hc_patient_files) == 0:
            print("No CSV files found in the specified directories!")
            return
        
        # Prepare all patient processing tasks
        tasks = []
        
        # Add SZ patients
        for i, csv_file in enumerate(sz_patient_files, 1):
            patient_id = f"SZ_{i:02d}"
            tasks.append((csv_file, patient_id, 'SZ'))
        
        # Add HC patients
        for i, csv_file in enumerate(hc_patient_files, 1):
            patient_id = f"HC_{i:02d}"
            tasks.append((csv_file, patient_id, 'HC'))
        
        total_sz_images = 0
        total_hc_images = 0
        
        # Process patients using ThreadPoolExecutor
        with ThreadPoolExecutor(max_workers=self.n_jobs) as executor:
            # Submit all tasks
            future_to_task = {
                executor.submit(self.process_patient_file_safe, csv_file, patient_id, label): (patient_id, label)
                for csv_file, patient_id, label in tasks
            }
            
            # Process completed tasks
            for future in as_completed(future_to_task):
                patient_id, label = future_to_task[future]
                try:
                    saved_files = future.result(timeout=300)  # 5 minute timeout per patient
                    if label == 'SZ':
                        total_sz_images += len(saved_files)
                    else:
                        total_hc_images += len(saved_files)
                    print(f"  Completed {patient_id}: {len(saved_files)} scalograms generated\n")
                    
                except Exception as e:
                    print(f"Error processing {patient_id}: {e}")
                    traceback.print_exc()
        
        print("=== Summary ===")
        print(f"Total Schizophrenia scalogram images: {total_sz_images}")
        print(f"Total Healthy Control scalogram images: {total_hc_images}")
        print(f"Total scalogram images generated: {total_sz_images + total_hc_images}")
        print(f"Images saved in: {self.output_dir}")
        print(f"  - Schizophrenia scalograms: {self.sz_dir}")
        print(f"  - Healthy Control scalograms: {self.hc_dir}")
        print(f"Wavelet used: {self.wavelet}")
        print(f"Frequency range: {self.freq_min}-{self.freq_max} Hz")
        print(f"Processing completed successfully with {self.n_jobs} threads")

    def process_all_patients_sequential_optimized(self):
        """
        Optimized sequential processing as fallback option
        """
        print("=== Optimized EEG Scalogram Generation (Sequential Processing) ===")
        print("Using optimized sequential processing for maximum stability\n")
        
        # Get patient files from both directories
        sz_patient_files = self.get_patient_files(self.sz_input_dir)
        hc_patient_files = self.get_patient_files(self.hc_input_dir)
        
        print(f"Found {len(sz_patient_files)} Schizophrenia patient files")
        print(f"Found {len(hc_patient_files)} Healthy Control patient files")
        
        if len(sz_patient_files) == 0 and len(hc_patient_files) == 0:
            print("No CSV files found in the specified directories!")
            return
        
        total_sz_images = 0
        total_hc_images = 0
        
        print("\n=== Processing Schizophrenia Patients ===")
        for i, csv_file in enumerate(sz_patient_files, 1):
            patient_id = f"SZ_{i:02d}"
            saved_files = self.process_patient_file_safe(csv_file, patient_id, 'SZ')
            total_sz_images += len(saved_files)
            print(f"  Generated {len(saved_files)} scalograms for {patient_id}\n")
        
        print("=== Processing Healthy Control Patients ===")
        for i, csv_file in enumerate(hc_patient_files, 1):
            patient_id = f"HC_{i:02d}"
            saved_files = self.process_patient_file_safe(csv_file, patient_id, 'HC')
            total_hc_images += len(saved_files)
            print(f"  Generated {len(saved_files)} scalograms for {patient_id}\n")
        
        print("=== Summary ===")
        print(f"Total Schizophrenia scalogram images: {total_sz_images}")
        print(f"Total Healthy Control scalogram images: {total_hc_images}")
        print(f"Total scalogram images generated: {total_sz_images + total_hc_images}")
        print(f"Images saved in: {self.output_dir}")
        print(f"Sequential processing completed successfully")

# Example usage
if __name__ == "__main__":
    # Define paths
    sz_input_directory = "D:/Milon2/SD14/schizophrenia"
    hc_input_directory = "D:/Milon2/SD14/healthy" 
    output_directory = "D:/Milon2/scalogram/images"
    
    # Create optimized scalogram generator
    generator = OptimizedEEGScalogramGenerator(
        sz_input_dir=sz_input_directory,
        hc_input_dir=hc_input_directory,
        output_dir=output_directory,
        sampling_rate=256,
        n_jobs=4  # Use 4 threads for safer parallel processing
    )
    
    print("Choose processing method:")
    print("1. Thread-based parallel processing (recommended)")
    print("2. Sequential processing (most stable)")
    
    try:
        # Try thread-based parallel processing first
        print("\nStarting thread-based parallel processing...")
        generator.process_all_patients_threaded()
    except Exception as e:
        print(f"\nThread-based processing failed: {e}")
        print("Falling back to sequential processing...")
        generator.process_all_patients_sequential_optimized()
    
    print("\nOptimized scalogram generation completed!")
    print("Key improvements:")
    print("- Thread-based parallelism (safer than multiprocessing)")
    print("- Comprehensive error handling and recovery")
    print("- Memory management with garbage collection")
    print("- Vectorized operations where possible")
    print("- Pre-computed filter coefficients")
    print("- Optimized matplotlib settings")
# Out:
# Initialized with 4 parallel threads
# Choose processing method:
# 1. Thread-based parallel processing (recommended)
# 2. Sequential processing (most stable)
#
# Starting thread-based parallel processing...
# === Optimized EEG Scalogram Generation (Thread-based Parallel Processing) ===
# Generating scalograms with thread-based parallelism for stability
#
# Found 2 Schizophrenia patient files
# Found 0 Healthy Control patient files
# Using 4 parallel threads
# Processing SZ Patient SZ_01...
# Processing SZ Patient SZ_02...
#   EEG data shape: (271750, 19)
#   Applying bandpass filter (0.5-45 Hz)...
#   Segmenting data into 3-second windows...
#   Generated 353 segments from patient SZ_02
#   Processing segment 1/353...
#   EEG data shape: (340000, 19)
#   Applying bandpass filter (0.5-45 Hz)...
#   Segmenting data into 3-second windows...
#   Generated 442 segments from patient SZ_01
#   Processing segment 1/442...
#   Saved: SZ_patient_SZ_01_segment_000_scalogram_combined.png  Saved: SZ_patient_SZ_02_segment_000_scalogram_combined.png
#   Processing segment 2/353...
#
#   Processing segment 2/442...
# Error creating scalogram for SZ_02 segment 1: list index out of range
#   Failed to save segment 1
#   Processing segment 3/353...
#   Saved: SZ_patient_SZ_01_segment_001_scalogram_combined.png
#   Processing segment 3/442...
#   Saved: SZ_patient_SZ_01_segment_002_scalogram_combined.png
#   Processing segment 4/442...
#   Saved: SZ_patient_SZ_02_segment_002_scalogram_combined.png
#   Processing segment 4/353...
#   Saved: SZ_patient_SZ_01_segment_003_scalogram_combined.png
#   Processing segment 5/442...
#   Saved: SZ_patient_SZ_02_segment_003_scalogram_combined.png
#   Processing segment 5/353...
#   Saved: SZ_patient_SZ_01_segment_004_scalogram_combined.png
#   Processing segment 6/442...
#   Saved: SZ_patient_SZ_02_segment_004_scalogram_combined.png
#   Processing segment 6/353...
#   Saved: SZ_patient_SZ_01_segment_005_scalogram_combined.png
#   Processing segment 7/442...
#   Saved: SZ_patient_SZ_02_segment_005_scalogram_combined.png
#   Processing segment 7/353...
#   Saved: SZ_patient_SZ_01_segment_006_scalogram_combined.png
#   Processing segment 8/442...
#   Saved: SZ_patient_SZ_02_segment_006_scalogram_combined.png
#   Processing segment 8/353...
#   Saved: SZ_patient_SZ_01_segment_007_scalogram_combined.png
#   Processing segment 9/442...
#   Saved: SZ_patient_SZ_02_segment_007_scalogram_combined.png
#   Processing segment 9/353...
#   Saved: SZ_patient_SZ_01_segment_008_scalogram_combined.png
#   Processing segment 10/442...
#   Saved: SZ_patient_SZ_02_segment_008_scalogram_combined.png
#   Processing segment 10/353...
#   Saved: SZ_patient_SZ_01_segment_009_scalogram_combined.png
#   Processing segment 11/442...
#   Saved: SZ_patient_SZ_02_segment_009_scalogram_combined.png
#   Processing segment 11/353...
#   Saved: SZ_patient_SZ_01_segment_010_scalogram_combined.png
#   Processing segment 12/442...
#   Saved: SZ_patient_SZ_02_segment_010_scalogram_combined.png
#   Processing segment 12/353...
#   Saved: SZ_patient_SZ_01_segment_011_scalogram_combined.png
#   Processing segment 13/442...
#   Saved: SZ_patient_SZ_02_segment_011_scalogram_combined.png
#   Processing segment 13/353...
#   Saved: SZ_patient_SZ_01_segment_012_scalogram_combined.png
#   Processing segment 14/442...
#   Saved: SZ_patient_SZ_02_segment_012_scalogram_combined.png
#   Processing segment 14/353...
#   Saved: SZ_patient_SZ_01_segment_013_scalogram_combined.png
#   Processing segment 15/442...
#   Saved: SZ_patient_SZ_02_segment_013_scalogram_combined.png
#   Processing segment 15/353...
#   Saved: SZ_patient_SZ_01_segment_014_scalogram_combined.png
#   Processing segment 16/442...
#   Saved: SZ_patient_SZ_02_segment_014_scalogram_combined.png
#   Processing segment 16/353...
#   Saved: SZ_patient_SZ_01_segment_015_scalogram_combined.png
#   Processing segment 17/442...
#   Saved: SZ_patient_SZ_02_segment_015_scalogram_combined.png
#   Processing segment 17/353...
#   Saved: SZ_patient_SZ_01_segment_016_scalogram_combined.png
#   Processing segment 18/442...
#   Saved: SZ_patient_SZ_02_segment_016_scalogram_combined.png
#   Processing segment 18/353...
#   Saved: SZ_patient_SZ_01_segment_017_scalogram_combined.png
#   Processing segment 19/442...
#   Saved: SZ_patient_SZ_02_segment_017_scalogram_combined.png
#   Processing segment 19/353...
#   Saved: SZ_patient_SZ_01_segment_018_scalogram_combined.png
#   Processing segment 20/442...
#   Saved: SZ_patient_SZ_02_segment_018_scalogram_combined.png
#   Processing segment 20/353...
#   Saved: SZ_patient_SZ_01_segment_019_scalogram_combined.png
#   Processing segment 21/442...
#   Saved: SZ_patient_SZ_02_segment_019_scalogram_combined.png
#   Processing segment 21/353...
#   Saved: SZ_patient_SZ_01_segment_020_scalogram_combined.png
#   Processing segment 22/442...
#   Saved: SZ_patient_SZ_02_segment_020_scalogram_combined.png
#   Processing segment 22/353...
#   Saved: SZ_patient_SZ_01_segment_021_scalogram_combined.png
#   Processing segment 23/442...
#   Saved: SZ_patient_SZ_02_segment_021_scalogram_combined.png
#   Processing segment 23/353...
#   Saved: SZ_patient_SZ_01_segment_022_scalogram_combined.png
#   Processing segment 24/442...
#   Saved: SZ_patient_SZ_02_segment_022_scalogram_combined.png
#   Processing segment 24/353...
#   Saved: SZ_patient_SZ_01_segment_023_scalogram_combined.png
#   Processing segment 25/442...
#   Saved: SZ_patient_SZ_02_segment_023_scalogram_combined.png
#   Processing segment 25/353...
#   Saved: SZ_patient_SZ_01_segment_024_scalogram_combined.png
#   Processing segment 26/442...
#   Saved: SZ_patient_SZ_02_segment_024_scalogram_combined.png
#   Processing segment 26/353...
#   Saved: SZ_patient_SZ_01_segment_025_scalogram_combined.png
#   Processing segment 27/442...
#   Saved: SZ_patient_SZ_02_segment_025_scalogram_combined.png
#   Processing segment 27/353...
#   Saved: SZ_patient_SZ_01_segment_026_scalogram_combined.png
#   Processing segment 28/442...
#   Saved: SZ_patient_SZ_02_segment_026_scalogram_combined.png
#   Processing segment 28/353...
#   Saved: SZ_patient_SZ_01_segment_027_scalogram_combined.png
#   Processing segment 29/442...
#   Saved: SZ_patient_SZ_02_segment_027_scalogram_combined.png
#   Processing segment 29/353...
#   Saved: SZ_patient_SZ_01_segment_028_scalogram_combined.png
#   Processing segment 30/442...
#   Saved: SZ_patient_SZ_02_segment_028_scalogram_combined.png
#   Processing segment 30/353...
#   Saved: SZ_patient_SZ_01_segment_029_scalogram_combined.png
#   Processing segment 31/442...
#   Saved: SZ_patient_SZ_02_segment_029_scalogram_combined.png
#   Processing segment 31/353...
#   Saved: SZ_patient_SZ_01_segment_030_scalogram_combined.png
#   Processing segment 32/442...
#   Saved: SZ_patient_SZ_02_segment_030_scalogram_combined.png
#   Processing segment 32/353...
#   Saved: SZ_patient_SZ_01_segment_031_scalogram_combined.png
#   Processing segment 33/442...
#   Saved: SZ_patient_SZ_02_segment_031_scalogram_combined.png
#   Processing segment 33/353...
#   Saved: SZ_patient_SZ_01_segment_032_scalogram_combined.png
#   Processing segment 34/442...
#   Saved: SZ_patient_SZ_02_segment_032_scalogram_combined.png
#   Processing segment 34/353...
#   Saved: SZ_patient_SZ_01_segment_033_scalogram_combined.png
#   Processing segment 35/442...
#   Saved: SZ_patient_SZ_02_segment_033_scalogram_combined.png
#   Processing segment 35/353...
#   Saved: SZ_patient_SZ_01_segment_034_scalogram_combined.png
#   Processing segment 36/442...
#   Saved: SZ_patient_SZ_02_segment_034_scalogram_combined.png
#   Processing segment 36/353...
#   Saved: SZ_patient_SZ_01_segment_035_scalogram_combined.png
#   Processing segment 37/442...
#   Saved: SZ_patient_SZ_02_segment_035_scalogram_combined.png
#   Processing segment 37/353...
#   Saved: SZ_patient_SZ_01_segment_036_scalogram_combined.png
#   Processing segment 38/442...
#   Saved: SZ_patient_SZ_02_segment_036_scalogram_combined.png
#   Processing segment 38/353...
#   Saved: SZ_patient_SZ_01_segment_037_scalogram_combined.png
#   Processing segment 39/442...
#   Saved: SZ_patient_SZ_02_segment_037_scalogram_combined.png
#   Processing segment 39/353...
#   Saved: SZ_patient_SZ_01_segment_038_scalogram_combined.png
#   Processing segment 40/442...
#   Saved: SZ_patient_SZ_02_segment_038_scalogram_combined.png
#   Processing segment 40/353...
#   Saved: SZ_patient_SZ_01_segment_039_scalogram_combined.png
#   Processing segment 41/442...
#   Saved: SZ_patient_SZ_02_segment_039_scalogram_combined.png
#   Processing segment 41/353...
#   Saved: SZ_patient_SZ_01_segment_040_scalogram_combined.png
#   Processing segment 42/442...
#   Saved: SZ_patient_SZ_02_segment_040_scalogram_combined.png
#   Processing segment 42/353...
#   Saved: SZ_patient_SZ_01_segment_041_scalogram_combined.png
#   Processing segment 43/442...
#   Saved: SZ_patient_SZ_02_segment_041_scalogram_combined.png
#   Processing segment 43/353...
#   Saved: SZ_patient_SZ_01_segment_042_scalogram_combined.png
#   Processing segment 44/442...
#   Saved: SZ_patient_SZ_02_segment_042_scalogram_combined.png
#   Processing segment 44/353...
#   Saved: SZ_patient_SZ_01_segment_043_scalogram_combined.png
#   Processing segment 45/442...
#   Saved: SZ_patient_SZ_02_segment_043_scalogram_combined.png
#   Processing segment 45/353...
#   Saved: SZ_patient_SZ_01_segment_044_scalogram_combined.png
#   Processing segment 46/442...
#   Saved: SZ_patient_SZ_02_segment_044_scalogram_combined.png
#   Processing segment 46/353...
#   Saved: SZ_patient_SZ_01_segment_045_scalogram_combined.png
#   Processing segment 47/442...
#   Saved: SZ_patient_SZ_02_segment_045_scalogram_combined.png
#   Processing segment 47/353...
#   Saved: SZ_patient_SZ_01_segment_046_scalogram_combined.png
#   Processing segment 48/442...
#   Saved: SZ_patient_SZ_02_segment_046_scalogram_combined.png
#   Processing segment 48/353...
#   Saved: SZ_patient_SZ_01_segment_047_scalogram_combined.png
#   Processing segment 49/442...
#   Saved: SZ_patient_SZ_02_segment_047_scalogram_combined.png
#   Processing segment 49/353...
#   Saved: SZ_patient_SZ_01_segment_048_scalogram_combined.png
#   Processing segment 50/442...
#   Saved: SZ_patient_SZ_02_segment_048_scalogram_combined.png
#   Processing segment 50/353...
#   Saved: SZ_patient_SZ_01_segment_049_scalogram_combined.png
#   Processing segment 51/442...
#   Saved: SZ_patient_SZ_02_segment_049_scalogram_combined.png
#   Processing segment 51/353...
#   Saved: SZ_patient_SZ_01_segment_050_scalogram_combined.png
#   Processing segment 52/442...
#   Saved: SZ_patient_SZ_02_segment_050_scalogram_combined.png
#   Processing segment 52/353...
#   Saved: SZ_patient_SZ_01_segment_051_scalogram_combined.png
#   Processing segment 53/442...
#   Saved: SZ_patient_SZ_02_segment_051_scalogram_combined.png
#   Processing segment 53/353...
#   Saved: SZ_patient_SZ_01_segment_052_scalogram_combined.png
#   Processing segment 54/442...
#   Saved: SZ_patient_SZ_02_segment_052_scalogram_combined.png
#   Processing segment 54/353...
#   Saved: SZ_patient_SZ_01_segment_053_scalogram_combined.png
#   Processing segment 55/442...
#   Saved: SZ_patient_SZ_02_segment_053_scalogram_combined.png
#   Processing segment 55/353...
#   Saved: SZ_patient_SZ_01_segment_054_scalogram_combined.png
#   Processing segment 56/442...
#   Saved: SZ_patient_SZ_02_segment_054_scalogram_combined.png
#   Processing segment 56/353...
#   Saved: SZ_patient_SZ_01_segment_055_scalogram_combined.png
#   Processing segment 57/442...
#   Saved: SZ_patient_SZ_02_segment_055_scalogram_combined.png
#   Processing segment 57/353...
#   Saved: SZ_patient_SZ_01_segment_056_scalogram_combined.png
#   Processing segment 58/442...
#   Saved: SZ_patient_SZ_02_segment_056_scalogram_combined.png
#   Processing segment 58/353...
#   Saved: SZ_patient_SZ_01_segment_057_scalogram_combined.png
#   Processing segment 59/442...
#   Saved: SZ_patient_SZ_02_segment_057_scalogram_combined.png
#   Processing segment 59/353...
#   Saved: SZ_patient_SZ_01_segment_058_scalogram_combined.png
#   Processing segment 60/442...
#   Saved: SZ_patient_SZ_02_segment_058_scalogram_combined.png
#   Processing segment 60/353...
#   Saved: SZ_patient_SZ_01_segment_059_scalogram_combined.png
#   Processing segment 61/442...
#   Saved: SZ_patient_SZ_02_segment_059_scalogram_combined.png
#   Processing segment 61/353...
#   Saved: SZ_patient_SZ_01_segment_060_scalogram_combined.png
#   Processing segment 62/442...
#   Saved: SZ_patient_SZ_02_segment_060_scalogram_combined.png
#   Processing segment 62/353...
#   Saved: SZ_patient_SZ_01_segment_061_scalogram_combined.png
#   Processing segment 63/442...
#   Saved: SZ_patient_SZ_02_segment_061_scalogram_combined.png
#   Processing segment 63/353...
#   Saved: SZ_patient_SZ_01_segment_062_scalogram_combined.png
#   Processing segment 64/442...
#   Saved: SZ_patient_SZ_02_segment_062_scalogram_combined.png
#   Processing segment 64/353...
#   Saved: SZ_patient_SZ_01_segment_063_scalogram_combined.png
#   Processing segment 65/442...
#   Saved: SZ_patient_SZ_02_segment_063_scalogram_combined.png
#   Processing segment 65/353...
#   Saved: SZ_patient_SZ_01_segment_064_scalogram_combined.png
#   Processing segment 66/442...
#   Saved: SZ_patient_SZ_02_segment_064_scalogram_combined.png
#   Processing segment 66/353...
#   Saved: SZ_patient_SZ_01_segment_065_scalogram_combined.png
#   Processing segment 67/442...
#   Saved: SZ_patient_SZ_02_segment_065_scalogram_combined.png
#   Processing segment 67/353...
#   Saved: SZ_patient_SZ_01_segment_066_scalogram_combined.png
#   Processing segment 68/442...
#   Saved: SZ_patient_SZ_02_segment_066_scalogram_combined.png
#   Processing segment 68/353...
#   Saved: SZ_patient_SZ_01_segment_067_scalogram_combined.png
#   Processing segment 69/442...
#   Saved: SZ_patient_SZ_02_segment_067_scalogram_combined.png
#   Processing segment 69/353...
#   Saved: SZ_patient_SZ_01_segment_068_scalogram_combined.png
#   Processing segment 70/442...
#   Saved: SZ_patient_SZ_02_segment_068_scalogram_combined.png
#   Processing segment 70/353...
#   Saved: SZ_patient_SZ_01_segment_069_scalogram_combined.png
#   Processing segment 71/442...
#   Saved: SZ_patient_SZ_02_segment_069_scalogram_combined.png
#   Processing segment 71/353...
#   Saved: SZ_patient_SZ_01_segment_070_scalogram_combined.png
#   Processing segment 72/442...
#   Saved: SZ_patient_SZ_02_segment_070_scalogram_combined.png
#   Processing segment 72/353...
#   Saved: SZ_patient_SZ_01_segment_071_scalogram_combined.png
#   Processing segment 73/442...
#   Saved: SZ_patient_SZ_02_segment_071_scalogram_combined.png
#   Processing segment 73/353...
#   Saved: SZ_patient_SZ_01_segment_072_scalogram_combined.png
#   Processing segment 74/442...
#   Saved: SZ_patient_SZ_02_segment_072_scalogram_combined.png
#   Processing segment 74/353...
#   Saved: SZ_patient_SZ_01_segment_073_scalogram_combined.png
#   Processing segment 75/442...
#   Saved: SZ_patient_SZ_02_segment_073_scalogram_combined.png
#   Processing segment 75/353...
#   Saved: SZ_patient_SZ_01_segment_074_scalogram_combined.png
#   Processing segment 76/442...
#   Saved: SZ_patient_SZ_02_segment_074_scalogram_combined.png
#   Processing segment 76/353...
#   Saved: SZ_patient_SZ_01_segment_075_scalogram_combined.png
#   Processing segment 77/442...
#   Saved: SZ_patient_SZ_02_segment_075_scalogram_combined.png
#   Processing segment 77/353...
#   Saved: SZ_patient_SZ_01_segment_076_scalogram_combined.png
#   Processing segment 78/442...
#   Saved: SZ_patient_SZ_02_segment_076_scalogram_combined.png
#   Processing segment 78/353...
#   Saved: SZ_patient_SZ_01_segment_077_scalogram_combined.png
#   Processing segment 79/442...
#   Saved: SZ_patient_SZ_02_segment_077_scalogram_combined.png
#   Processing segment 79/353...
#   Saved: SZ_patient_SZ_01_segment_078_scalogram_combined.png
#   Processing segment 80/442...
#   Saved: SZ_patient_SZ_02_segment_078_scalogram_combined.png
#   Processing segment 80/353...
#   Saved: SZ_patient_SZ_01_segment_079_scalogram_combined.png
#   Processing segment 81/442...
#   Saved: SZ_patient_SZ_02_segment_079_scalogram_combined.png
#   Processing segment 81/353...
#   Saved: SZ_patient_SZ_01_segment_080_scalogram_combined.png
#   Processing segment 82/442...
#   Saved: SZ_patient_SZ_02_segment_080_scalogram_combined.png
#   Processing segment 82/353...
#   Saved: SZ_patient_SZ_01_segment_081_scalogram_combined.png
#   Processing segment 83/442...
#   Saved: SZ_patient_SZ_02_segment_081_scalogram_combined.png
#   Processing segment 83/353...
#   Saved: SZ_patient_SZ_02_segment_082_scalogram_combined.png
#   Processing segment 84/353...
#   Saved: SZ_patient_SZ_01_segment_082_scalogram_combined.png
#   Processing segment 84/442...
#   Saved: SZ_patient_SZ_02_segment_083_scalogram_combined.png
#   Processing segment 85/353...
#   Saved: SZ_patient_SZ_01_segment_083_scalogram_combined.png
#   Processing segment 85/442...
#   Saved: SZ_patient_SZ_02_segment_084_scalogram_combined.png
#   Processing segment 86/353...
#   Saved: SZ_patient_SZ_01_segment_084_scalogram_combined.png
#   Processing segment 86/442...
#   Saved: SZ_patient_SZ_02_segment_085_scalogram_combined.png
#   Processing segment 87/353...
#   Saved: SZ_patient_SZ_01_segment_085_scalogram_combined.png
#   Processing segment 87/442...
#   Saved: SZ_patient_SZ_02_segment_086_scalogram_combined.png
#   Processing segment 88/353...
#   Saved: SZ_patient_SZ_01_segment_086_scalogram_combined.png
#   Processing segment 88/442...
#   Saved: SZ_patient_SZ_02_segment_087_scalogram_combined.png
#   Processing segment 89/353...
#   Saved: SZ_patient_SZ_01_segment_087_scalogram_combined.png
#   Processing segment 89/442...
#   Saved: SZ_patient_SZ_02_segment_088_scalogram_combined.png
#   Processing segment 90/353...
#   Saved: SZ_patient_SZ_01_segment_088_scalogram_combined.png
#   Processing segment 90/442...
#   Saved: SZ_patient_SZ_02_segment_089_scalogram_combined.png
#   Processing segment 91/353...
#   Saved: SZ_patient_SZ_01_segment_089_scalogram_combined.png
#   Processing segment 91/442...
#   Saved: SZ_patient_SZ_02_segment_090_scalogram_combined.png
#   Processing segment 92/353...
#   Saved: SZ_patient_SZ_01_segment_090_scalogram_combined.png
#   Processing segment 92/442...
#   Saved: SZ_patient_SZ_02_segment_091_scalogram_combined.png
#   Processing segment 93/353...
#   Saved: SZ_patient_SZ_01_segment_091_scalogram_combined.png
#   Processing segment 93/442...
#   Saved: SZ_patient_SZ_02_segment_092_scalogram_combined.png
#   Processing segment 94/353...
#   Saved: SZ_patient_SZ_01_segment_092_scalogram_combined.png
#   Processing segment 94/442...
#   Saved: SZ_patient_SZ_02_segment_093_scalogram_combined.png
#   Processing segment 95/353...
#   Saved: SZ_patient_SZ_01_segment_093_scalogram_combined.png
#   Processing segment 95/442...
#   Saved: SZ_patient_SZ_02_segment_094_scalogram_combined.png
#   Processing segment 96/353...
#   Saved: SZ_patient_SZ_01_segment_094_scalogram_combined.png
#   Processing segment 96/442...
#   Saved: SZ_patient_SZ_02_segment_095_scalogram_combined.png
#   Processing segment 97/353...
#   Saved: SZ_patient_SZ_01_segment_095_scalogram_combined.png
#   Processing segment 97/442...
#   Saved: SZ_patient_SZ_02_segment_096_scalogram_combined.png
#   Processing segment 98/353...
#   Saved: SZ_patient_SZ_01_segment_096_scalogram_combined.png
#   Processing segment 98/442...
#   Saved: SZ_patient_SZ_02_segment_097_scalogram_combined.png
#   Processing segment 99/353...
#   Saved: SZ_patient_SZ_01_segment_097_scalogram_combined.png
#   Processing segment 99/442...
#   Saved: SZ_patient_SZ_02_segment_098_scalogram_combined.png
#   Processing segment 100/353...
#   Saved: SZ_patient_SZ_01_segment_098_scalogram_combined.png
#   Processing segment 100/442...
#   Saved: SZ_patient_SZ_02_segment_099_scalogram_combined.png
#   Processing segment 101/353...
#   Saved: SZ_patient_SZ_01_segment_099_scalogram_combined.png
#   Processing segment 101/442...
#   Saved: SZ_patient_SZ_02_segment_100_scalogram_combined.png
#   Processing segment 102/353...
#   Saved: SZ_patient_SZ_01_segment_100_scalogram_combined.png
#   Processing segment 102/442...
#   Saved: SZ_patient_SZ_02_segment_101_scalogram_combined.png
#   Processing segment 103/353...
#   Saved: SZ_patient_SZ_01_segment_101_scalogram_combined.png
#   Processing segment 103/442...
#   Saved: SZ_patient_SZ_02_segment_102_scalogram_combined.png
#   Processing segment 104/353...
#   Saved: SZ_patient_SZ_01_segment_102_scalogram_combined.png
#   Processing segment 104/442...
#   Saved: SZ_patient_SZ_02_segment_103_scalogram_combined.png
#   Processing segment 105/353...
#   Saved: SZ_patient_SZ_01_segment_103_scalogram_combined.png
#   Processing segment 105/442...
#   Saved: SZ_patient_SZ_02_segment_104_scalogram_combined.png
#   Processing segment 106/353...
#   Saved: SZ_patient_SZ_01_segment_104_scalogram_combined.png
#   Processing segment 106/442...
#   Saved: SZ_patient_SZ_02_segment_105_scalogram_combined.png
#   Processing segment 107/353...
#   Saved: SZ_patient_SZ_01_segment_105_scalogram_combined.png
#   Processing segment 107/442...
#   Saved: SZ_patient_SZ_02_segment_106_scalogram_combined.png
#   Processing segment 108/353...
#   Saved: SZ_patient_SZ_01_segment_106_scalogram_combined.png
#   Processing segment 108/442...
#   Saved: SZ_patient_SZ_02_segment_107_scalogram_combined.png
#   Processing segment 109/353...
#   Saved: SZ_patient_SZ_01_segment_107_scalogram_combined.png
#   Processing segment 109/442...
#   Saved: SZ_patient_SZ_02_segment_108_scalogram_combined.png
#   Processing segment 110/353...
#   Saved: SZ_patient_SZ_01_segment_108_scalogram_combined.png
#   Processing segment 110/442...
#   Saved: SZ_patient_SZ_02_segment_109_scalogram_combined.png
#   Processing segment 111/353...
#   Saved: SZ_patient_SZ_01_segment_109_scalogram_combined.png
#   Processing segment 111/442...
#   Saved: SZ_patient_SZ_02_segment_110_scalogram_combined.png
#   Processing segment 112/353...
#   Saved: SZ_patient_SZ_01_segment_110_scalogram_combined.png
#   Processing segment 112/442...
#   Saved: SZ_patient_SZ_02_segment_111_scalogram_combined.png
#   Processing segment 113/353...
#   Saved: SZ_patient_SZ_01_segment_111_scalogram_combined.png
#   Processing segment 113/442...
#   Saved: SZ_patient_SZ_02_segment_112_scalogram_combined.png
#   Processing segment 114/353...
#   Saved: SZ_patient_SZ_01_segment_112_scalogram_combined.png
#   Processing segment 114/442...
#   Saved: SZ_patient_SZ_02_segment_113_scalogram_combined.png
#   Processing segment 115/353...
#   Saved: SZ_patient_SZ_01_segment_113_scalogram_combined.png
#   Processing segment 115/442...
#   Saved: SZ_patient_SZ_02_segment_114_scalogram_combined.png
#   Processing segment 116/353...
#   Saved: SZ_patient_SZ_01_segment_114_scalogram_combined.png
#   Processing segment 116/442...
#   Saved: SZ_patient_SZ_02_segment_115_scalogram_combined.png
#   Processing segment 117/353...
#   Saved: SZ_patient_SZ_01_segment_115_scalogram_combined.png
#   Processing segment 117/442...
#   Saved: SZ_patient_SZ_02_segment_116_scalogram_combined.png
#   Processing segment 118/353...
#   Saved: SZ_patient_SZ_01_segment_116_scalogram_combined.png
#   Processing segment 118/442...
#   Saved: SZ_patient_SZ_02_segment_117_scalogram_combined.png
#   Processing segment 119/353...
#   Saved: SZ_patient_SZ_01_segment_117_scalogram_combined.png
#   Processing segment 119/442...
#   Saved: SZ_patient_SZ_02_segment_118_scalogram_combined.png
#   Processing segment 120/353...
#   Saved: SZ_patient_SZ_01_segment_118_scalogram_combined.png
#   Processing segment 120/442...
#   Saved: SZ_patient_SZ_02_segment_119_scalogram_combined.png
#   Processing segment 121/353...
#   Saved: SZ_patient_SZ_01_segment_119_scalogram_combined.png
#   Processing segment 121/442...
#   Saved: SZ_patient_SZ_02_segment_120_scalogram_combined.png
#   Processing segment 122/353...
#   Saved: SZ_patient_SZ_01_segment_120_scalogram_combined.png
#   Processing segment 122/442...
#   Saved: SZ_patient_SZ_02_segment_121_scalogram_combined.png
#   Processing segment 123/353...
#   Saved: SZ_patient_SZ_01_segment_121_scalogram_combined.png
#   Processing segment 123/442...
#   Saved: SZ_patient_SZ_02_segment_122_scalogram_combined.png
#   Processing segment 124/353...
#   Saved: SZ_patient_SZ_01_segment_122_scalogram_combined.png
#   Processing segment 124/442...
#   Saved: SZ_patient_SZ_02_segment_123_scalogram_combined.png
#   Processing segment 125/353...
#   Saved: SZ_patient_SZ_01_segment_123_scalogram_combined.png
#   Processing segment 125/442...
#   Saved: SZ_patient_SZ_02_segment_124_scalogram_combined.png
#   Processing segment 126/353...
#   Saved: SZ_patient_SZ_01_segment_124_scalogram_combined.png
#   Processing segment 126/442...
#   Saved: SZ_patient_SZ_02_segment_125_scalogram_combined.png
#   Processing segment 127/353...
#   Saved: SZ_patient_SZ_01_segment_125_scalogram_combined.png
#   Processing segment 127/442...
#   Saved: SZ_patient_SZ_02_segment_126_scalogram_combined.png
#   Processing segment 128/353...
#   Saved: SZ_patient_SZ_01_segment_126_scalogram_combined.png
#   Processing segment 128/442...
#   Saved: SZ_patient_SZ_02_segment_127_scalogram_combined.png
#   Processing segment 129/353...
#   Saved: SZ_patient_SZ_01_segment_127_scalogram_combined.png
#   Processing segment 129/442...
#   Saved: SZ_patient_SZ_02_segment_128_scalogram_combined.png
#   Processing segment 130/353...
#   Saved: SZ_patient_SZ_01_segment_128_scalogram_combined.png
#   Processing segment 130/442...
#   Saved: SZ_patient_SZ_02_segment_129_scalogram_combined.png
#   Processing segment 131/353...
#   Saved: SZ_patient_SZ_01_segment_129_scalogram_combined.png
#   Processing segment 131/442...
#   Saved: SZ_patient_SZ_02_segment_130_scalogram_combined.png
#   Processing segment 132/353...
#   Saved: SZ_patient_SZ_01_segment_130_scalogram_combined.png
#   Processing segment 132/442...
#   Saved: SZ_patient_SZ_02_segment_131_scalogram_combined.png
#   Processing segment 133/353...
#   Saved: SZ_patient_SZ_01_segment_131_scalogram_combined.png
#   Processing segment 133/442...
#   Saved: SZ_patient_SZ_02_segment_132_scalogram_combined.png
#   Processing segment 134/353...
#   Saved: SZ_patient_SZ_01_segment_132_scalogram_combined.png
#   Processing segment 134/442...
#   Saved: SZ_patient_SZ_02_segment_133_scalogram_combined.png
#   Processing segment 135/353...
#   Saved: SZ_patient_SZ_01_segment_133_scalogram_combined.png
#   Processing segment 135/442...
#   Saved: SZ_patient_SZ_02_segment_134_scalogram_combined.png
#   Processing segment 136/353...
#   Saved: SZ_patient_SZ_01_segment_134_scalogram_combined.png
#   Processing segment 136/442...
#   Saved: SZ_patient_SZ_01_segment_135_scalogram_combined.png
#   Processing segment 137/442...
#   Saved: SZ_patient_SZ_02_segment_135_scalogram_combined.png
#   Processing segment 137/353...
#   Saved: SZ_patient_SZ_01_segment_136_scalogram_combined.png
#   Processing segment 138/442...
#   Saved: SZ_patient_SZ_02_segment_136_scalogram_combined.png
#   Processing segment 138/353...
#   Saved: SZ_patient_SZ_01_segment_137_scalogram_combined.png
#   Processing segment 139/442...
#   Saved: SZ_patient_SZ_02_segment_137_scalogram_combined.png
#   Processing segment 139/353...
#   Saved: SZ_patient_SZ_01_segment_138_scalogram_combined.png
#   Processing segment 140/442...
#   Saved: SZ_patient_SZ_02_segment_138_scalogram_combined.png
#   Processing segment 140/353...
#   Saved: SZ_patient_SZ_01_segment_139_scalogram_combined.png
#   Processing segment 141/442...
#   Saved: SZ_patient_SZ_02_segment_139_scalogram_combined.png
#   Processing segment 141/353...
#   Saved: SZ_patient_SZ_01_segment_140_scalogram_combined.png
#   Processing segment 142/442...
#   Saved: SZ_patient_SZ_02_segment_140_scalogram_combined.png
#   Processing segment 142/353...
#   Saved: SZ_patient_SZ_01_segment_141_scalogram_combined.png
#   Processing segment 143/442...
#   Saved: SZ_patient_SZ_02_segment_141_scalogram_combined.png
#   Processing segment 143/353...
#   Saved: SZ_patient_SZ_01_segment_142_scalogram_combined.png
#   Processing segment 144/442...
#   Saved: SZ_patient_SZ_02_segment_142_scalogram_combined.png
#   Processing segment 144/353...
#   Saved: SZ_patient_SZ_01_segment_143_scalogram_combined.png
#   Processing segment 145/442...
#   Saved: SZ_patient_SZ_02_segment_143_scalogram_combined.png
#   Processing segment 145/353...
#   Saved: SZ_patient_SZ_01_segment_144_scalogram_combined.png
#   Processing segment 146/442...
#   Saved: SZ_patient_SZ_02_segment_144_scalogram_combined.png
#   Processing segment 146/353...
#   Saved: SZ_patient_SZ_01_segment_145_scalogram_combined.png
#   Processing segment 147/442...
#   Saved: SZ_patient_SZ_02_segment_145_scalogram_combined.png
#   Processing segment 147/353...
#   Saved: SZ_patient_SZ_01_segment_146_scalogram_combined.png
#   Processing segment 148/442...
#   Saved: SZ_patient_SZ_02_segment_146_scalogram_combined.png
#   Processing segment 148/353...
#   Saved: SZ_patient_SZ_01_segment_147_scalogram_combined.png
#   Processing segment 149/442...
#   Saved: SZ_patient_SZ_02_segment_147_scalogram_combined.png
#   Processing segment 149/353...
#   Saved: SZ_patient_SZ_01_segment_148_scalogram_combined.png
#   Processing segment 150/442...
#   Saved: SZ_patient_SZ_02_segment_148_scalogram_combined.png
#   Processing segment 150/353...
#   Saved: SZ_patient_SZ_01_segment_149_scalogram_combined.png
#   Processing segment 151/442...
#   Saved: SZ_patient_SZ_02_segment_149_scalogram_combined.png
#   Processing segment 151/353...
#   Saved: SZ_patient_SZ_01_segment_150_scalogram_combined.png
#   Processing segment 152/442...
#   Saved: SZ_patient_SZ_02_segment_150_scalogram_combined.png
#   Processing segment 152/353...
#   Saved: SZ_patient_SZ_01_segment_151_scalogram_combined.png
#   Processing segment 153/442...
#   Saved: SZ_patient_SZ_02_segment_151_scalogram_combined.png
#   Processing segment 153/353...
#   Saved: SZ_patient_SZ_01_segment_152_scalogram_combined.png
#   Processing segment 154/442...
#   Saved: SZ_patient_SZ_02_segment_152_scalogram_combined.png
#   Processing segment 154/353...
#   Saved: SZ_patient_SZ_01_segment_153_scalogram_combined.png
#   Processing segment 155/442...
#   Saved: SZ_patient_SZ_02_segment_153_scalogram_combined.png
#   Processing segment 155/353...
#   Saved: SZ_patient_SZ_01_segment_154_scalogram_combined.png
#   Processing segment 156/442...
#   Saved: SZ_patient_SZ_02_segment_154_scalogram_combined.png
#   Processing segment 156/353...
#   Saved: SZ_patient_SZ_01_segment_155_scalogram_combined.png
#   Processing segment 157/442...
#   Saved: SZ_patient_SZ_02_segment_155_scalogram_combined.png
#   Processing segment 157/353...
#   Saved: SZ_patient_SZ_01_segment_156_scalogram_combined.png
#   Processing segment 158/442...
#   Saved: SZ_patient_SZ_02_segment_156_scalogram_combined.png
#   Processing segment 158/353...
#   Saved: SZ_patient_SZ_01_segment_157_scalogram_combined.png
#   Processing segment 159/442...
#   Saved: SZ_patient_SZ_02_segment_157_scalogram_combined.png
#   Processing segment 159/353...
#   Saved: SZ_patient_SZ_01_segment_158_scalogram_combined.png
#   Processing segment 160/442...
#   Saved: SZ_patient_SZ_02_segment_158_scalogram_combined.png
#   Processing segment 160/353...
#   Saved: SZ_patient_SZ_01_segment_159_scalogram_combined.png
#   Processing segment 161/442...
#   Saved: SZ_patient_SZ_02_segment_159_scalogram_combined.png
#   Processing segment 161/353...
#   Saved: SZ_patient_SZ_01_segment_160_scalogram_combined.png
#   Processing segment 162/442...
#   Saved: SZ_patient_SZ_02_segment_160_scalogram_combined.png
#   Processing segment 162/353...
#   Saved: SZ_patient_SZ_01_segment_161_scalogram_combined.png
#   Processing segment 163/442...
#   Saved: SZ_patient_SZ_02_segment_161_scalogram_combined.png
#   Processing segment 163/353...
#   Saved: SZ_patient_SZ_01_segment_162_scalogram_combined.png
#   Processing segment 164/442...
#   Saved: SZ_patient_SZ_02_segment_162_scalogram_combined.png
#   Processing segment 164/353...
#   Saved: SZ_patient_SZ_01_segment_163_scalogram_combined.png
#   Processing segment 165/442...
#   Saved: SZ_patient_SZ_02_segment_163_scalogram_combined.png
#   Processing segment 165/353...
#   Saved: SZ_patient_SZ_01_segment_164_scalogram_combined.png
#   Processing segment 166/442...
#   Saved: SZ_patient_SZ_02_segment_164_scalogram_combined.png
#   Processing segment 166/353...
#   Saved: SZ_patient_SZ_01_segment_165_scalogram_combined.png
#   Processing segment 167/442...
#   Saved: SZ_patient_SZ_02_segment_165_scalogram_combined.png
#   Processing segment 167/353...
#   Saved: SZ_patient_SZ_01_segment_166_scalogram_combined.png
#   Processing segment 168/442...
#   Saved: SZ_patient_SZ_02_segment_166_scalogram_combined.png
#   Processing segment 168/353...
#   Saved: SZ_patient_SZ_01_segment_167_scalogram_combined.png
#   Processing segment 169/442...
#   Saved: SZ_patient_SZ_02_segment_167_scalogram_combined.png
#   Processing segment 169/353...
#   Saved: SZ_patient_SZ_01_segment_168_scalogram_combined.png
#   Processing segment 170/442...
#   Saved: SZ_patient_SZ_02_segment_168_scalogram_combined.png
#   Processing segment 170/353...
#   Saved: SZ_patient_SZ_01_segment_169_scalogram_combined.png
#   Processing segment 171/442...
#   Saved: SZ_patient_SZ_02_segment_169_scalogram_combined.png
#   Processing segment 171/353...
#   Saved: SZ_patient_SZ_01_segment_170_scalogram_combined.png
#   Processing segment 172/442...
#   Saved: SZ_patient_SZ_02_segment_170_scalogram_combined.png
#   Processing segment 172/353...
#   Saved: SZ_patient_SZ_01_segment_171_scalogram_combined.png
#   Processing segment 173/442...
#   Saved: SZ_patient_SZ_02_segment_171_scalogram_combined.png
#   Processing segment 173/353...
#   Saved: SZ_patient_SZ_01_segment_172_scalogram_combined.png
#   Processing segment 174/442...
#   Saved: SZ_patient_SZ_02_segment_172_scalogram_combined.png
#   Processing segment 174/353...
#   Saved: SZ_patient_SZ_01_segment_173_scalogram_combined.png
#   Processing segment 175/442...
#   Saved: SZ_patient_SZ_02_segment_173_scalogram_combined.png
#   Processing segment 175/353...
#   Saved: SZ_patient_SZ_01_segment_174_scalogram_combined.png
#   Processing segment 176/442...
#   Saved: SZ_patient_SZ_02_segment_174_scalogram_combined.png
#   Processing segment 176/353...
#   Saved: SZ_patient_SZ_01_segment_175_scalogram_combined.png
#   Processing segment 177/442...
#   Saved: SZ_patient_SZ_02_segment_175_scalogram_combined.png
#   Processing segment 177/353...
#   Saved: SZ_patient_SZ_01_segment_176_scalogram_combined.png
#   Processing segment 178/442...
#   Saved: SZ_patient_SZ_02_segment_176_scalogram_combined.png
#   Processing segment 178/353...
#   Saved: SZ_patient_SZ_01_segment_177_scalogram_combined.png
#   Processing segment 179/442...
#   Saved: SZ_patient_SZ_02_segment_177_scalogram_combined.png
#   Processing segment 179/353...
#   Saved: SZ_patient_SZ_01_segment_178_scalogram_combined.png
#   Processing segment 180/442...
#   Saved: SZ_patient_SZ_02_segment_178_scalogram_combined.png
#   Processing segment 180/353...
#   Saved: SZ_patient_SZ_01_segment_179_scalogram_combined.png
#   Processing segment 181/442...
#   Saved: SZ_patient_SZ_02_segment_179_scalogram_combined.png
#   Processing segment 181/353...
#   Saved: SZ_patient_SZ_01_segment_180_scalogram_combined.png
#   Processing segment 182/442...
#   Saved: SZ_patient_SZ_02_segment_180_scalogram_combined.png
#   Processing segment 182/353...
#   Saved: SZ_patient_SZ_01_segment_181_scalogram_combined.png
#   Processing segment 183/442...
#   Saved: SZ_patient_SZ_02_segment_181_scalogram_combined.png
#   Processing segment 183/353...
#   Saved: SZ_patient_SZ_01_segment_182_scalogram_combined.png
#   Processing segment 184/442...
#   Saved: SZ_patient_SZ_02_segment_182_scalogram_combined.png
#   Processing segment 184/353...
#   Saved: SZ_patient_SZ_01_segment_183_scalogram_combined.png
#   Processing segment 185/442...
#   Saved: SZ_patient_SZ_02_segment_183_scalogram_combined.png
#   Processing segment 185/353...
#   Saved: SZ_patient_SZ_01_segment_184_scalogram_combined.png
#   Processing segment 186/442...
#   Saved: SZ_patient_SZ_02_segment_184_scalogram_combined.png
#   Processing segment 186/353...
#   Saved: SZ_patient_SZ_01_segment_185_scalogram_combined.png
#   Processing segment 187/442...
#   Saved: SZ_patient_SZ_02_segment_185_scalogram_combined.png
#   Processing segment 187/353...
#   Saved: SZ_patient_SZ_01_segment_186_scalogram_combined.png
#   Processing segment 188/442...
#   Saved: SZ_patient_SZ_02_segment_186_scalogram_combined.png
#   Processing segment 188/353...
#   Saved: SZ_patient_SZ_01_segment_187_scalogram_combined.png
#   Processing segment 189/442...
#   Saved: SZ_patient_SZ_02_segment_187_scalogram_combined.png
#   Processing segment 189/353...
#   Saved: SZ_patient_SZ_01_segment_188_scalogram_combined.png
#   Processing segment 190/442...
#   Saved: SZ_patient_SZ_02_segment_188_scalogram_combined.png
#   Processing segment 190/353...
#   Saved: SZ_patient_SZ_01_segment_189_scalogram_combined.png
#   Processing segment 191/442...
#   Saved: SZ_patient_SZ_02_segment_189_scalogram_combined.png
#   Processing segment 191/353...
#   Saved: SZ_patient_SZ_01_segment_190_scalogram_combined.png
#   Processing segment 192/442...
#   Saved: SZ_patient_SZ_01_segment_191_scalogram_combined.png
#   Processing segment 193/442...
#   Saved: SZ_patient_SZ_02_segment_190_scalogram_combined.png
#   Processing segment 192/353...
#   Saved: SZ_patient_SZ_01_segment_192_scalogram_combined.png
#   Processing segment 194/442...
#   Saved: SZ_patient_SZ_02_segment_191_scalogram_combined.png
#   Processing segment 193/353...
#   Saved: SZ_patient_SZ_01_segment_193_scalogram_combined.png
#   Processing segment 195/442...
#   Saved: SZ_patient_SZ_02_segment_192_scalogram_combined.png
#   Processing segment 194/353...
#   Saved: SZ_patient_SZ_01_segment_194_scalogram_combined.png
#   Processing segment 196/442...
#   Saved: SZ_patient_SZ_02_segment_193_scalogram_combined.png
#   Processing segment 195/353...
#   Saved: SZ_patient_SZ_01_segment_195_scalogram_combined.png
#   Processing segment 197/442...
#   Saved: SZ_patient_SZ_02_segment_194_scalogram_combined.png
#   Processing segment 196/353...
#   Saved: SZ_patient_SZ_01_segment_196_scalogram_combined.png
#   Processing segment 198/442...
#   Saved: SZ_patient_SZ_02_segment_195_scalogram_combined.png
#   Processing segment 197/353...
#   Saved: SZ_patient_SZ_01_segment_197_scalogram_combined.png
#   Processing segment 199/442...
#   Saved: SZ_patient_SZ_02_segment_196_scalogram_combined.png
#   Processing segment 198/353...
#   Saved: SZ_patient_SZ_01_segment_198_scalogram_combined.png
#   Processing segment 200/442...
#   Saved: SZ_patient_SZ_02_segment_197_scalogram_combined.png
#   Processing segment 199/353...
#   Saved: SZ_patient_SZ_01_segment_199_scalogram_combined.png
#   Processing segment 201/442...
#   Saved: SZ_patient_SZ_02_segment_198_scalogram_combined.png
#   Processing segment 200/353...
#   Saved: SZ_patient_SZ_01_segment_200_scalogram_combined.png
#   Processing segment 202/442...
#   Saved: SZ_patient_SZ_02_segment_199_scalogram_combined.png
#   Processing segment 201/353...
#   Saved: SZ_patient_SZ_01_segment_201_scalogram_combined.png
#   Processing segment 203/442...
#   Saved: SZ_patient_SZ_02_segment_200_scalogram_combined.png
#   Processing segment 202/353...
#   Saved: SZ_patient_SZ_01_segment_202_scalogram_combined.png
#   Processing segment 204/442...
#   Saved: SZ_patient_SZ_02_segment_201_scalogram_combined.png
#   Processing segment 203/353...
#   Saved: SZ_patient_SZ_01_segment_203_scalogram_combined.png
#   Processing segment 205/442...
#   Saved: SZ_patient_SZ_02_segment_202_scalogram_combined.png
#   Processing segment 204/353...
#   Saved: SZ_patient_SZ_01_segment_204_scalogram_combined.png
#   Processing segment 206/442...
#   Saved: SZ_patient_SZ_02_segment_203_scalogram_combined.png
#   Processing segment 205/353...
#   Saved: SZ_patient_SZ_01_segment_205_scalogram_combined.png
#   Processing segment 207/442...
#   Saved: SZ_patient_SZ_02_segment_204_scalogram_combined.png
#   Processing segment 206/353...
#   Saved: SZ_patient_SZ_01_segment_206_scalogram_combined.png
#   Processing segment 208/442...
#   Saved: SZ_patient_SZ_02_segment_205_scalogram_combined.png
#   Processing segment 207/353...
#   Saved: SZ_patient_SZ_01_segment_207_scalogram_combined.png
#   Processing segment 209/442...
#   Saved: SZ_patient_SZ_02_segment_206_scalogram_combined.png
#   Processing segment 208/353...
#   Saved: SZ_patient_SZ_01_segment_208_scalogram_combined.png
#   Processing segment 210/442...
#   Saved: SZ_patient_SZ_02_segment_207_scalogram_combined.png
#   Processing segment 209/353...
#   Saved: SZ_patient_SZ_01_segment_209_scalogram_combined.png
#   Processing segment 211/442...
#   Saved: SZ_patient_SZ_02_segment_208_scalogram_combined.png
#   Processing segment 210/353...
#   Saved: SZ_patient_SZ_01_segment_210_scalogram_combined.png
#   Processing segment 212/442...
#   Saved: SZ_patient_SZ_02_segment_209_scalogram_combined.png
#   Processing segment 211/353...
#   Saved: SZ_patient_SZ_01_segment_211_scalogram_combined.png
#   Processing segment 213/442...
#   Saved: SZ_patient_SZ_02_segment_210_scalogram_combined.png
#   Processing segment 212/353...
#   Saved: SZ_patient_SZ_01_segment_212_scalogram_combined.png
#   Processing segment 214/442...
#   Saved: SZ_patient_SZ_02_segment_211_scalogram_combined.png
#   Processing segment 213/353...
#   Saved: SZ_patient_SZ_01_segment_213_scalogram_combined.png
#   Processing segment 215/442...
#   Saved: SZ_patient_SZ_02_segment_212_scalogram_combined.png
#   Processing segment 214/353...
#   Saved: SZ_patient_SZ_01_segment_214_scalogram_combined.png
#   Processing segment 216/442...
#   Saved: SZ_patient_SZ_02_segment_213_scalogram_combined.png
#   Processing segment 215/353...
#   Saved: SZ_patient_SZ_01_segment_215_scalogram_combined.png
#   Processing segment 217/442...
#   Saved: SZ_patient_SZ_02_segment_214_scalogram_combined.png
#   Processing segment 216/353...
#   Saved: SZ_patient_SZ_01_segment_216_scalogram_combined.png
#   Processing segment 218/442...
#   Saved: SZ_patient_SZ_02_segment_215_scalogram_combined.png
#   Processing segment 217/353...
#   Saved: SZ_patient_SZ_01_segment_217_scalogram_combined.png
#   Processing segment 219/442...
#   Saved: SZ_patient_SZ_02_segment_216_scalogram_combined.png
#   Processing segment 218/353...
#   Saved: SZ_patient_SZ_01_segment_218_scalogram_combined.png
#   Processing segment 220/442...
#   Saved: SZ_patient_SZ_02_segment_217_scalogram_combined.png
#   Processing segment 219/353...
#   Saved: SZ_patient_SZ_01_segment_219_scalogram_combined.png
#   Processing segment 221/442...
#   Saved: SZ_patient_SZ_02_segment_218_scalogram_combined.png
#   Processing segment 220/353...
#   Saved: SZ_patient_SZ_01_segment_220_scalogram_combined.png
#   Processing segment 222/442...
#   Saved: SZ_patient_SZ_02_segment_219_scalogram_combined.png
#   Processing segment 221/353...
#   Saved: SZ_patient_SZ_01_segment_221_scalogram_combined.png
#   Processing segment 223/442...
#   Saved: SZ_patient_SZ_02_segment_220_scalogram_combined.png
#   Processing segment 222/353...
#   Saved: SZ_patient_SZ_01_segment_222_scalogram_combined.png
#   Processing segment 224/442...
#   Saved: SZ_patient_SZ_02_segment_221_scalogram_combined.png
#   Processing segment 223/353...
#   Saved: SZ_patient_SZ_01_segment_223_scalogram_combined.png
#   Processing segment 225/442...
#   Saved: SZ_patient_SZ_02_segment_222_scalogram_combined.png
#   Processing segment 224/353...
#   Saved: SZ_patient_SZ_01_segment_224_scalogram_combined.png
#   Processing segment 226/442...
#   Saved: SZ_patient_SZ_02_segment_223_scalogram_combined.png
#   Processing segment 225/353...
#   Saved: SZ_patient_SZ_01_segment_225_scalogram_combined.png
#   Processing segment 227/442...
#   Saved: SZ_patient_SZ_02_segment_224_scalogram_combined.png
#   Processing segment 226/353...
#   Saved: SZ_patient_SZ_01_segment_226_scalogram_combined.png
#   Processing segment 228/442...
#   Saved: SZ_patient_SZ_02_segment_225_scalogram_combined.png
#   Processing segment 227/353...
#   Saved: SZ_patient_SZ_01_segment_227_scalogram_combined.png
#   Processing segment 229/442...
#   Saved: SZ_patient_SZ_02_segment_226_scalogram_combined.png
#   Processing segment 228/353...
#   Saved: SZ_patient_SZ_01_segment_228_scalogram_combined.png
#   Processing segment 230/442...
#   Saved: SZ_patient_SZ_02_segment_227_scalogram_combined.png
#   Processing segment 229/353...
#   Saved: SZ_patient_SZ_01_segment_229_scalogram_combined.png
#   Processing segment 231/442...
#   Saved: SZ_patient_SZ_02_segment_228_scalogram_combined.png
#   Processing segment 230/353...
#   Saved: SZ_patient_SZ_01_segment_230_scalogram_combined.png
#   Processing segment 232/442...
#   Saved: SZ_patient_SZ_02_segment_229_scalogram_combined.png
#   Processing segment 231/353...
#   Saved: SZ_patient_SZ_01_segment_231_scalogram_combined.png
#   Processing segment 233/442...
#   Saved: SZ_patient_SZ_02_segment_230_scalogram_combined.png
#   Processing segment 232/353...
#   Saved: SZ_patient_SZ_01_segment_232_scalogram_combined.png
#   Processing segment 234/442...
#   Saved: SZ_patient_SZ_02_segment_231_scalogram_combined.png
#   Processing segment 233/353...
#   Saved: SZ_patient_SZ_01_segment_233_scalogram_combined.png
#   Processing segment 235/442...
#   Saved: SZ_patient_SZ_02_segment_232_scalogram_combined.png
#   Processing segment 234/353...
#   Saved: SZ_patient_SZ_01_segment_234_scalogram_combined.png
#   Processing segment 236/442...
#   Saved: SZ_patient_SZ_02_segment_233_scalogram_combined.png
#   Processing segment 235/353...
#   Saved: SZ_patient_SZ_01_segment_235_scalogram_combined.png
#   Processing segment 237/442...
#   Saved: SZ_patient_SZ_02_segment_234_scalogram_combined.png
#   Processing segment 236/353...
#   Saved: SZ_patient_SZ_01_segment_236_scalogram_combined.png
#   Processing segment 238/442...
#   Saved: SZ_patient_SZ_02_segment_235_scalogram_combined.png
#   Processing segment 237/353...
#   Saved: SZ_patient_SZ_01_segment_237_scalogram_combined.png
#   Processing segment 239/442...
#   Saved: SZ_patient_SZ_01_segment_238_scalogram_combined.png
#   Processing segment 240/442...
#   Saved: SZ_patient_SZ_02_segment_236_scalogram_combined.png
#   Processing segment 238/353...
#   Saved: SZ_patient_SZ_01_segment_239_scalogram_combined.png
#   Processing segment 241/442...
#   Saved: SZ_patient_SZ_02_segment_237_scalogram_combined.png
#   Processing segment 239/353...
#   Saved: SZ_patient_SZ_01_segment_240_scalogram_combined.png
#   Processing segment 242/442...
#   Saved: SZ_patient_SZ_02_segment_238_scalogram_combined.png
#   Processing segment 240/353...
#   Saved: SZ_patient_SZ_01_segment_241_scalogram_combined.png
#   Processing segment 243/442...
#   Saved: SZ_patient_SZ_02_segment_239_scalogram_combined.png
#   Processing segment 241/353...
#   Saved: SZ_patient_SZ_01_segment_242_scalogram_combined.png
#   Processing segment 244/442...
#   Saved: SZ_patient_SZ_02_segment_240_scalogram_combined.png
#   Processing segment 242/353...
#   Saved: SZ_patient_SZ_01_segment_243_scalogram_combined.png
#   Processing segment 245/442...
#   Saved: SZ_patient_SZ_02_segment_241_scalogram_combined.png
#   Processing segment 243/353...
#   Saved: SZ_patient_SZ_01_segment_244_scalogram_combined.png
#   Processing segment 246/442...
#   Saved: SZ_patient_SZ_02_segment_242_scalogram_combined.png
#   Processing segment 244/353...
#   Saved: SZ_patient_SZ_01_segment_245_scalogram_combined.png
#   Processing segment 247/442...
#   Saved: SZ_patient_SZ_02_segment_243_scalogram_combined.png
#   Processing segment 245/353...
#   Saved: SZ_patient_SZ_01_segment_246_scalogram_combined.png
#   Processing segment 248/442...
#   Saved: SZ_patient_SZ_02_segment_244_scalogram_combined.png
#   Processing segment 246/353...
#   Saved: SZ_patient_SZ_01_segment_247_scalogram_combined.png
#   Processing segment 249/442...
#   Saved: SZ_patient_SZ_02_segment_245_scalogram_combined.png
#   Processing segment 247/353...
#   Saved: SZ_patient_SZ_01_segment_248_scalogram_combined.png
#   Processing segment 250/442...
#   Saved: SZ_patient_SZ_02_segment_246_scalogram_combined.png
#   Processing segment 248/353...
#   Saved: SZ_patient_SZ_01_segment_249_scalogram_combined.png
#   Processing segment 251/442...
#   Saved: SZ_patient_SZ_02_segment_247_scalogram_combined.png
#   Processing segment 249/353...
#   Saved: SZ_patient_SZ_01_segment_250_scalogram_combined.png
#   Processing segment 252/442...
#   Saved: SZ_patient_SZ_02_segment_248_scalogram_combined.png
#   Processing segment 250/353...
#   Saved: SZ_patient_SZ_01_segment_251_scalogram_combined.png
#   Processing segment 253/442...
#   Saved: SZ_patient_SZ_02_segment_249_scalogram_combined.png
#   Processing segment 251/353...
#   Saved: SZ_patient_SZ_01_segment_252_scalogram_combined.png
#   Processing segment 254/442...
#   Saved: SZ_patient_SZ_02_segment_250_scalogram_combined.png
#   Processing segment 252/353...
#   Saved: SZ_patient_SZ_01_segment_253_scalogram_combined.png
#   Processing segment 255/442...
#   Saved: SZ_patient_SZ_02_segment_251_scalogram_combined.png
#   Processing segment 253/353...
#   Saved: SZ_patient_SZ_01_segment_254_scalogram_combined.png
#   Processing segment 256/442...
#   Saved: SZ_patient_SZ_02_segment_252_scalogram_combined.png
#   Processing segment 254/353...
#   Saved: SZ_patient_SZ_01_segment_255_scalogram_combined.png
#   Processing segment 257/442...
#   Saved: SZ_patient_SZ_02_segment_253_scalogram_combined.png
#   Processing segment 255/353...
#   Saved: SZ_patient_SZ_01_segment_256_scalogram_combined.png
#   Processing segment 258/442...
#   Saved: SZ_patient_SZ_02_segment_254_scalogram_combined.png
#   Processing segment 256/353...
#   Saved: SZ_patient_SZ_01_segment_257_scalogram_combined.png
#   Processing segment 259/442...
#   Saved: SZ_patient_SZ_02_segment_255_scalogram_combined.png
#   Processing segment 257/353...
#   Saved: SZ_patient_SZ_01_segment_258_scalogram_combined.png
#   Processing segment 260/442...
#   Saved: SZ_patient_SZ_02_segment_256_scalogram_combined.png
#   Processing segment 258/353...
#   Saved: SZ_patient_SZ_01_segment_259_scalogram_combined.png
#   Processing segment 261/442...
#   Saved: SZ_patient_SZ_02_segment_257_scalogram_combined.png
#   Processing segment 259/353...
#   Saved: SZ_patient_SZ_01_segment_260_scalogram_combined.png
#   Processing segment 262/442...
#   Saved: SZ_patient_SZ_02_segment_258_scalogram_combined.png
#   Processing segment 260/353...
#   Saved: SZ_patient_SZ_01_segment_261_scalogram_combined.png
#   Processing segment 263/442...
#   Saved: SZ_patient_SZ_02_segment_259_scalogram_combined.png
#   Processing segment 261/353...
#   Saved: SZ_patient_SZ_01_segment_262_scalogram_combined.png
#   Processing segment 264/442...
#   Saved: SZ_patient_SZ_02_segment_260_scalogram_combined.png
#   Processing segment 262/353...
#   Saved: SZ_patient_SZ_01_segment_263_scalogram_combined.png
#   Processing segment 265/442...
#   Saved: SZ_patient_SZ_02_segment_261_scalogram_combined.png
#   Processing segment 263/353...
#   Saved: SZ_patient_SZ_01_segment_264_scalogram_combined.png
#   Processing segment 266/442...
#   Saved: SZ_patient_SZ_02_segment_262_scalogram_combined.png
#   Processing segment 264/353...
#   Saved: SZ_patient_SZ_01_segment_265_scalogram_combined.png
#   Processing segment 267/442...
#   Saved: SZ_patient_SZ_02_segment_263_scalogram_combined.png
#   Processing segment 265/353...
#   Saved: SZ_patient_SZ_01_segment_266_scalogram_combined.png
#   Processing segment 268/442...
#   Saved: SZ_patient_SZ_02_segment_264_scalogram_combined.png
#   Processing segment 266/353...
#   Saved: SZ_patient_SZ_01_segment_267_scalogram_combined.png
#   Processing segment 269/442...
#   Saved: SZ_patient_SZ_02_segment_265_scalogram_combined.png
#   Processing segment 267/353...
#   Saved: SZ_patient_SZ_01_segment_268_scalogram_combined.png
#   Processing segment 270/442...
#   Saved: SZ_patient_SZ_02_segment_266_scalogram_combined.png
#   Processing segment 268/353...
#   Saved: SZ_patient_SZ_01_segment_269_scalogram_combined.png
#   Processing segment 271/442...
#   Saved: SZ_patient_SZ_02_segment_267_scalogram_combined.png
#   Processing segment 269/353...
#   Saved: SZ_patient_SZ_01_segment_270_scalogram_combined.png
#   Processing segment 272/442...
#   Saved: SZ_patient_SZ_02_segment_268_scalogram_combined.png
#   Processing segment 270/353...
#   Saved: SZ_patient_SZ_01_segment_271_scalogram_combined.png
#   Processing segment 273/442...
#   Saved: SZ_patient_SZ_02_segment_269_scalogram_combined.png
#   Processing segment 271/353...
#   Saved: SZ_patient_SZ_01_segment_272_scalogram_combined.png
#   Processing segment 274/442...
#   Saved: SZ_patient_SZ_02_segment_270_scalogram_combined.png
#   Processing segment 272/353...
#   Saved: SZ_patient_SZ_01_segment_273_scalogram_combined.png
#   Processing segment 275/442...
#   Saved: SZ_patient_SZ_02_segment_271_scalogram_combined.png
#   Processing segment 273/353...
#   Saved: SZ_patient_SZ_01_segment_274_scalogram_combined.png
#   Processing segment 276/442...
#   Saved: SZ_patient_SZ_02_segment_272_scalogram_combined.png
#   Processing segment 274/353...
#   Saved: SZ_patient_SZ_01_segment_275_scalogram_combined.png
#   Processing segment 277/442...
#   Saved: SZ_patient_SZ_02_segment_273_scalogram_combined.png
#   Processing segment 275/353...
#   Saved: SZ_patient_SZ_01_segment_276_scalogram_combined.png
#   Processing segment 278/442...
#   Saved: SZ_patient_SZ_02_segment_274_scalogram_combined.png
#   Processing segment 276/353...
#   Saved: SZ_patient_SZ_01_segment_277_scalogram_combined.png
#   Processing segment 279/442...
#   Saved: SZ_patient_SZ_02_segment_275_scalogram_combined.png
#   Processing segment 277/353...
#   Saved: SZ_patient_SZ_01_segment_278_scalogram_combined.png
#   Processing segment 280/442...
#   Saved: SZ_patient_SZ_02_segment_276_scalogram_combined.png
#   Processing segment 278/353...
#   Saved: SZ_patient_SZ_01_segment_279_scalogram_combined.png
#   Processing segment 281/442...
#   Saved: SZ_patient_SZ_02_segment_277_scalogram_combined.png
#   Processing segment 279/353...
#   Saved: SZ_patient_SZ_01_segment_280_scalogram_combined.png
#   Processing segment 282/442...
#   Saved: SZ_patient_SZ_02_segment_278_scalogram_combined.png
#   Processing segment 280/353...
#   Saved: SZ_patient_SZ_01_segment_281_scalogram_combined.png
#   Processing segment 283/442...
#   Saved: SZ_patient_SZ_02_segment_279_scalogram_combined.png
#   Processing segment 281/353...
#   Saved: SZ_patient_SZ_01_segment_282_scalogram_combined.png
#   Processing segment 284/442...
#   Saved: SZ_patient_SZ_02_segment_280_scalogram_combined.png
#   Processing segment 282/353...
#   Saved: SZ_patient_SZ_01_segment_283_scalogram_combined.png
#   Processing segment 285/442...
#   Saved: SZ_patient_SZ_02_segment_281_scalogram_combined.png
#   Processing segment 283/353...
#   Saved: SZ_patient_SZ_01_segment_284_scalogram_combined.png
#   Processing segment 286/442...
#   Saved: SZ_patient_SZ_02_segment_282_scalogram_combined.png
#   Processing segment 284/353...
#   Saved: SZ_patient_SZ_01_segment_285_scalogram_combined.png
#   Processing segment 287/442...
#   Saved: SZ_patient_SZ_02_segment_283_scalogram_combined.png
#   Processing segment 285/353...
#   Saved: SZ_patient_SZ_01_segment_286_scalogram_combined.png
#   Processing segment 288/442...
#   Saved: SZ_patient_SZ_02_segment_284_scalogram_combined.png
#   Processing segment 286/353...
#   Saved: SZ_patient_SZ_01_segment_287_scalogram_combined.png
#   Processing segment 289/442...
#   Saved: SZ_patient_SZ_02_segment_285_scalogram_combined.png
#   Processing segment 287/353...
#   Saved: SZ_patient_SZ_01_segment_288_scalogram_combined.png
#   Processing segment 290/442...
#   Saved: SZ_patient_SZ_02_segment_286_scalogram_combined.png
#   Processing segment 288/353...
#   Saved: SZ_patient_SZ_01_segment_289_scalogram_combined.png
#   Processing segment 291/442...
#   Saved: SZ_patient_SZ_02_segment_287_scalogram_combined.png
#   Processing segment 289/353...
#   Saved: SZ_patient_SZ_01_segment_290_scalogram_combined.png
#   Processing segment 292/442...
#   Saved: SZ_patient_SZ_02_segment_288_scalogram_combined.png
#   Processing segment 290/353...
#   Saved: SZ_patient_SZ_01_segment_291_scalogram_combined.png
#   Processing segment 293/442...
#   Saved: SZ_patient_SZ_02_segment_289_scalogram_combined.png
#   Processing segment 291/353...
#   Saved: SZ_patient_SZ_01_segment_292_scalogram_combined.png
#   Processing segment 294/442...
#   Saved: SZ_patient_SZ_02_segment_290_scalogram_combined.png
#   Processing segment 292/353...
#   Saved: SZ_patient_SZ_01_segment_293_scalogram_combined.png
#   Processing segment 295/442...
#   Saved: SZ_patient_SZ_02_segment_291_scalogram_combined.png
#   Processing segment 293/353...
#   Saved: SZ_patient_SZ_01_segment_294_scalogram_combined.png
#   Processing segment 296/442...
#   Saved: SZ_patient_SZ_02_segment_292_scalogram_combined.png
#   Processing segment 294/353...
#   Saved: SZ_patient_SZ_01_segment_295_scalogram_combined.png
#   Processing segment 297/442...
#   Saved: SZ_patient_SZ_02_segment_293_scalogram_combined.png
#   Processing segment 295/353...
#   Saved: SZ_patient_SZ_01_segment_296_scalogram_combined.png
#   Processing segment 298/442...
#   Saved: SZ_patient_SZ_02_segment_294_scalogram_combined.png
#   Processing segment 296/353...
#   Saved: SZ_patient_SZ_01_segment_297_scalogram_combined.png
#   Processing segment 299/442...
#   Saved: SZ_patient_SZ_02_segment_295_scalogram_combined.png
#   Processing segment 297/353...
#   Saved: SZ_patient_SZ_01_segment_298_scalogram_combined.png
#   Processing segment 300/442...
#   Saved: SZ_patient_SZ_02_segment_296_scalogram_combined.png
#   Processing segment 298/353...
#   Saved: SZ_patient_SZ_01_segment_299_scalogram_combined.png
#   Processing segment 301/442...
#   Saved: SZ_patient_SZ_02_segment_297_scalogram_combined.png
#   Processing segment 299/353...
#   Saved: SZ_patient_SZ_01_segment_300_scalogram_combined.png
#   Processing segment 302/442...
#   Saved: SZ_patient_SZ_02_segment_298_scalogram_combined.png
#   Processing segment 300/353...
#   Saved: SZ_patient_SZ_01_segment_301_scalogram_combined.png
#   Processing segment 303/442...
#   Saved: SZ_patient_SZ_02_segment_299_scalogram_combined.png
#   Processing segment 301/353...
#   Saved: SZ_patient_SZ_01_segment_302_scalogram_combined.png
#   Processing segment 304/442...
#   Saved: SZ_patient_SZ_02_segment_300_scalogram_combined.png
#   Processing segment 302/353...
#   Saved: SZ_patient_SZ_01_segment_303_scalogram_combined.png
#   Processing segment 305/442...
#   Saved: SZ_patient_SZ_02_segment_301_scalogram_combined.png
#   Processing segment 303/353...
#   Saved: SZ_patient_SZ_01_segment_304_scalogram_combined.png
#   Processing segment 306/442...
#   Saved: SZ_patient_SZ_02_segment_302_scalogram_combined.png
#   Processing segment 304/353...
#   Saved: SZ_patient_SZ_01_segment_305_scalogram_combined.png
#   Processing segment 307/442...
#   Saved: SZ_patient_SZ_02_segment_303_scalogram_combined.png
#   Processing segment 305/353...
#   Saved: SZ_patient_SZ_01_segment_306_scalogram_combined.png
#   Processing segment 308/442...
#   Saved: SZ_patient_SZ_01_segment_307_scalogram_combined.png
#   Processing segment 309/442...
#   Saved: SZ_patient_SZ_02_segment_304_scalogram_combined.png
#   Processing segment 306/353...
#   Saved: SZ_patient_SZ_01_segment_308_scalogram_combined.png
#   Processing segment 310/442...
#   Saved: SZ_patient_SZ_02_segment_305_scalogram_combined.png
#   Processing segment 307/353...
#   Saved: SZ_patient_SZ_01_segment_309_scalogram_combined.png
#   Processing segment 311/442...
#   Saved: SZ_patient_SZ_02_segment_306_scalogram_combined.png
#   Processing segment 308/353...
#   Saved: SZ_patient_SZ_01_segment_310_scalogram_combined.png
#   Processing segment 312/442...
#   Saved: SZ_patient_SZ_02_segment_307_scalogram_combined.png
#   Processing segment 309/353...
#   Saved: SZ_patient_SZ_01_segment_311_scalogram_combined.png
#   Processing segment 313/442...
#   Saved: SZ_patient_SZ_02_segment_308_scalogram_combined.png
#   Processing segment 310/353...
#   Saved: SZ_patient_SZ_01_segment_312_scalogram_combined.png
#   Processing segment 314/442...
#   Saved: SZ_patient_SZ_02_segment_309_scalogram_combined.png
#   Processing segment 311/353...
#   Saved: SZ_patient_SZ_01_segment_313_scalogram_combined.png
#   Processing segment 315/442...
#   Saved: SZ_patient_SZ_02_segment_310_scalogram_combined.png
#   Processing segment 312/353...
#   Saved: SZ_patient_SZ_01_segment_314_scalogram_combined.png
#   Processing segment 316/442...
#   Saved: SZ_patient_SZ_02_segment_311_scalogram_combined.png
#   Processing segment 313/353...
#   Saved: SZ_patient_SZ_01_segment_315_scalogram_combined.png
#   Processing segment 317/442...
#   Saved: SZ_patient_SZ_02_segment_312_scalogram_combined.png
#   Processing segment 314/353...
#   Saved: SZ_patient_SZ_01_segment_316_scalogram_combined.png
#   Processing segment 318/442...
#   Saved: SZ_patient_SZ_02_segment_313_scalogram_combined.png
#   Processing segment 315/353...
#   Saved: SZ_patient_SZ_01_segment_317_scalogram_combined.png
#   Processing segment 319/442...
#   Saved: SZ_patient_SZ_02_segment_314_scalogram_combined.png
#   Processing segment 316/353...
#   Saved: SZ_patient_SZ_01_segment_318_scalogram_combined.png
#   Processing segment 320/442...
#   Saved: SZ_patient_SZ_02_segment_315_scalogram_combined.png
#   Processing segment 317/353...
#   Saved: SZ_patient_SZ_01_segment_319_scalogram_combined.png
#   Processing segment 321/442...
#   Saved: SZ_patient_SZ_02_segment_316_scalogram_combined.png
#   Processing segment 318/353...
#   Saved: SZ_patient_SZ_01_segment_320_scalogram_combined.png
#   Processing segment 322/442...
#   Saved: SZ_patient_SZ_02_segment_317_scalogram_combined.png
#   Processing segment 319/353...
#   Saved: SZ_patient_SZ_01_segment_321_scalogram_combined.png
#   Processing segment 323/442...
#   Saved: SZ_patient_SZ_02_segment_318_scalogram_combined.png
#   Processing segment 320/353...
#   Saved: SZ_patient_SZ_01_segment_322_scalogram_combined.png
#   Processing segment 324/442...
#   Saved: SZ_patient_SZ_02_segment_319_scalogram_combined.png
#   Processing segment 321/353...
#   Saved: SZ_patient_SZ_01_segment_323_scalogram_combined.png
#   Processing segment 325/442...
#   Saved: SZ_patient_SZ_02_segment_320_scalogram_combined.png
#   Processing segment 322/353...
#   Saved: SZ_patient_SZ_01_segment_324_scalogram_combined.png
#   Processing segment 326/442...
#   Saved: SZ_patient_SZ_02_segment_321_scalogram_combined.png
#   Processing segment 323/353...
#   Saved: SZ_patient_SZ_01_segment_325_scalogram_combined.png
#   Processing segment 327/442...
#   Saved: SZ_patient_SZ_02_segment_322_scalogram_combined.png
#   Processing segment 324/353...
#   Saved: SZ_patient_SZ_01_segment_326_scalogram_combined.png
#   Processing segment 328/442...
#   Saved: SZ_patient_SZ_02_segment_323_scalogram_combined.png
#   Processing segment 325/353...
#   Saved: SZ_patient_SZ_01_segment_327_scalogram_combined.png
#   Processing segment 329/442...
#   Saved: SZ_patient_SZ_02_segment_324_scalogram_combined.png
#   Processing segment 326/353...
#   Saved: SZ_patient_SZ_01_segment_328_scalogram_combined.png
#   Processing segment 330/442...
#   Saved: SZ_patient_SZ_02_segment_325_scalogram_combined.png
#   Processing segment 327/353...
#   Saved: SZ_patient_SZ_01_segment_329_scalogram_combined.png
#   Processing segment 331/442...
#   Saved: SZ_patient_SZ_02_segment_326_scalogram_combined.png
#   Processing segment 328/353...
#   Saved: SZ_patient_SZ_01_segment_330_scalogram_combined.png
#   Processing segment 332/442...
#   Saved: SZ_patient_SZ_02_segment_327_scalogram_combined.png
#   Processing segment 329/353...
#   Saved: SZ_patient_SZ_01_segment_331_scalogram_combined.png
#   Processing segment 333/442...
#   Saved: SZ_patient_SZ_02_segment_328_scalogram_combined.png
#   Processing segment 330/353...
#   Saved: SZ_patient_SZ_01_segment_332_scalogram_combined.png
#   Processing segment 334/442...
#   Saved: SZ_patient_SZ_02_segment_329_scalogram_combined.png
#   Processing segment 331/353...
