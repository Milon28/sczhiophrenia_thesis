# %%
import os
import numpy as np
import pandas as pd
import matplotlib
matplotlib.use('Agg')  # Set backend before importing pyplot
import matplotlib.pyplot as plt
from scipy import signal
from scipy.signal import butter, sosfiltfilt, hilbert
from PyEMD import EMD, EEMD
from concurrent.futures import ThreadPoolExecutor, as_completed
import multiprocessing as mp
from functools import partial
import warnings
import traceback
import gc
from sklearn.preprocessing import MinMaxScaler
warnings.filterwarnings('ignore')

class OptimizedEEGHilbertSpectrumGenerator:
    def __init__(self, sz_input_dir, hc_input_dir, output_dir, sampling_rate=256, n_jobs=None):
        """
        Initialize the Optimized EEG Hilbert Spectrum Generator using Hilbert-Huang Transform (HHT)
        
        Parameters:
        sz_input_dir (str): Directory containing CSV files with Schizophrenia EEG data
        hc_input_dir (str): Directory containing CSV files with Healthy Control EEG data
        output_dir (str): Root directory to save Hilbert spectrum images
        sampling_rate (int): EEG sampling rate in Hz (default: 256 Hz)
        n_jobs (int): Number of parallel threads (default: CPU count)
        """
        self.sz_input_dir = sz_input_dir
        self.hc_input_dir = hc_input_dir
        self.output_dir = output_dir
        self.sampling_rate = sampling_rate
        self.segment_duration = 3  # 3 seconds
        self.segment_samples = self.sampling_rate * self.segment_duration
        
        # Set number of parallel jobs (using threads instead of processes)
        if n_jobs is None:
            self.n_jobs = min(mp.cpu_count(), 6)  # Cap at 6 to avoid memory issues
        else:
            self.n_jobs = min(n_jobs, 6)
        
        # HHT parameters
        self.freq_min = 0.5   # Minimum frequency (Hz)
        self.freq_max = 32    # Maximum frequency (Hz)
        self.freq_bins = 100  # Number of frequency bins for Hilbert spectrum
        self.max_imfs = 8     # Maximum number of IMFs to extract
        
        # EMD parameters
        self.emd_trials = 50  # Number of trials for EEMD (Ensemble EMD)
        self.noise_std = 0.2  # Standard deviation of added noise for EEMD
        
        # Pre-compute frequency bins for Hilbert spectrum
        self.freq_bins_array = np.linspace(self.freq_min, self.freq_max, self.freq_bins, dtype=np.float32)
        
        # Pre-compute filter coefficients (SOS format for stability and speed)
        self.filter_sos = self._precompute_filter()
        
        # Create output directories
        self.sz_dir = os.path.join(output_dir, 'Schizophrenia_HHT')
        self.hc_dir = os.path.join(output_dir, 'HealthyControl_HHT')
        os.makedirs(self.sz_dir, exist_ok=True)
        os.makedirs(self.hc_dir, exist_ok=True)
        
        print(f"Initialized HHT Generator with {self.n_jobs} parallel threads")
        print(f"Frequency range: {self.freq_min}-{self.freq_max} Hz with {self.freq_bins} bins")
        
    def _precompute_filter(self):
        """Pre-compute bandpass filter coefficients for reuse"""
        nyquist = 0.5 * self.sampling_rate
        low = self.freq_min / nyquist
        high = self.freq_max / nyquist
        sos = signal.butter(4, [low, high], btype='band', output='sos')
        return sos
    
    def bandpass_filter_optimized(self, data):
        """
        Apply pre-computed bandpass filter to EEG data (optimized version)
        """
        # Use SOS format for better numerical stability and speed
        filtered_data = sosfiltfilt(self.filter_sos, data, axis=0)
        return filtered_data.astype(np.float32)
    
    def segment_signal_vectorized(self, data):
        """
        Vectorized segmentation of EEG signal into 3-second windows
        """
        n_samples, n_channels = data.shape
        n_segments = n_samples // self.segment_samples
        
        if n_segments == 0:
            return []
        
        # Reshape for vectorized processing
        valid_samples = n_segments * self.segment_samples
        reshaped_data = data[:valid_samples, :].reshape(n_segments, self.segment_samples, n_channels)
        
        # Convert to list of segments
        segments = [segment.astype(np.float32) for segment in reshaped_data]
        return segments
    
    def emd_decomposition(self, signal_data, use_eemd=True):
        """
        Perform Empirical Mode Decomposition (EMD) or Ensemble EMD (EEMD)
        
        Parameters:
        signal_data: 1D array of EEG signal
        use_eemd: Whether to use Ensemble EMD (more robust but slower)
        
        Returns:
        imfs: Array of Intrinsic Mode Functions
        """
        try:
            if use_eemd:
                # Use Ensemble EMD for better decomposition
                eemd = EEMD(trials=self.emd_trials, noise_std=self.noise_std)
                imfs = eemd.eemd(signal_data, max_imf=self.max_imfs)
            else:
                # Use standard EMD
                emd = EMD()
                imfs = emd.emd(signal_data, max_imf=self.max_imfs)
            
            return imfs.astype(np.float32)
            
        except Exception as e:
            print(f"EMD decomposition error: {e}")
            # Return original signal as single IMF if decomposition fails
            return np.array([signal_data], dtype=np.float32)
    
    def compute_instantaneous_frequency(self, imf):
        """
        Compute instantaneous frequency and amplitude using Hilbert Transform
        
        Parameters:
        imf: Intrinsic Mode Function (1D array)
        
        Returns:
        inst_freq: Instantaneous frequency array
        inst_amp: Instantaneous amplitude array
        """
        try:
            # Apply Hilbert transform
            analytic_signal = hilbert(imf)
            
            # Compute instantaneous amplitude
            inst_amp = np.abs(analytic_signal)
            
            # Compute instantaneous phase
            inst_phase = np.angle(analytic_signal)
            
            # Compute instantaneous frequency (derivative of phase)
            inst_freq = np.diff(np.unwrap(inst_phase)) * self.sampling_rate / (2 * np.pi)
            
            # Pad to maintain same length
            inst_freq = np.concatenate([[inst_freq[0]], inst_freq])
            
            # Remove negative frequencies and outliers
            inst_freq = np.abs(inst_freq)
            inst_freq = np.clip(inst_freq, self.freq_min, self.freq_max)
            
            return inst_freq.astype(np.float32), inst_amp.astype(np.float32)
            
        except Exception as e:
            print(f"Instantaneous frequency computation error: {e}")
            # Return zero arrays if computation fails
            return (np.zeros(len(imf), dtype=np.float32), 
                   np.zeros(len(imf), dtype=np.float32))
    
    def create_hilbert_spectrum(self, imfs):
        """
        Create Hilbert Spectrum from IMFs
        
        Parameters:
        imfs: Array of Intrinsic Mode Functions
        
        Returns:
        hilbert_spectrum: 2D array (frequency_bins x time_samples)
        time_axis: Time axis for the spectrum
        """
        try:
            n_samples = imfs.shape[1]
            time_axis = np.linspace(0, self.segment_duration, n_samples, dtype=np.float32)
            
            # Initialize Hilbert spectrum
            hilbert_spectrum = np.zeros((len(self.freq_bins_array), n_samples), dtype=np.float32)
            
            # Process each IMF
            for imf in imfs:
                if len(imf) == 0:
                    continue
                    
                # Compute instantaneous frequency and amplitude
                inst_freq, inst_amp = self.compute_instantaneous_frequency(imf)
                
                # Map instantaneous frequency to frequency bins
                for t in range(len(inst_freq)):
                    freq_val = inst_freq[t]
                    amp_val = inst_amp[t]
                    
                    # Find closest frequency bin
                    freq_idx = np.argmin(np.abs(self.freq_bins_array - freq_val))
                    
                    # Add amplitude to Hilbert spectrum
                    hilbert_spectrum[freq_idx, t] += amp_val
            
            # Convert to power spectrum (square of amplitude)
            power_spectrum = hilbert_spectrum ** 2
            
            # Convert to dB scale with error handling
            power_spectrum_db = 10 * np.log10(np.maximum(power_spectrum, 1e-12))
            
            return power_spectrum_db, time_axis
            
        except Exception as e:
            print(f"Hilbert spectrum creation error: {e}")
            # Return zero spectrum if computation fails
            n_samples = imfs.shape[1] if len(imfs) > 0 else self.segment_samples
            time_axis = np.linspace(0, self.segment_duration, n_samples, dtype=np.float32)
            return (np.zeros((len(self.freq_bins_array), n_samples), dtype=np.float32), 
                   time_axis)
    
    def compute_hht_spectrum_optimized(self, signal_data):
        """
        Optimized HHT computation for a single channel
        
        Parameters:
        signal_data: 1D EEG signal array
        
        Returns:
        hilbert_spectrum: 2D Hilbert spectrum (frequency x time)
        time_axis: Time axis
        """
        try:
            # Normalize signal to improve EMD stability
            signal_normalized = (signal_data - np.mean(signal_data)) / (np.std(signal_data) + 1e-8)
            
            # Perform EMD decomposition
            imfs = self.emd_decomposition(signal_normalized, use_eemd=True)
            
            # Create Hilbert spectrum
            hilbert_spectrum, time_axis = self.create_hilbert_spectrum(imfs)
            
            return hilbert_spectrum, time_axis
            
        except Exception as e:
            print(f"HHT spectrum computation error: {e}")
            # Return zero spectrum if computation fails
            time_axis = np.linspace(0, self.segment_duration, len(signal_data), dtype=np.float32)
            return (np.zeros((len(self.freq_bins_array), len(signal_data)), dtype=np.float32), 
                   time_axis)
    
    def create_combined_hilbert_spectrum_safe(self, segment, patient_id, segment_idx, label):
        """
        Safe version of Hilbert spectrum creation with proper error handling
        """
        try:
            # Compute HHT for all channels
            spectra = []
            time_axes = []
            
            for ch in range(segment.shape[1]):
                spectrum, time_axis = self.compute_hht_spectrum_optimized(segment[:, ch])
                spectra.append(spectrum)
                time_axes.append(time_axis)
            
            # Average across all channels
            avg_spectrum = np.mean(spectra, axis=0, dtype=np.float32)
            avg_time_axis = time_axes[0]  # All time axes should be the same
            
            # Create figure with explicit cleanup
            plt.ioff()  # Turn off interactive mode
            fig, ax = plt.subplots(figsize=(12, 8), dpi=150)
            
            try:
                # Create the Hilbert spectrum plot
                im = ax.imshow(
                    avg_spectrum, 
                    aspect='auto', 
                    origin='lower',
                    extent=[avg_time_axis[0], avg_time_axis[-1], 
                           self.freq_bins_array[0], self.freq_bins_array[-1]],
                    cmap='jet',  # 'jet' colormap often works well for Hilbert spectra
                    interpolation='bilinear'
                )
                
                # Remove all captions - just the plot
                ax.set_xticks([])
                ax.set_yticks([])
                ax.set_ylim(self.freq_min, self.freq_max)
                ax.axis('off')
                
                # Determine save directory and filename
                save_dir = self.sz_dir if label == 'SZ' else self.hc_dir
                filename = f'{label}_patient_{patient_id}_segment_{segment_idx:03d}_hilbert_spectrum.png'
                filepath = os.path.join(save_dir, filename)
                
                # Save with error handling
                plt.savefig(filepath, dpi=150, bbox_inches='tight', facecolor='white', 
                           format='png')
                
                return filepath
                
            finally:
                plt.close(fig)  # Always close the figure
                plt.clf()       # Clear any remaining plots
                gc.collect()    # Force garbage collection
                
        except Exception as e:
            print(f"Error creating Hilbert spectrum for {patient_id} segment {segment_idx}: {e}")
            return None
    
    def process_patient_file_safe(self, csv_file, patient_id, label):
        """
        Safe version of patient file processing with comprehensive error handling
        """
        print(f"Processing {label} Patient {patient_id}...")
        
        try:
            # Load EEG data with error handling
            try:
                data = pd.read_csv(csv_file, dtype=np.float32)
                eeg_data = data.values.astype(np.float32)
            except Exception as e:
                print(f"Error loading CSV file {csv_file}: {e}")
                return []
            
            # Handle channel count
            if eeg_data.shape[1] != 19:
                print(f"Warning: Expected 19 channels, got {eeg_data.shape[1]} for patient {patient_id}")
                if eeg_data.shape[1] > 19:
                    eeg_data = eeg_data[:, :19]
                else:
                    padding = np.zeros((eeg_data.shape[0], 19 - eeg_data.shape[1]), dtype=np.float32)
                    eeg_data = np.hstack([eeg_data, padding])
            
            print(f"  EEG data shape: {eeg_data.shape}")
            
            # Apply bandpass filter with error handling
            try:
                print(f"  Applying bandpass filter ({self.freq_min}-{self.freq_max} Hz)...")
                filtered_data = self.bandpass_filter_optimized(eeg_data)
            except Exception as e:
                print(f"Error in filtering for patient {patient_id}: {e}")
                return []
            
            # Segment the data
            print(f"  Segmenting data into {self.segment_duration}-second windows...")
            segments = self.segment_signal_vectorized(filtered_data)
            
            if not segments:
                print(f"  No segments generated for patient {patient_id}")
                return []
            
            print(f"  Generated {len(segments)} segments from patient {patient_id}")
            
            # Create Hilbert spectrum images for each segment
            saved_files = []
            for idx, segment in enumerate(segments):
                print(f"  Processing segment {idx + 1}/{len(segments)} with HHT...")
                
                filepath = self.create_combined_hilbert_spectrum_safe(segment, patient_id, idx, label)
                if filepath:
                    saved_files.append(filepath)
                    print(f"  Saved: {os.path.basename(filepath)}")
                else:
                    print(f"  Failed to save segment {idx}")
            
            return saved_files
            
        except Exception as e:
            print(f"Error processing patient {patient_id}: {str(e)}")
            traceback.print_exc()
            return []
    
    def get_patient_files(self, directory):
        """
        Get all CSV files from a directory
        """
        csv_files = []
        if os.path.exists(directory):
            for file in os.listdir(directory):
                if file.lower().endswith('.csv'):
                    csv_files.append(os.path.join(directory, file))
            csv_files.sort()
        else:
            print(f"Warning: Directory {directory} does not exist!")
        
        return csv_files
    
    def process_all_patients_threaded(self):
        """
        Process all patients using thread-based parallelism (safer than multiprocessing)
        """
        print("=== Optimized EEG Hilbert Spectrum Generation (HHT - Thread-based Parallel Processing) ===")
        print("Generating Hilbert spectra with thread-based parallelism for stability\n")
        
        # Get patient files from both directories
        sz_patient_files = self.get_patient_files(self.sz_input_dir)
        hc_patient_files = self.get_patient_files(self.hc_input_dir)
        
        print(f"Found {len(sz_patient_files)} Schizophrenia patient files")
        print(f"Found {len(hc_patient_files)} Healthy Control patient files")
        print(f"Using {self.n_jobs} parallel threads")
        
        if len(sz_patient_files) == 0 and len(hc_patient_files) == 0:
            print("No CSV files found in the specified directories!")
            return
        
        # Prepare all patient processing tasks
        tasks = []
        
        # Add SZ patients
        for i, csv_file in enumerate(sz_patient_files, 1):
            patient_id = f"SZ_{i:02d}"
            tasks.append((csv_file, patient_id, 'SZ'))
        
        # Add HC patients
        for i, csv_file in enumerate(hc_patient_files, 1):
            patient_id = f"HC_{i:02d}"
            tasks.append((csv_file, patient_id, 'HC'))
        
        total_sz_images = 0
        total_hc_images = 0
        
        # Process patients using ThreadPoolExecutor
        with ThreadPoolExecutor(max_workers=self.n_jobs) as executor:
            # Submit all tasks
            future_to_task = {
                executor.submit(self.process_patient_file_safe, csv_file, patient_id, label): (patient_id, label)
                for csv_file, patient_id, label in tasks
            }
            
            # Process completed tasks
            for future in as_completed(future_to_task):
                patient_id, label = future_to_task[future]
                try:
                    saved_files = future.result(timeout=600)  # 10 minute timeout per patient (HHT takes longer)
                    if label == 'SZ':
                        total_sz_images += len(saved_files)
                    else:
                        total_hc_images += len(saved_files)
                    print(f"  Completed {patient_id}: {len(saved_files)} Hilbert spectra generated\n")
                    
                except Exception as e:
                    print(f"Error processing {patient_id}: {e}")
                    traceback.print_exc()
        
        print("=== Summary ===")
        print(f"Total Schizophrenia Hilbert spectrum images: {total_sz_images}")
        print(f"Total Healthy Control Hilbert spectrum images: {total_hc_images}")
        print(f"Total Hilbert spectrum images generated: {total_sz_images + total_hc_images}")
        print(f"Images saved in: {self.output_dir}")
        print(f"  - Schizophrenia Hilbert spectra: {self.sz_dir}")
        print(f"  - Healthy Control Hilbert spectra: {self.hc_dir}")
        print(f"HHT Method: Ensemble EMD + Hilbert Transform")
        print(f"Frequency range: {self.freq_min}-{self.freq_max} Hz")
        print(f"Processing completed successfully with {self.n_jobs} threads")

    def process_all_patients_sequential_optimized(self):
        """
        Optimized sequential processing as fallback option
        """
        print("=== Optimized EEG Hilbert Spectrum Generation (HHT - Sequential Processing) ===")
        print("Using optimized sequential processing for maximum stability\n")
        
        # Get patient files from both directories
        sz_patient_files = self.get_patient_files(self.sz_input_dir)
        hc_patient_files = self.get_patient_files(self.hc_input_dir)
        
        print(f"Found {len(sz_patient_files)} Schizophrenia patient files")
        print(f"Found {len(hc_patient_files)} Healthy Control patient files")
        
        if len(sz_patient_files) == 0 and len(hc_patient_files) == 0:
            print("No CSV files found in the specified directories!")
            return
        
        total_sz_images = 0
        total_hc_images = 0
        
        print("\n=== Processing Schizophrenia Patients ===")
        for i, csv_file in enumerate(sz_patient_files, 1):
            patient_id = f"SZ_{i:02d}"
            saved_files = self.process_patient_file_safe(csv_file, patient_id, 'SZ')
            total_sz_images += len(saved_files)
            print(f"  Generated {len(saved_files)} Hilbert spectra for {patient_id}\n")
        
        print("=== Processing Healthy Control Patients ===")
        for i, csv_file in enumerate(hc_patient_files, 1):
            patient_id = f"HC_{i:02d}"
            saved_files = self.process_patient_file_safe(csv_file, patient_id, 'HC')
            total_hc_images += len(saved_files)
            print(f"  Generated {len(saved_files)} Hilbert spectra for {patient_id}\n")
        
        print("=== Summary ===")
        print(f"Total Schizophrenia Hilbert spectrum images: {total_sz_images}")
        print(f"Total Healthy Control Hilbert spectrum images: {total_hc_images}")
        print(f"Total Hilbert spectrum images generated: {total_sz_images + total_hc_images}")
        print(f"Images saved in: {self.output_dir}")
        print(f"Sequential HHT processing completed successfully")

# Example usage
if __name__ == "__main__":
    # Define paths
    sz_input_directory = "D:/result/dataset6/S"
    hc_input_directory = "D:/result/dataset6/H" 
    output_directory = "D:/result/sobi6"
    
    # Create optimized Hilbert spectrum generator
    generator = OptimizedEEGHilbertSpectrumGenerator(
        sz_input_dir=sz_input_directory,
        hc_input_dir=hc_input_directory,
        output_dir=output_directory,
        sampling_rate=256,
        n_jobs=4  # Use 4 threads for safer parallel processing (HHT is more intensive)
    )
    
    print("Choose processing method:")
    print("1. Thread-based parallel processing (recommended)")
    print("2. Sequential processing (most stable)")
    
    try:
        # Try thread-based parallel processing first
        print("\nStarting thread-based parallel processing with HHT...")
        generator.process_all_patients_threaded()
    except Exception as e:
        print(f"\nThread-based processing failed: {e}")
        print("Falling back to sequential processing...")
        generator.process_all_patients_sequential_optimized()
    
    print("\nOptimized Hilbert-Huang Transform processing completed!")
    print("Key HHT Features:")
    print("- Empirical Mode Decomposition (EMD/EEMD)")
    print("- Hilbert Transform for instantaneous frequency/amplitude")
    print("- Adaptive time-frequency representation")
    print("- Thread-based parallelism with comprehensive error handling")
    print("- Memory management and optimization")
    print("- Robust signal processing pipeline")
# Out:
# Initialized HHT Generator with 4 parallel threads
# Frequency range: 0.5-32 Hz with 100 bins
# Choose processing method:
# 1. Thread-based parallel processing (recommended)
# 2. Sequential processing (most stable)
#
# Starting thread-based parallel processing with HHT...
# === Optimized EEG Hilbert Spectrum Generation (HHT - Thread-based Parallel Processing) ===
# Generating Hilbert spectra with thread-based parallelism for stability
#
# Found 0 Schizophrenia patient files
# Found 1 Healthy Control patient files
# Using 4 parallel threads
# Processing HC Patient HC_01...
#   EEG data shape: (241250, 19)
#   Applying bandpass filter (0.5-32 Hz)...
#   Segmenting data into 3-second windows...
#   Generated 314 segments from patient HC_01
#   Processing segment 1/314 with HHT...
#   Saved: HC_patient_HC_01_segment_000_hilbert_spectrum.png
#   Processing segment 2/314 with HHT...
#   Saved: HC_patient_HC_01_segment_001_hilbert_spectrum.png
#   Processing segment 3/314 with HHT...
#   Saved: HC_patient_HC_01_segment_002_hilbert_spectrum.png
#   Processing segment 4/314 with HHT...
#   Saved: HC_patient_HC_01_segment_003_hilbert_spectrum.png
#   Processing segment 5/314 with HHT...
#   Saved: HC_patient_HC_01_segment_004_hilbert_spectrum.png
#   Processing segment 6/314 with HHT...
#   Saved: HC_patient_HC_01_segment_005_hilbert_spectrum.png
#   Processing segment 7/314 with HHT...
#   Saved: HC_patient_HC_01_segment_006_hilbert_spectrum.png
#   Processing segment 8/314 with HHT...
#   Saved: HC_patient_HC_01_segment_007_hilbert_spectrum.png
#   Processing segment 9/314 with HHT...
#   Saved: HC_patient_HC_01_segment_008_hilbert_spectrum.png
#   Processing segment 10/314 with HHT...
#   Saved: HC_patient_HC_01_segment_009_hilbert_spectrum.png
#   Processing segment 11/314 with HHT...
#   Saved: HC_patient_HC_01_segment_010_hilbert_spectrum.png
#   Processing segment 12/314 with HHT...
#   Saved: HC_patient_HC_01_segment_011_hilbert_spectrum.png
#   Processing segment 13/314 with HHT...
#   Saved: HC_patient_HC_01_segment_012_hilbert_spectrum.png
#   Processing segment 14/314 with HHT...
#   Saved: HC_patient_HC_01_segment_013_hilbert_spectrum.png
#   Processing segment 15/314 with HHT...
#   Saved: HC_patient_HC_01_segment_014_hilbert_spectrum.png
#   Processing segment 16/314 with HHT...
#   Saved: HC_patient_HC_01_segment_015_hilbert_spectrum.png
#   Processing segment 17/314 with HHT...
#   Saved: HC_patient_HC_01_segment_016_hilbert_spectrum.png
#   Processing segment 18/314 with HHT...
#   Saved: HC_patient_HC_01_segment_017_hilbert_spectrum.png
#   Processing segment 19/314 with HHT...
#   Saved: HC_patient_HC_01_segment_018_hilbert_spectrum.png
#   Processing segment 20/314 with HHT...
#   Saved: HC_patient_HC_01_segment_019_hilbert_spectrum.png
#   Processing segment 21/314 with HHT...
#   Saved: HC_patient_HC_01_segment_020_hilbert_spectrum.png
#   Processing segment 22/314 with HHT...
#   Saved: HC_patient_HC_01_segment_021_hilbert_spectrum.png
#   Processing segment 23/314 with HHT...
#   Saved: HC_patient_HC_01_segment_022_hilbert_spectrum.png
#   Processing segment 24/314 with HHT...
#   Saved: HC_patient_HC_01_segment_023_hilbert_spectrum.png
#   Processing segment 25/314 with HHT...
#   Saved: HC_patient_HC_01_segment_024_hilbert_spectrum.png
#   Processing segment 26/314 with HHT...
#   Saved: HC_patient_HC_01_segment_025_hilbert_spectrum.png
#   Processing segment 27/314 with HHT...
#   Saved: HC_patient_HC_01_segment_026_hilbert_spectrum.png
#   Processing segment 28/314 with HHT...
#   Saved: HC_patient_HC_01_segment_027_hilbert_spectrum.png
#   Processing segment 29/314 with HHT...
#   Saved: HC_patient_HC_01_segment_028_hilbert_spectrum.png
#   Processing segment 30/314 with HHT...
#   Saved: HC_patient_HC_01_segment_029_hilbert_spectrum.png
#   Processing segment 31/314 with HHT...
#   Saved: HC_patient_HC_01_segment_030_hilbert_spectrum.png
#   Processing segment 32/314 with HHT...
#   Saved: HC_patient_HC_01_segment_031_hilbert_spectrum.png
#   Processing segment 33/314 with HHT...
#   Saved: HC_patient_HC_01_segment_032_hilbert_spectrum.png
#   Processing segment 34/314 with HHT...
#   Saved: HC_patient_HC_01_segment_033_hilbert_spectrum.png
#   Processing segment 35/314 with HHT...
#   Saved: HC_patient_HC_01_segment_034_hilbert_spectrum.png
#   Processing segment 36/314 with HHT...
#   Saved: HC_patient_HC_01_segment_035_hilbert_spectrum.png
#   Processing segment 37/314 with HHT...
#   Saved: HC_patient_HC_01_segment_036_hilbert_spectrum.png
#   Processing segment 38/314 with HHT...
#   Saved: HC_patient_HC_01_segment_037_hilbert_spectrum.png
#   Processing segment 39/314 with HHT...
#   Saved: HC_patient_HC_01_segment_038_hilbert_spectrum.png
#   Processing segment 40/314 with HHT...
#   Saved: HC_patient_HC_01_segment_039_hilbert_spectrum.png
#   Processing segment 41/314 with HHT...
#   Saved: HC_patient_HC_01_segment_040_hilbert_spectrum.png
#   Processing segment 42/314 with HHT...
#   Saved: HC_patient_HC_01_segment_041_hilbert_spectrum.png
#   Processing segment 43/314 with HHT...
#   Saved: HC_patient_HC_01_segment_042_hilbert_spectrum.png
#   Processing segment 44/314 with HHT...
#   Saved: HC_patient_HC_01_segment_043_hilbert_spectrum.png
#   Processing segment 45/314 with HHT...
#   Saved: HC_patient_HC_01_segment_044_hilbert_spectrum.png
#   Processing segment 46/314 with HHT...
#   Saved: HC_patient_HC_01_segment_045_hilbert_spectrum.png
#   Processing segment 47/314 with HHT...
#   Saved: HC_patient_HC_01_segment_046_hilbert_spectrum.png
#   Processing segment 48/314 with HHT...
#   Saved: HC_patient_HC_01_segment_047_hilbert_spectrum.png
#   Processing segment 49/314 with HHT...
#   Saved: HC_patient_HC_01_segment_048_hilbert_spectrum.png
#   Processing segment 50/314 with HHT...
#   Saved: HC_patient_HC_01_segment_049_hilbert_spectrum.png
#   Processing segment 51/314 with HHT...
#   Saved: HC_patient_HC_01_segment_050_hilbert_spectrum.png
#   Processing segment 52/314 with HHT...
#   Saved: HC_patient_HC_01_segment_051_hilbert_spectrum.png
#   Processing segment 53/314 with HHT...
#   Saved: HC_patient_HC_01_segment_052_hilbert_spectrum.png
#   Processing segment 54/314 with HHT...
#   Saved: HC_patient_HC_01_segment_053_hilbert_spectrum.png
#   Processing segment 55/314 with HHT...
#   Saved: HC_patient_HC_01_segment_054_hilbert_spectrum.png
#   Processing segment 56/314 with HHT...
#   Saved: HC_patient_HC_01_segment_055_hilbert_spectrum.png
#   Processing segment 57/314 with HHT...
#   Saved: HC_patient_HC_01_segment_056_hilbert_spectrum.png
#   Processing segment 58/314 with HHT...
#   Saved: HC_patient_HC_01_segment_057_hilbert_spectrum.png
#   Processing segment 59/314 with HHT...
#   Saved: HC_patient_HC_01_segment_058_hilbert_spectrum.png
#   Processing segment 60/314 with HHT...
#   Saved: HC_patient_HC_01_segment_059_hilbert_spectrum.png
#   Processing segment 61/314 with HHT...
#   Saved: HC_patient_HC_01_segment_060_hilbert_spectrum.png
#   Processing segment 62/314 with HHT...
#   Saved: HC_patient_HC_01_segment_061_hilbert_spectrum.png
#   Processing segment 63/314 with HHT...
#   Saved: HC_patient_HC_01_segment_062_hilbert_spectrum.png
#   Processing segment 64/314 with HHT...
#   Saved: HC_patient_HC_01_segment_063_hilbert_spectrum.png
#   Processing segment 65/314 with HHT...
#   Saved: HC_patient_HC_01_segment_064_hilbert_spectrum.png
#   Processing segment 66/314 with HHT...
#   Saved: HC_patient_HC_01_segment_065_hilbert_spectrum.png
#   Processing segment 67/314 with HHT...
#   Saved: HC_patient_HC_01_segment_066_hilbert_spectrum.png
#   Processing segment 68/314 with HHT...
#   Saved: HC_patient_HC_01_segment_067_hilbert_spectrum.png
#   Processing segment 69/314 with HHT...
#   Saved: HC_patient_HC_01_segment_068_hilbert_spectrum.png
#   Processing segment 70/314 with HHT...
#   Saved: HC_patient_HC_01_segment_069_hilbert_spectrum.png
#   Processing segment 71/314 with HHT...
#   Saved: HC_patient_HC_01_segment_070_hilbert_spectrum.png
#   Processing segment 72/314 with HHT...
#   Saved: HC_patient_HC_01_segment_071_hilbert_spectrum.png
#   Processing segment 73/314 with HHT...
#   Saved: HC_patient_HC_01_segment_072_hilbert_spectrum.png
#   Processing segment 74/314 with HHT...
#   Saved: HC_patient_HC_01_segment_073_hilbert_spectrum.png
#   Processing segment 75/314 with HHT...
#   Saved: HC_patient_HC_01_segment_074_hilbert_spectrum.png
#   Processing segment 76/314 with HHT...
#   Saved: HC_patient_HC_01_segment_075_hilbert_spectrum.png
#   Processing segment 77/314 with HHT...
#   Saved: HC_patient_HC_01_segment_076_hilbert_spectrum.png
#   Processing segment 78/314 with HHT...
#   Saved: HC_patient_HC_01_segment_077_hilbert_spectrum.png
#   Processing segment 79/314 with HHT...
#   Saved: HC_patient_HC_01_segment_078_hilbert_spectrum.png
#   Processing segment 80/314 with HHT...
#   Saved: HC_patient_HC_01_segment_079_hilbert_spectrum.png
#   Processing segment 81/314 with HHT...
#   Saved: HC_patient_HC_01_segment_080_hilbert_spectrum.png
#   Processing segment 82/314 with HHT...
#   Saved: HC_patient_HC_01_segment_081_hilbert_spectrum.png
#   Processing segment 83/314 with HHT...
#   Saved: HC_patient_HC_01_segment_082_hilbert_spectrum.png
#   Processing segment 84/314 with HHT...
#   Saved: HC_patient_HC_01_segment_083_hilbert_spectrum.png
#   Processing segment 85/314 with HHT...
#   Saved: HC_patient_HC_01_segment_084_hilbert_spectrum.png
#   Processing segment 86/314 with HHT...
#   Saved: HC_patient_HC_01_segment_085_hilbert_spectrum.png
#   Processing segment 87/314 with HHT...
#   Saved: HC_patient_HC_01_segment_086_hilbert_spectrum.png
#   Processing segment 88/314 with HHT...
#   Saved: HC_patient_HC_01_segment_087_hilbert_spectrum.png
#   Processing segment 89/314 with HHT...
#   Saved: HC_patient_HC_01_segment_088_hilbert_spectrum.png
#   Processing segment 90/314 with HHT...
#   Saved: HC_patient_HC_01_segment_089_hilbert_spectrum.png
#   Processing segment 91/314 with HHT...
#   Saved: HC_patient_HC_01_segment_090_hilbert_spectrum.png
#   Processing segment 92/314 with HHT...
#   Saved: HC_patient_HC_01_segment_091_hilbert_spectrum.png
#   Processing segment 93/314 with HHT...
#   Saved: HC_patient_HC_01_segment_092_hilbert_spectrum.png
#   Processing segment 94/314 with HHT...
#   Saved: HC_patient_HC_01_segment_093_hilbert_spectrum.png
#   Processing segment 95/314 with HHT...
#   Saved: HC_patient_HC_01_segment_094_hilbert_spectrum.png
#   Processing segment 96/314 with HHT...
#   Saved: HC_patient_HC_01_segment_095_hilbert_spectrum.png
#   Processing segment 97/314 with HHT...
#   Saved: HC_patient_HC_01_segment_096_hilbert_spectrum.png
#   Processing segment 98/314 with HHT...
#   Saved: HC_patient_HC_01_segment_097_hilbert_spectrum.png
#   Processing segment 99/314 with HHT...
#   Saved: HC_patient_HC_01_segment_098_hilbert_spectrum.png
#   Processing segment 100/314 with HHT...
#   Saved: HC_patient_HC_01_segment_099_hilbert_spectrum.png
#   Processing segment 101/314 with HHT...
#   Saved: HC_patient_HC_01_segment_100_hilbert_spectrum.png
#   Processing segment 102/314 with HHT...
#   Saved: HC_patient_HC_01_segment_101_hilbert_spectrum.png
#   Processing segment 103/314 with HHT...
#   Saved: HC_patient_HC_01_segment_102_hilbert_spectrum.png
#   Processing segment 104/314 with HHT...
#   Saved: HC_patient_HC_01_segment_103_hilbert_spectrum.png
#   Processing segment 105/314 with HHT...
#   Saved: HC_patient_HC_01_segment_104_hilbert_spectrum.png
#   Processing segment 106/314 with HHT...
#   Saved: HC_patient_HC_01_segment_105_hilbert_spectrum.png
#   Processing segment 107/314 with HHT...
#   Saved: HC_patient_HC_01_segment_106_hilbert_spectrum.png
#   Processing segment 108/314 with HHT...
#   Saved: HC_patient_HC_01_segment_107_hilbert_spectrum.png
#   Processing segment 109/314 with HHT...
#   Saved: HC_patient_HC_01_segment_108_hilbert_spectrum.png
#   Processing segment 110/314 with HHT...
#   Saved: HC_patient_HC_01_segment_109_hilbert_spectrum.png
#   Processing segment 111/314 with HHT...
#   Saved: HC_patient_HC_01_segment_110_hilbert_spectrum.png
#   Processing segment 112/314 with HHT...
#   Saved: HC_patient_HC_01_segment_111_hilbert_spectrum.png
#   Processing segment 113/314 with HHT...
#   Saved: HC_patient_HC_01_segment_112_hilbert_spectrum.png
#   Processing segment 114/314 with HHT...
#   Saved: HC_patient_HC_01_segment_113_hilbert_spectrum.png
#   Processing segment 115/314 with HHT...
#   Saved: HC_patient_HC_01_segment_114_hilbert_spectrum.png
#   Processing segment 116/314 with HHT...
#   Saved: HC_patient_HC_01_segment_115_hilbert_spectrum.png
#   Processing segment 117/314 with HHT...
#   Saved: HC_patient_HC_01_segment_116_hilbert_spectrum.png
#   Processing segment 118/314 with HHT...
#   Saved: HC_patient_HC_01_segment_117_hilbert_spectrum.png
#   Processing segment 119/314 with HHT...
#   Saved: HC_patient_HC_01_segment_118_hilbert_spectrum.png
#   Processing segment 120/314 with HHT...
#   Saved: HC_patient_HC_01_segment_119_hilbert_spectrum.png
#   Processing segment 121/314 with HHT...
#   Saved: HC_patient_HC_01_segment_120_hilbert_spectrum.png
#   Processing segment 122/314 with HHT...
#   Saved: HC_patient_HC_01_segment_121_hilbert_spectrum.png
#   Processing segment 123/314 with HHT...
#   Saved: HC_patient_HC_01_segment_122_hilbert_spectrum.png
#   Processing segment 124/314 with HHT...
#   Saved: HC_patient_HC_01_segment_123_hilbert_spectrum.png
#   Processing segment 125/314 with HHT...
#   Saved: HC_patient_HC_01_segment_124_hilbert_spectrum.png
#   Processing segment 126/314 with HHT...
#   Saved: HC_patient_HC_01_segment_125_hilbert_spectrum.png
#   Processing segment 127/314 with HHT...
#   Saved: HC_patient_HC_01_segment_126_hilbert_spectrum.png
#   Processing segment 128/314 with HHT...
#   Saved: HC_patient_HC_01_segment_127_hilbert_spectrum.png
#   Processing segment 129/314 with HHT...
#   Saved: HC_patient_HC_01_segment_128_hilbert_spectrum.png
#   Processing segment 130/314 with HHT...
#   Saved: HC_patient_HC_01_segment_129_hilbert_spectrum.png
#   Processing segment 131/314 with HHT...
#   Saved: HC_patient_HC_01_segment_130_hilbert_spectrum.png
#   Processing segment 132/314 with HHT...
#   Saved: HC_patient_HC_01_segment_131_hilbert_spectrum.png
#   Processing segment 133/314 with HHT...
#   Saved: HC_patient_HC_01_segment_132_hilbert_spectrum.png
#   Processing segment 134/314 with HHT...
#   Saved: HC_patient_HC_01_segment_133_hilbert_spectrum.png
#   Processing segment 135/314 with HHT...
#   Saved: HC_patient_HC_01_segment_134_hilbert_spectrum.png
#   Processing segment 136/314 with HHT...
#   Saved: HC_patient_HC_01_segment_135_hilbert_spectrum.png
#   Processing segment 137/314 with HHT...
#   Saved: HC_patient_HC_01_segment_136_hilbert_spectrum.png
#   Processing segment 138/314 with HHT...
#   Saved: HC_patient_HC_01_segment_137_hilbert_spectrum.png
#   Processing segment 139/314 with HHT...
#   Saved: HC_patient_HC_01_segment_138_hilbert_spectrum.png
#   Processing segment 140/314 with HHT...
#   Saved: HC_patient_HC_01_segment_139_hilbert_spectrum.png
#   Processing segment 141/314 with HHT...
#   Saved: HC_patient_HC_01_segment_140_hilbert_spectrum.png
#   Processing segment 142/314 with HHT...
#   Saved: HC_patient_HC_01_segment_141_hilbert_spectrum.png
#   Processing segment 143/314 with HHT...
#   Saved: HC_patient_HC_01_segment_142_hilbert_spectrum.png
#   Processing segment 144/314 with HHT...
#   Saved: HC_patient_HC_01_segment_143_hilbert_spectrum.png
#   Processing segment 145/314 with HHT...
#   Saved: HC_patient_HC_01_segment_144_hilbert_spectrum.png
#   Processing segment 146/314 with HHT...
#   Saved: HC_patient_HC_01_segment_145_hilbert_spectrum.png
#   Processing segment 147/314 with HHT...
#   Saved: HC_patient_HC_01_segment_146_hilbert_spectrum.png
#   Processing segment 148/314 with HHT...
#   Saved: HC_patient_HC_01_segment_147_hilbert_spectrum.png
#   Processing segment 149/314 with HHT...
#   Saved: HC_patient_HC_01_segment_148_hilbert_spectrum.png
#   Processing segment 150/314 with HHT...
#   Saved: HC_patient_HC_01_segment_149_hilbert_spectrum.png
#   Processing segment 151/314 with HHT...
#   Saved: HC_patient_HC_01_segment_150_hilbert_spectrum.png
#   Processing segment 152/314 with HHT...
#   Saved: HC_patient_HC_01_segment_151_hilbert_spectrum.png
#   Processing segment 153/314 with HHT...
#   Saved: HC_patient_HC_01_segment_152_hilbert_spectrum.png
#   Processing segment 154/314 with HHT...
#   Saved: HC_patient_HC_01_segment_153_hilbert_spectrum.png
#   Processing segment 155/314 with HHT...
#   Saved: HC_patient_HC_01_segment_154_hilbert_spectrum.png
#   Processing segment 156/314 with HHT...
#   Saved: HC_patient_HC_01_segment_155_hilbert_spectrum.png
#   Processing segment 157/314 with HHT...
#   Saved: HC_patient_HC_01_segment_156_hilbert_spectrum.png
#   Processing segment 158/314 with HHT...
#   Saved: HC_patient_HC_01_segment_157_hilbert_spectrum.png
#   Processing segment 159/314 with HHT...
#   Saved: HC_patient_HC_01_segment_158_hilbert_spectrum.png
#   Processing segment 160/314 with HHT...
#   Saved: HC_patient_HC_01_segment_159_hilbert_spectrum.png
#   Processing segment 161/314 with HHT...
#   Saved: HC_patient_HC_01_segment_160_hilbert_spectrum.png
#   Processing segment 162/314 with HHT...
#   Saved: HC_patient_HC_01_segment_161_hilbert_spectrum.png
#   Processing segment 163/314 with HHT...
#   Saved: HC_patient_HC_01_segment_162_hilbert_spectrum.png
#   Processing segment 164/314 with HHT...
#   Saved: HC_patient_HC_01_segment_163_hilbert_spectrum.png
#   Processing segment 165/314 with HHT...
#   Saved: HC_patient_HC_01_segment_164_hilbert_spectrum.png
#   Processing segment 166/314 with HHT...
#   Saved: HC_patient_HC_01_segment_165_hilbert_spectrum.png
#   Processing segment 167/314 with HHT...
#   Saved: HC_patient_HC_01_segment_166_hilbert_spectrum.png
#   Processing segment 168/314 with HHT...
#   Saved: HC_patient_HC_01_segment_167_hilbert_spectrum.png
#   Processing segment 169/314 with HHT...
#   Saved: HC_patient_HC_01_segment_168_hilbert_spectrum.png
#   Processing segment 170/314 with HHT...
#   Saved: HC_patient_HC_01_segment_169_hilbert_spectrum.png
#   Processing segment 171/314 with HHT...
#   Saved: HC_patient_HC_01_segment_170_hilbert_spectrum.png
#   Processing segment 172/314 with HHT...
#   Saved: HC_patient_HC_01_segment_171_hilbert_spectrum.png
#   Processing segment 173/314 with HHT...
#   Saved: HC_patient_HC_01_segment_172_hilbert_spectrum.png
#   Processing segment 174/314 with HHT...
#   Saved: HC_patient_HC_01_segment_173_hilbert_spectrum.png
#   Processing segment 175/314 with HHT...
#   Saved: HC_patient_HC_01_segment_174_hilbert_spectrum.png
#   Processing segment 176/314 with HHT...
#   Saved: HC_patient_HC_01_segment_175_hilbert_spectrum.png
#   Processing segment 177/314 with HHT...
#   Saved: HC_patient_HC_01_segment_176_hilbert_spectrum.png
#   Processing segment 178/314 with HHT...
#   Saved: HC_patient_HC_01_segment_177_hilbert_spectrum.png
#   Processing segment 179/314 with HHT...
#   Saved: HC_patient_HC_01_segment_178_hilbert_spectrum.png
#   Processing segment 180/314 with HHT...
#   Saved: HC_patient_HC_01_segment_179_hilbert_spectrum.png
#   Processing segment 181/314 with HHT...
#   Saved: HC_patient_HC_01_segment_180_hilbert_spectrum.png
#   Processing segment 182/314 with HHT...
#   Saved: HC_patient_HC_01_segment_181_hilbert_spectrum.png
#   Processing segment 183/314 with HHT...
#   Saved: HC_patient_HC_01_segment_182_hilbert_spectrum.png
#   Processing segment 184/314 with HHT...
#   Saved: HC_patient_HC_01_segment_183_hilbert_spectrum.png
#   Processing segment 185/314 with HHT...
#   Saved: HC_patient_HC_01_segment_184_hilbert_spectrum.png
#   Processing segment 186/314 with HHT...
#   Saved: HC_patient_HC_01_segment_185_hilbert_spectrum.png
#   Processing segment 187/314 with HHT...
#   Saved: HC_patient_HC_01_segment_186_hilbert_spectrum.png
#   Processing segment 188/314 with HHT...
#   Saved: HC_patient_HC_01_segment_187_hilbert_spectrum.png
#   Processing segment 189/314 with HHT...
#   Saved: HC_patient_HC_01_segment_188_hilbert_spectrum.png
#   Processing segment 190/314 with HHT...
#   Saved: HC_patient_HC_01_segment_189_hilbert_spectrum.png
#   Processing segment 191/314 with HHT...
#   Saved: HC_patient_HC_01_segment_190_hilbert_spectrum.png
#   Processing segment 192/314 with HHT...
#   Saved: HC_patient_HC_01_segment_191_hilbert_spectrum.png
#   Processing segment 193/314 with HHT...
#   Saved: HC_patient_HC_01_segment_192_hilbert_spectrum.png
#   Processing segment 194/314 with HHT...
#   Saved: HC_patient_HC_01_segment_193_hilbert_spectrum.png
#   Processing segment 195/314 with HHT...
#   Saved: HC_patient_HC_01_segment_194_hilbert_spectrum.png
#   Processing segment 196/314 with HHT...
#   Saved: HC_patient_HC_01_segment_195_hilbert_spectrum.png
#   Processing segment 197/314 with HHT...
#   Saved: HC_patient_HC_01_segment_196_hilbert_spectrum.png
#   Processing segment 198/314 with HHT...
#   Saved: HC_patient_HC_01_segment_197_hilbert_spectrum.png
#   Processing segment 199/314 with HHT...
#   Saved: HC_patient_HC_01_segment_198_hilbert_spectrum.png
#   Processing segment 200/314 with HHT...
#   Saved: HC_patient_HC_01_segment_199_hilbert_spectrum.png
#   Processing segment 201/314 with HHT...
#   Saved: HC_patient_HC_01_segment_200_hilbert_spectrum.png
#   Processing segment 202/314 with HHT...
#   Saved: HC_patient_HC_01_segment_201_hilbert_spectrum.png
#   Processing segment 203/314 with HHT...
#   Saved: HC_patient_HC_01_segment_202_hilbert_spectrum.png
#   Processing segment 204/314 with HHT...
#   Saved: HC_patient_HC_01_segment_203_hilbert_spectrum.png
#   Processing segment 205/314 with HHT...
#   Saved: HC_patient_HC_01_segment_204_hilbert_spectrum.png
#   Processing segment 206/314 with HHT...
#   Saved: HC_patient_HC_01_segment_205_hilbert_spectrum.png
#   Processing segment 207/314 with HHT...
#   Saved: HC_patient_HC_01_segment_206_hilbert_spectrum.png
#   Processing segment 208/314 with HHT...
#   Saved: HC_patient_HC_01_segment_207_hilbert_spectrum.png
#   Processing segment 209/314 with HHT...
#   Saved: HC_patient_HC_01_segment_208_hilbert_spectrum.png
#   Processing segment 210/314 with HHT...
#   Saved: HC_patient_HC_01_segment_209_hilbert_spectrum.png
#   Processing segment 211/314 with HHT...
#   Saved: HC_patient_HC_01_segment_210_hilbert_spectrum.png
#   Processing segment 212/314 with HHT...
#   Saved: HC_patient_HC_01_segment_211_hilbert_spectrum.png
#   Processing segment 213/314 with HHT...
#   Saved: HC_patient_HC_01_segment_212_hilbert_spectrum.png
#   Processing segment 214/314 with HHT...
#   Saved: HC_patient_HC_01_segment_213_hilbert_spectrum.png
#   Processing segment 215/314 with HHT...
#   Saved: HC_patient_HC_01_segment_214_hilbert_spectrum.png
#   Processing segment 216/314 with HHT...
#   Saved: HC_patient_HC_01_segment_215_hilbert_spectrum.png
#   Processing segment 217/314 with HHT...
#   Saved: HC_patient_HC_01_segment_216_hilbert_spectrum.png
#   Processing segment 218/314 with HHT...
#   Saved: HC_patient_HC_01_segment_217_hilbert_spectrum.png
#   Processing segment 219/314 with HHT...
#   Saved: HC_patient_HC_01_segment_218_hilbert_spectrum.png
#   Processing segment 220/314 with HHT...
#   Saved: HC_patient_HC_01_segment_219_hilbert_spectrum.png
#   Processing segment 221/314 with HHT...
#   Saved: HC_patient_HC_01_segment_220_hilbert_spectrum.png
#   Processing segment 222/314 with HHT...
#   Saved: HC_patient_HC_01_segment_221_hilbert_spectrum.png
#   Processing segment 223/314 with HHT...
#   Saved: HC_patient_HC_01_segment_222_hilbert_spectrum.png
#   Processing segment 224/314 with HHT...
#   Saved: HC_patient_HC_01_segment_223_hilbert_spectrum.png
#   Processing segment 225/314 with HHT...
#   Saved: HC_patient_HC_01_segment_224_hilbert_spectrum.png
#   Processing segment 226/314 with HHT...
#   Saved: HC_patient_HC_01_segment_225_hilbert_spectrum.png
#   Processing segment 227/314 with HHT...
#   Saved: HC_patient_HC_01_segment_226_hilbert_spectrum.png
#   Processing segment 228/314 with HHT...
#   Saved: HC_patient_HC_01_segment_227_hilbert_spectrum.png
#   Processing segment 229/314 with HHT...
#   Saved: HC_patient_HC_01_segment_228_hilbert_spectrum.png
#   Processing segment 230/314 with HHT...
#   Saved: HC_patient_HC_01_segment_229_hilbert_spectrum.png
#   Processing segment 231/314 with HHT...
#   Saved: HC_patient_HC_01_segment_230_hilbert_spectrum.png
#   Processing segment 232/314 with HHT...
#   Saved: HC_patient_HC_01_segment_231_hilbert_spectrum.png
#   Processing segment 233/314 with HHT...
#   Saved: HC_patient_HC_01_segment_232_hilbert_spectrum.png
#   Processing segment 234/314 with HHT...
#   Saved: HC_patient_HC_01_segment_233_hilbert_spectrum.png
#   Processing segment 235/314 with HHT...
#   Saved: HC_patient_HC_01_segment_234_hilbert_spectrum.png
#   Processing segment 236/314 with HHT...
#   Saved: HC_patient_HC_01_segment_235_hilbert_spectrum.png
#   Processing segment 237/314 with HHT...
#   Saved: HC_patient_HC_01_segment_236_hilbert_spectrum.png
#   Processing segment 238/314 with HHT...
#   Saved: HC_patient_HC_01_segment_237_hilbert_spectrum.png
#   Processing segment 239/314 with HHT...
#   Saved: HC_patient_HC_01_segment_238_hilbert_spectrum.png
#   Processing segment 240/314 with HHT...
#   Saved: HC_patient_HC_01_segment_239_hilbert_spectrum.png
#   Processing segment 241/314 with HHT...
#   Saved: HC_patient_HC_01_segment_240_hilbert_spectrum.png
#   Processing segment 242/314 with HHT...
#   Saved: HC_patient_HC_01_segment_241_hilbert_spectrum.png
#   Processing segment 243/314 with HHT...
#   Saved: HC_patient_HC_01_segment_242_hilbert_spectrum.png
#   Processing segment 244/314 with HHT...
#   Saved: HC_patient_HC_01_segment_243_hilbert_spectrum.png
#   Processing segment 245/314 with HHT...
#   Saved: HC_patient_HC_01_segment_244_hilbert_spectrum.png
#   Processing segment 246/314 with HHT...
#   Saved: HC_patient_HC_01_segment_245_hilbert_spectrum.png
#   Processing segment 247/314 with HHT...
#   Saved: HC_patient_HC_01_segment_246_hilbert_spectrum.png
#   Processing segment 248/314 with HHT...
#   Saved: HC_patient_HC_01_segment_247_hilbert_spectrum.png
#   Processing segment 249/314 with HHT...
#   Saved: HC_patient_HC_01_segment_248_hilbert_spectrum.png
#   Processing segment 250/314 with HHT...
#   Saved: HC_patient_HC_01_segment_249_hilbert_spectrum.png
#   Processing segment 251/314 with HHT...
#   Saved: HC_patient_HC_01_segment_250_hilbert_spectrum.png
#   Processing segment 252/314 with HHT...
#   Saved: HC_patient_HC_01_segment_251_hilbert_spectrum.png
#   Processing segment 253/314 with HHT...
#   Saved: HC_patient_HC_01_segment_252_hilbert_spectrum.png
#   Processing segment 254/314 with HHT...
#   Saved: HC_patient_HC_01_segment_253_hilbert_spectrum.png
#   Processing segment 255/314 with HHT...
#   Saved: HC_patient_HC_01_segment_254_hilbert_spectrum.png
#   Processing segment 256/314 with HHT...
#   Saved: HC_patient_HC_01_segment_255_hilbert_spectrum.png
#   Processing segment 257/314 with HHT...
#   Saved: HC_patient_HC_01_segment_256_hilbert_spectrum.png
#   Processing segment 258/314 with HHT...
#   Saved: HC_patient_HC_01_segment_257_hilbert_spectrum.png
#   Processing segment 259/314 with HHT...
#   Saved: HC_patient_HC_01_segment_258_hilbert_spectrum.png
#   Processing segment 260/314 with HHT...
#   Saved: HC_patient_HC_01_segment_259_hilbert_spectrum.png
#   Processing segment 261/314 with HHT...
#   Saved: HC_patient_HC_01_segment_260_hilbert_spectrum.png
#   Processing segment 262/314 with HHT...
#   Saved: HC_patient_HC_01_segment_261_hilbert_spectrum.png
#   Processing segment 263/314 with HHT...
#   Saved: HC_patient_HC_01_segment_262_hilbert_spectrum.png
#   Processing segment 264/314 with HHT...
#   Saved: HC_patient_HC_01_segment_263_hilbert_spectrum.png
#   Processing segment 265/314 with HHT...
#   Saved: HC_patient_HC_01_segment_264_hilbert_spectrum.png
#   Processing segment 266/314 with HHT...
#   Saved: HC_patient_HC_01_segment_265_hilbert_spectrum.png
#   Processing segment 267/314 with HHT...
#   Saved: HC_patient_HC_01_segment_266_hilbert_spectrum.png
#   Processing segment 268/314 with HHT...
#   Saved: HC_patient_HC_01_segment_267_hilbert_spectrum.png
#   Processing segment 269/314 with HHT...
#   Saved: HC_patient_HC_01_segment_268_hilbert_spectrum.png
#   Processing segment 270/314 with HHT...
#   Saved: HC_patient_HC_01_segment_269_hilbert_spectrum.png
#   Processing segment 271/314 with HHT...
#   Saved: HC_patient_HC_01_segment_270_hilbert_spectrum.png
#   Processing segment 272/314 with HHT...
#   Saved: HC_patient_HC_01_segment_271_hilbert_spectrum.png
#   Processing segment 273/314 with HHT...
#   Saved: HC_patient_HC_01_segment_272_hilbert_spectrum.png
#   Processing segment 274/314 with HHT...
#   Saved: HC_patient_HC_01_segment_273_hilbert_spectrum.png
#   Processing segment 275/314 with HHT...
#   Saved: HC_patient_HC_01_segment_274_hilbert_spectrum.png
#   Processing segment 276/314 with HHT...
#   Saved: HC_patient_HC_01_segment_275_hilbert_spectrum.png
#   Processing segment 277/314 with HHT...
#   Saved: HC_patient_HC_01_segment_276_hilbert_spectrum.png
#   Processing segment 278/314 with HHT...
#   Saved: HC_patient_HC_01_segment_277_hilbert_spectrum.png
#   Processing segment 279/314 with HHT...
#   Saved: HC_patient_HC_01_segment_278_hilbert_spectrum.png
#   Processing segment 280/314 with HHT...
#   Saved: HC_patient_HC_01_segment_279_hilbert_spectrum.png
#   Processing segment 281/314 with HHT...
#   Saved: HC_patient_HC_01_segment_280_hilbert_spectrum.png
#   Processing segment 282/314 with HHT...
#   Saved: HC_patient_HC_01_segment_281_hilbert_spectrum.png
#   Processing segment 283/314 with HHT...
#   Saved: HC_patient_HC_01_segment_282_hilbert_spectrum.png
#   Processing segment 284/314 with HHT...
#   Saved: HC_patient_HC_01_segment_283_hilbert_spectrum.png
#   Processing segment 285/314 with HHT...
#   Saved: HC_patient_HC_01_segment_284_hilbert_spectrum.png
#   Processing segment 286/314 with HHT...
#   Saved: HC_patient_HC_01_segment_285_hilbert_spectrum.png
#   Processing segment 287/314 with HHT...
#   Saved: HC_patient_HC_01_segment_286_hilbert_spectrum.png
#   Processing segment 288/314 with HHT...
#   Saved: HC_patient_HC_01_segment_287_hilbert_spectrum.png
#   Processing segment 289/314 with HHT...
#   Saved: HC_patient_HC_01_segment_288_hilbert_spectrum.png
#   Processing segment 290/314 with HHT...
#   Saved: HC_patient_HC_01_segment_289_hilbert_spectrum.png
#   Processing segment 291/314 with HHT...
#   Saved: HC_patient_HC_01_segment_290_hilbert_spectrum.png
#   Processing segment 292/314 with HHT...
#   Saved: HC_patient_HC_01_segment_291_hilbert_spectrum.png
#   Processing segment 293/314 with HHT...
#   Saved: HC_patient_HC_01_segment_292_hilbert_spectrum.png
#   Processing segment 294/314 with HHT...
#   Saved: HC_patient_HC_01_segment_293_hilbert_spectrum.png
#   Processing segment 295/314 with HHT...
#   Saved: HC_patient_HC_01_segment_294_hilbert_spectrum.png
#   Processing segment 296/314 with HHT...
#   Saved: HC_patient_HC_01_segment_295_hilbert_spectrum.png
#   Processing segment 297/314 with HHT...
#   Saved: HC_patient_HC_01_segment_296_hilbert_spectrum.png
#   Processing segment 298/314 with HHT...
#   Saved: HC_patient_HC_01_segment_297_hilbert_spectrum.png
#   Processing segment 299/314 with HHT...
#   Saved: HC_patient_HC_01_segment_298_hilbert_spectrum.png
#   Processing segment 300/314 with HHT...
#   Saved: HC_patient_HC_01_segment_299_hilbert_spectrum.png
#   Processing segment 301/314 with HHT...
#   Saved: HC_patient_HC_01_segment_300_hilbert_spectrum.png
#   Processing segment 302/314 with HHT...
#   Saved: HC_patient_HC_01_segment_301_hilbert_spectrum.png
#   Processing segment 303/314 with HHT...
#   Saved: HC_patient_HC_01_segment_302_hilbert_spectrum.png
#   Processing segment 304/314 with HHT...
#   Saved: HC_patient_HC_01_segment_303_hilbert_spectrum.png
#   Processing segment 305/314 with HHT...
#   Saved: HC_patient_HC_01_segment_304_hilbert_spectrum.png
#   Processing segment 306/314 with HHT...
#   Saved: HC_patient_HC_01_segment_305_hilbert_spectrum.png
#   Processing segment 307/314 with HHT...
#   Saved: HC_patient_HC_01_segment_306_hilbert_spectrum.png
#   Processing segment 308/314 with HHT...
#   Saved: HC_patient_HC_01_segment_307_hilbert_spectrum.png
#   Processing segment 309/314 with HHT...
#   Saved: HC_patient_HC_01_segment_308_hilbert_spectrum.png
#   Processing segment 310/314 with HHT...
#   Saved: HC_patient_HC_01_segment_309_hilbert_spectrum.png
#   Processing segment 311/314 with HHT...
#   Saved: HC_patient_HC_01_segment_310_hilbert_spectrum.png
#   Processing segment 312/314 with HHT...
#   Saved: HC_patient_HC_01_segment_311_hilbert_spectrum.png
#   Processing segment 313/314 with HHT...
#   Saved: HC_patient_HC_01_segment_312_hilbert_spectrum.png
#   Processing segment 314/314 with HHT...
#   Saved: HC_patient_HC_01_segment_313_hilbert_spectrum.png
#   Completed HC_01: 314 Hilbert spectra generated
#
# === Summary ===
# Total Schizophrenia Hilbert spectrum images: 0
# Total Healthy Control Hilbert spectrum images: 314
# Total Hilbert spectrum images generated: 314
# Images saved in: D:/result/sobi6
#   - Schizophrenia Hilbert spectra: D:/result/sobi6\Schizophrenia_HHT
#   - Healthy Control Hilbert spectra: D:/result/sobi6\HealthyControl_HHT
# HHT Method: Ensemble EMD + Hilbert Transform
# Frequency range: 0.5-32 Hz
# Processing completed successfully with 4 threads
#
# Optimized Hilbert-Huang Transform processing completed!
# Key HHT Features:
# - Empirical Mode Decomposition (EMD/EEMD)
# - Hilbert Transform for instantaneous frequency/amplitude
# - Adaptive time-frequency representation
# - Thread-based parallelism with comprehensive error handling
# - Memory management and optimization
# - Robust signal processing pipeline
