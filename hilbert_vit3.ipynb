# %%
# Part 1: Import Libraries and Setup
import os
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from PIL import Image
import matplotlib.pyplot as plt
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from transformers import ViTForImageClassification, ViTImageProcessor
from transformers import TrainingArguments, Trainer
import seaborn as sns
from tqdm import tqdm
import warnings
warnings.filterwarnings('ignore')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File d:\code\.venv\Lib\site-packages\tensorflow\python\pywrap_tensorflow.py:73
#      72 try:
# ---> 73   from tensorflow.python._pywrap_tensorflow_internal import *
#      74 # This try catch logic is because there is no bazel equivalent for py_extension.
#      75 # Externally in opensource we must enable exceptions to load the shared object
#      76 # by exposing the PyInit symbols with pybind. This error will only be
#      77 # caught internally or if someone changes the name of the target _pywrap_tensorflow_internal.
#      78
#      79 # This logic is used in other internal projects using py_extension.
#
# ImportError: DLL load failed while importing _pywrap_tensorflow_internal: A dynamic link library (DLL) initialization routine failed.
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 13
#      11 from sklearn.model_selection import StratifiedKFold
#      12 from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
# ---> 13 from transformers import ViTForImageClassification, ViTImageProcessor
#      14 from transformers import TrainingArguments, Trainer
#      15 import seaborn as sns
#
# File d:\code\.venv\Lib\site-packages\transformers\utils\import_utils.py:2045, in _LazyModule.__getattr__(self, name)
#    2043 elif name in self._class_to_module.keys():
#    2044     try:
# -> 2045         module = self._get_module(self._class_to_module[name])
#    2046         value = getattr(module, name)
#    2047     except (ModuleNotFoundError, RuntimeError) as e:
#
# File d:\code\.venv\Lib\site-packages\transformers\utils\import_utils.py:2075, in _LazyModule._get_module(self, module_name)
#    2073     return importlib.import_module("." + module_name, self.__name__)
#    2074 except Exception as e:
# -> 2075     raise e
#
# File d:\code\.venv\Lib\site-packages\transformers\utils\import_utils.py:2073, in _LazyModule._get_module(self, module_name)
#    2071 def _get_module(self, module_name: str):
#    2072     try:
# -> 2073         return importlib.import_module("." + module_name, self.__name__)
#    2074     except Exception as e:
#    2075         raise e
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\importlib\__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File d:\code\.venv\Lib\site-packages\transformers\models\vit\modeling_vit.py:33
#      26 from ...activations import ACT2FN
#      27 from ...modeling_outputs import (
#      28     BaseModelOutput,
#      29     BaseModelOutputWithPooling,
#      30     ImageClassifierOutput,
#      31     MaskedImageModelingOutput,
#      32 )
# ---> 33 from ...modeling_utils import ALL_ATTENTION_FUNCTIONS, PreTrainedModel
#      34 from ...pytorch_utils import find_pruneable_heads_and_indices, prune_linear_layer
#      35 from ...utils import auto_docstring, logging, torch_int
#
# File d:\code\.venv\Lib\site-packages\transformers\modeling_utils.py:73
#      63 from .integrations.sdpa_attention import sdpa_attention_forward
#      64 from .integrations.tensor_parallel import (
#      65     ALL_PARALLEL_STYLES,
#      66     _get_parameter_tp_plan,
#    (...)     71     verify_tp_plan,
#      72 )
# ---> 73 from .loss.loss_utils import LOSS_MAPPING
#      74 from .pytorch_utils import (  # noqa: F401
#      75     Conv1D,
#      76     apply_chunking_to_forward,
#    (...)     81     prune_linear_layer,
#      82 )
#      83 from .quantizers import AutoHfQuantizer, HfQuantizer
#
# File d:\code\.venv\Lib\site-packages\transformers\loss\loss_utils.py:21
#      18 import torch.nn as nn
#      19 from torch.nn import BCEWithLogitsLoss, MSELoss
# ---> 21 from .loss_d_fine import DFineForObjectDetectionLoss
#      22 from .loss_deformable_detr import DeformableDetrForObjectDetectionLoss, DeformableDetrForSegmentationLoss
#      23 from .loss_for_object_detection import ForObjectDetectionLoss, ForSegmentationLoss
#
# File d:\code\.venv\Lib\site-packages\transformers\loss\loss_d_fine.py:21
#      18 import torch.nn.functional as F
#      20 from ..utils import is_vision_available
# ---> 21 from .loss_for_object_detection import (
#      22     box_iou,
#      23 )
#      24 from .loss_rt_detr import RTDetrHungarianMatcher, RTDetrLoss
#      27 if is_vision_available():
#
# File d:\code\.venv\Lib\site-packages\transformers\loss\loss_for_object_detection.py:32
#      28     from scipy.optimize import linear_sum_assignment
#      31 if is_vision_available():
# ---> 32     from transformers.image_transforms import center_to_corners_format
#      35 def dice_loss(inputs, targets, num_boxes):
#      36     """
#      37     Compute the DICE loss, similar to generalized IOU for masks
#      38
#    (...)     44                  class).
#      45     """
#
# File d:\code\.venv\Lib\site-packages\transformers\image_transforms.py:47
#      44     import torch
#      46 if is_tf_available():
# ---> 47     import tensorflow as tf
#      49 if is_flax_available():
#      50     import jax.numpy as jnp
#
# File d:\code\.venv\Lib\site-packages\tensorflow\__init__.py:40
#      37 _os.environ.setdefault("ENABLE_RUNTIME_UPTIME_TELEMETRY", "1")
#      39 # Do not remove this line; See https://github.com/tensorflow/tensorflow/issues/42596
# ---> 40 from tensorflow.python import pywrap_tensorflow as _pywrap_tensorflow  # pylint: disable=unused-import
#      41 from tensorflow.python.tools import module_util as _module_util
#      42 from tensorflow.python.util.lazy_loader import KerasLazyLoader as _KerasLazyLoader
#
# File d:\code\.venv\Lib\site-packages\tensorflow\python\pywrap_tensorflow.py:88
#      86     sys.setdlopenflags(_default_dlopen_flags)
#      87 except ImportError:
# ---> 88   raise ImportError(
#      89       f'{traceback.format_exc()}'
#      90       f'\n\nFailed to load the native TensorFlow runtime.\n'
#      91       f'See https://www.tensorflow.org/install/errors '
#      92       f'for some common causes and solutions.\n'
#      93       f'If you need help, create an issue '
#      94       f'at https://github.com/tensorflow/tensorflow/issues '
#      95       f'and include the entire stack trace above this error message.')
#      97 # pylint: enable=wildcard-import,g-import-not-at-top,unused-import,line-too-long
#
# ImportError: Traceback (most recent call last):
#   File "d:\code\.venv\Lib\site-packages\tensorflow\python\pywrap_tensorflow.py", line 73, in <module>
#     from tensorflow.python._pywrap_tensorflow_internal import *
# ImportError: DLL load failed while importing _pywrap_tensorflow_internal: A dynamic link library (DLL) initialization routine failed.
#
#
# Failed to load the native TensorFlow runtime.
# See https://www.tensorflow.org/install/errors for some common causes and solutions.
# If you need help, create an issue at https://github.com/tensorflow/tensorflow/issues and include the entire stack trace above this error message.

# %%
# Set device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

# Set random seeds for reproducibility
torch.manual_seed(42)
np.random.seed(42)
if torch.cuda.is_available():
    torch.cuda.manual_seed(42)

# %%
# Part 2: Dataset Configuration and Custom Dataset Class

# Configuration - UPDATE THESE PATHS TO YOUR ACTUAL PATHS
CONFIG = {
    'schizophrenia_folder': '/path/to/schizophrenia/folder',  # Update this path
    'healthy_folder': '/path/to/healthy/folder',              # Update this path
    'batch_size': 16,
    'num_epochs': 50,
    'learning_rate': 2e-5,
    'image_size': 224,
    'num_folds': 5,
    'num_classes': 2,
    'model_name': 'google/vit-base-patch16-224-in21k'
}

class EEGDataset(Dataset):
    def __init__(self, image_paths, labels, processor, transform=None):
        self.image_paths = image_paths
        self.labels = labels
        self.processor = processor
        self.transform = transform
    
    def __len__(self):
        return len(self.image_paths)
    
    def __getitem__(self, idx):
        # Load image
        image_path = self.image_paths[idx]
        image = Image.open(image_path).convert('RGB')
        
        # Apply transforms if provided
        if self.transform:
            image = self.transform(image)
        
        # Process with ViT processor
        inputs = self.processor(images=image, return_tensors="pt")
        pixel_values = inputs['pixel_values'].squeeze(0)
        
        label = torch.tensor(self.labels[idx], dtype=torch.long)
        
        return {
            'pixel_values': pixel_values,
            'labels': label
        }

# Data augmentation transforms
train_transform = transforms.Compose([
    transforms.Resize((CONFIG['image_size'], CONFIG['image_size'])),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomRotation(degrees=10),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.RandomAffine(degrees=0, translate=(0.1, 0.1)),
])

val_transform = transforms.Compose([
    transforms.Resize((CONFIG['image_size'], CONFIG['image_size'])),
])

print("Dataset class and transforms defined successfully!")
